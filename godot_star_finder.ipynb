# %%
import requests
import time
import csv
import numpy as np
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import re
from datetime import datetime
from dotenv import load_dotenv
import os
from collections import Counter

# %% [markdown]
# Step 1 - Batch scrape GitHub URLs, save to `assets_with_github.csv` and `assets_without_github.csv`

# %%
def scrape_assets(max_pages=13):
    all_assets = []
    assets_with_github = []
    assets_without_github = []
    
    for page in range(max_pages):
        url = f"https://godotengine.org/asset-library/asset?max_results=500&page={page}&sort=name"
        print(f"Scraping page {page}...")
        
        try:
            response = requests.get(url)
            response.raise_for_status()
            
            soup = BeautifulSoup(response.content, 'html.parser')
            asset_items = soup.find_all('li', class_='asset-item')
            
            if not asset_items:
                print(f"No more assets found on page {page}. Stopping.")
                break
                
            print(f"Found {len(asset_items)} assets on page {page}")
            
            for item in asset_items:
                asset_data = {}
                
                title_elem = item.find('h4')
                if title_elem:
                    asset_data['title'] = title_elem.get_text(strip=True)
                
                link_elem = item.find('a', class_='asset-header')
                if link_elem and link_elem.get('href'):
                    href = link_elem['href']
                    asset_id = href.split('/')[-1]
                    asset_data['asset_id'] = asset_id
                    asset_data['asset_url'] = f"https://godotengine.org{href}"
                
                primary_tag = item.find('span', class_='label-primary')
                if primary_tag:
                    asset_data['category'] = primary_tag.get_text(strip=True)
                
                license_tag = item.find('span', class_='label-default')
                if license_tag:
                    asset_data['license'] = license_tag.get_text(strip=True)
                
                footer = item.find('div', class_='asset-footer')
                if footer:
                    author_link = footer.find('a')
                    if author_link:
                        author_text = author_link.get('title', '')
                        if 'Search assets by' in author_text:
                            author = author_text.replace('Search assets by', '').strip(" '\"")
                            asset_data['author'] = author
                
                img_elem = item.find('img', class_='media-object')
                github_url = None
                if img_elem and img_elem.get('src'):
                    icon_src = img_elem['src']
                    asset_data['icon_url'] = icon_src
                    
                    if 'github.com' in icon_src or ('githubusercontent.com' in icon_src and 'user-images.githubusercontent.com' not in icon_src):
                        # Handle github.com and raw.githubusercontent.com (but not user-images.githubusercontent.com)
                        if 'githubusercontent.com' in icon_src:
                            # For raw.githubusercontent.com/user/repo/branch/file
                            github_match = re.search(r'githubusercontent\.com/([^/]+/[^/]+)', icon_src)
                        else:
                            # For github.com URLs
                            github_match = re.search(r'github\.com/([^/]+/[^/]+)', icon_src)
                            
                        if github_match:
                            repo_path = github_match.group(1)
                            repo_path = repo_path.split('/blob/')[0].split('/raw/')[0].split('?')[0]
                            github_url = f"https://github.com/{repo_path}"
                            asset_data['github_url'] = github_url
                            print(f"Success: {asset_data.get('title', 'Unknown')}")
                        else:
                            print(f"GitHub found in icon but regex failed for '{asset_data.get('title', 'Unknown')}': {icon_src}")
                    else:
                        print(f"No GitHub in icon for '{asset_data.get('title', 'Unknown')}': {icon_src}")
                else:
                    print(f"No icon found for '{asset_data.get('title', 'Unknown')}'")
                          
                if asset_data:
                    all_assets.append(asset_data)
                    if github_url:
                        assets_with_github.append(asset_data)
                    else:
                        assets_without_github.append(asset_data)
            
            time.sleep(5)
            
        except Exception as e:
            print(f"Error scraping page {page}: {e}")
            break
    
    return assets_with_github, assets_without_github

print("Starting Godot Asset Library scraping...")
assets_with_github, assets_without_github = scrape_assets()

print(f"\n=== SAVING {len(assets_with_github)} ASSETS WITH GITHUB ===")
with open('assets_with_github.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(['title', 'category', 'license', 'author', 'asset_url', 'github_url'])
    for asset in assets_with_github:
        writer.writerow([
            asset.get('title', ''),
            asset.get('category', ''),
            asset.get('license', ''),
            asset.get('author', ''),
            asset.get('asset_url', ''),
            asset.get('github_url', '')
        ])

print(f"\n=== SAVING {len(assets_without_github)} ASSETS WITHOUT GITHUB ===")
with open('assets_without_github.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(['title', 'category', 'license', 'author', 'asset_url'])
    for asset in assets_without_github:
        writer.writerow([
            asset.get('title', ''),
            asset.get('category', ''),
            asset.get('license', ''),
            asset.get('author', ''),
            asset.get('asset_url', '')
        ])

print("Step 1 complete")
# Out:
# Starting Godot Asset Library scraping...
# Scraping page 0...
# Found 500 assets on page 0
# Success: Godot Atlas Cutter
# Success: Packed Scene Instantiater
# Success: Takin Game Template
# Success: Godot 3D Flight Control Tutorial
# Success: Thirdperson Controller (.NET)
# Success: 3D Cross The Road Template
# Success: 3d Maze Generator
# Success: Alexandria - alexandria.netserver
# Success: DungeonCrawler3D
# Success: Follow Parent
# Success: GdScript2All
# Success: Godot Tiled Tools
# Success: Godot-Spyglass
# Success: GodotTouchCamera
# No GitHub in icon for 'Kenney Prototype Tools':  	https://gitlab.com/MrMinimal/godot-kenney-prototype-tools/-/raw/master/icon.PNG
# Success: Kenney's UI Audio
# Success: localization_with_google_sheet
# Success: RhythmNotifier - Sync Your Game to the Beat of the Music (Sound & Audio)
# Success: TextEditor Integration
# Success: TODO 4
# Success: Virtual Joystick
# Success: Visibility shortcut
# Success: "Immersive" First Person Controller
# Success: .mtl loader
# No GitHub in icon for '.nw Level Importer': https://gitlab.com/xzirox/nw-level-importer/raw/main/addons/nw_level_importer/assets/icon.png
# Success: 1$ gesture recogniser and recorder
# Success: 10 Simple Shader Examples (with Video)
# Success: 10+ GDScript Tips Script (With Video)
# Success: 2, 4, 8 Godot-multidirectional-joystick
# Success: 2.5D Demo
# Success: 2.5D Game Demo
# No GitHub in icon for '2.5D Sprite Rotator': https://i.ibb.co/vcQSLpT/3d-1529981.png
# No GitHub in icon for '2.5D World Map with Selection': https://i.imgur.com/zFrdCZ7.png
# No GitHub in icon for '2048 Demo': https://s2.loli.net/2022/12/15/9JYny2TK8hUD6wL.png
# No GitHub in icon for '2090s Language System': https://2090s-gamestudio.de/wp-content/uploads/2023/12/Language_system_icon.png
# No GitHub in icon for '2090s Storage System': https://2090s-gamestudio.de/wp-content/uploads/2023/12/Storage_System_icon.png
# Success: 2D Action Compute Resource
# Success: 2D Bullet Shower Demo
# Success: 2D Camera Controller - Multitarget follow + FXs
# No GitHub in icon for '2D Camera Controller Singleton / with Dev Tools': https://www.burtonmediainc.com/images/camera_controller.png
# No GitHub in icon for '2D Camera Limiter': https://i.imgur.com/bxPKGvK.png
# Success: 2D Controls Toolkit
# Success: 2D CRPG Character Controller
# No GitHub in icon for '2D Dodge The Creeps Demo': https://user-images.githubusercontent.com/5276727/74889290-2e432a00-5389-11ea-9762-3525012fc949.png
# No GitHub in icon for '2D Dodge The Creeps Demo (Mono version)': https://user-images.githubusercontent.com/5276727/74889290-2e432a00-5389-11ea-9762-3525012fc949.png
# Success: 2D drawing by code (gdscript)
# No GitHub in icon for '2D Dungeon Generator': https://i.imgur.com/9mrKAbr.png
# Success: 2D Editor Light Toggle
# No GitHub in icon for '2D Finite State Machine Demo': https://user-images.githubusercontent.com/5276727/74890913-1f12ab00-538e-11ea-8692-4b0e97599b12.png
# No GitHub in icon for '2D Flipscreen Library with Scrolling': https://gitlab.com/chucklepie-productions/flipscreen-template/-/raw/master/README_Images/image-pt4-3.png
# No GitHub in icon for '2D Flocking Demo': https://natureofcode.com/book/imgs/chapter06/ch06_01.png
# No GitHub in icon for '2D GD Paint Demo': https://user-images.githubusercontent.com/5276727/74892067-428b2500-5391-11ea-8ee8-32773c6a400b.png
# Success: 2D grid based movement
# No GitHub in icon for '2D HDR Demo': https://user-images.githubusercontent.com/5276727/35007679-235424ea-fb03-11e7-9cb2-3d9dbd260182.png
# Success: 2D Hexagon TileMapLayer Navigation Class
# No GitHub in icon for '2D Hexagonal Map Demo': https://user-images.githubusercontent.com/5276727/35007684-2422357e-fb03-11e7-829a-7315474c0c74.png
# Success: 2D Hexagonal Map Navigation Demo
# No GitHub in icon for '2D in 3D Demo': https://user-images.githubusercontent.com/5276727/35007796-3c9a05aa-fb03-11e7-9bef-9452e44f2da3.png
# Success: 2D in 3D Viewport Demo
# No GitHub in icon for '2D Isometric Demo': https://user-images.githubusercontent.com/5276727/35007686-24b098a0-fb03-11e7-9eaf-52dd023601eb.png
# No GitHub in icon for '2D Kinematic Character Demo': https://user-images.githubusercontent.com/5276727/35007689-250401fc-fb03-11e7-9df8-397b369eda40.png
# No GitHub in icon for '2D Kinematic Character Demo CS': https://user-images.githubusercontent.com/5276727/35007689-250401fc-fb03-11e7-9df8-397b369eda40.png
# No GitHub in icon for '2D Light Masks Demo': https://user-images.githubusercontent.com/5276727/35007693-26402172-fb03-11e7-8ed6-4c3dc9c2a345.png
# No GitHub in icon for '2D Lights and Shadows Demo': https://user-images.githubusercontent.com/5276727/35007697-26de3e66-fb03-11e7-8076-d96ba489a9e1.png
# Success: 2D Lights and Shadows Demo
# Success: 2D Lights as Mask Demo
# Success: 2D Liquid Simulator
# Success: 2D Liquid Simulator - 4.3+
# No GitHub in icon for '2D Movement Controller (C#)': https://godotengine.org/assets/press/icon_color.png
# No GitHub in icon for '2D Navigation Astar Demo': https://user-images.githubusercontent.com/5276727/74892352-0906e980-5392-11ea-8f1f-bc1e31720046.png
# No GitHub in icon for '2D Navigation Astar Demo CS': https://user-images.githubusercontent.com/5276727/74892352-0906e980-5392-11ea-8f1f-bc1e31720046.png
# No GitHub in icon for '2D Navigation Demo': https://user-images.githubusercontent.com/5276727/35007699-277f8e38-fb03-11e7-9e5d-2ba5ec673328.png
# No GitHub in icon for '2D Navigation Demo CS': https://user-images.githubusercontent.com/5276727/35007699-277f8e38-fb03-11e7-9e5d-2ba5ec673328.png
# No GitHub in icon for '2D outline shader': https://godotshaders.com/wp-content/uploads/2021/01/outline_shader_asset_library.png
# No GitHub in icon for '2D outline shader': https://godotshaders.com/wp-content/uploads/2021/01/outline_shader_asset_library.png
# Success: 2D Particles Demo
# No GitHub in icon for '2D Particles Demo': https://user-images.githubusercontent.com/5276727/35007702-2841ca98-fb03-11e7-9a0b-288ef5ff3aed.png
# No GitHub in icon for '2D Physics Platformer Demo (RigidBody)': https://user-images.githubusercontent.com/5276727/35007704-289bf87e-fb03-11e7-9e0d-b000dd77d7e2.png
# No GitHub in icon for '2D Physics Platformer Demo (Rigidbody) CS': https://user-images.githubusercontent.com/5276727/35007704-289bf87e-fb03-11e7-9e0d-b000dd77d7e2.png
# Success: 2D Physics Tests Demo
# Success: 2D Physics Tests Demo
# Success: 2D Planar Movement
# Success: 2D Platformer - Starter Kit
# Success: 2D Platformer Demo
# No GitHub in icon for '2D Platformer Demo (KinematicBody)': https://user-images.githubusercontent.com/5276727/35007706-2922edf2-fb03-11e7-9a82-9b27459d007e.png
# No GitHub in icon for '2D Platformer Pathfinding Tool': https://i.postimg.cc/MHNNgKyW/title-image.png
# Success: 2D Platformer Toolkit
# Success: 2D Procedural Map Generator
# Success: 2D Revealer
# No GitHub in icon for '2D Role Playing Game Demo': https://user-images.githubusercontent.com/5276727/74892533-90545d00-5392-11ea-8511-6597aa9f1601.png
# No GitHub in icon for '2D Screen-Space Shaders Demo': https://user-images.githubusercontent.com/5276727/35007713-2a15d21a-fb03-11e7-8844-c3d5f397c455.png
# Success: 2D Shapes
# No GitHub in icon for '2D Sprite Shaders Demo': https://user-images.githubusercontent.com/5276727/74892950-c3e3b700-5393-11ea-8b35-bec152d0561e.png
# Success: 2D Strategy Camera
# Success: 2D Tactical RPG Demo
# No GitHub in icon for '2D Tools': https://img.itch.zone/aW1nLzE3ODk3OTM1LnBuZw==/315x250%23c/QOrTt4.png
# Success: 2D Train/Railroad Demo
# Success: 2D Train/Railroad Demo
# Success: 2D Wheeled Vehicle Template
# Success: 2DLights-Benchmark-Demo
# No GitHub in icon for '3D Animated Robot': https://i.imgur.com/isTjPxh.png
# Success: 3D Anti-Aliasing Demo
# Success: 3D asset pack preview renederer
# Success: 3D Auto Collision Generator
# Success: 3D Basis Workspace
# Success: 3D Car with Settingspanel
# Success: 3D Controls Toolkit
# No GitHub in icon for '3D Course Editor': https://bitbucket.org/arlez80/course-editor/downloads/icon.png
# Success: 3D Destructible Procedural Smooth Terrain
# Success: 3D Enemy Toolkit
# Success: 3D First Person WASD Input Actions
# No GitHub in icon for '3D FPP Interaction Template': https://i.imgur.com/cwtJ7ic.png
# Success: 3D Gallery
# Success: 3D Gizmo Tool
# Success: 3D Global Illumination Demo
# Success: 3D Graphics Settings Demo
# Success: 3D GridMap and non GridMap Navmesh Demos
# No GitHub in icon for '3D Hover canvasitem': https://i.ibb.co/Kj3xbkXQ/Hover-UI-Cover2.jpg
# No GitHub in icon for '3D in 2D Demo': https://user-images.githubusercontent.com/5276727/35007799-3d1a11aa-fb03-11e7-8f33-721ca378f671.png
# Success: 3D in 2D Viewport demo
# No GitHub in icon for '3D Inverse Kinematics Demo': https://user-images.githubusercontent.com/5276727/74893199-7ca9f600-5394-11ea-9949-06790826a0ae.png
# Success: 3D Kinematic Character Demo
# No GitHub in icon for '3D Kinematic Character Demo CS': https://user-images.githubusercontent.com/5276727/35007720-2b7fef50-fb03-11e7-9f40-870065fe1680.png
# Success: 3D Labels and Texts Demo
# Success: 3D Lights and Shadows Demo
# Success: 3D Low-Poly Exterior Plants
# Success: 3d Male Base Mesh
# No GitHub in icon for '3D Material Testers Demo': https://user-images.githubusercontent.com/5276727/35007723-2c00cc10-fb03-11e7-9ed0-2d8244121d85.png
# Success: 3D Multiplayer Bobmerman
# Success: 3D Navigation Demo
# No GitHub in icon for '3D Navmesh Demo': https://user-images.githubusercontent.com/5276727/35007727-2cba9686-fb03-11e7-97f8-b8fd49b898fa.png
# Success: 3D Node Graph
# Success: 3D Outline
# Success: 3D Particles Demo
# Success: 3D Physics Tests Demo
# Success: 3D Physics Tests Demo
# Success: 3D Pixel-Perfect Outline
# Success: 3D Planet Generator
# Success: 3D Platform Template
# No GitHub in icon for '3D Platformer - Starter': https://user-images.githubusercontent.com/92097566/270122768-630fc077-3997-4fc2-b25f-03419cf02dae.png
# No GitHub in icon for '3D Platformer Demo': https://user-images.githubusercontent.com/5276727/35007729-2d09bc70-fb03-11e7-907e-aa95314c1d4a.png
# Success: 3D Platformer Robot
# No GitHub in icon for '3D print shader': https://upload.wikimedia.org/wikipedia/commons/thumb/6/6a/Godot_icon.svg/240px-Godot_icon.svg.png
# Success: 3D reflecting laser Godot.
# Success: 3D Refraction Shader
# Success: 3D Resolution Scaling Demo
# Success: 3D RigidBody Character Demo
# Success: 3d Rotate Direct Constant Smooth
# Success: 3D RTS Camera
# Success: 3D Shooter Kit
# Success: 3D Targeting System
# Success: 3D Targeting System Ultimate
# Success: 3D Text Plugin
# No GitHub in icon for '3D Tiles For Godot': https://i.postimg.cc/MH6qVqgr/Upscaled-Cesium1.png
# No GitHub in icon for '3D Trail in C#': https://upload.wikimedia.org/wikipedia/commons/thumb/6/6a/Godot_icon.svg/240px-Godot_icon.svg.png
# No GitHub in icon for '3D Truck Town Demo': https://user-images.githubusercontent.com/5276727/74893463-1c678400-5395-11ea-9541-43252785dbb8.png
# Success: 3D Viewport Scaling Demo
# Success: 3D Visualized Path
# Success: 3D Voxel Demo
# Success: 3D Water Surface
# Success: 3D Waypoints Demo
# Success: 3D Waypoints Demo
# Success: 3DCamera for Fighing Game
# Success: 4-Directional Animation
# Success: 4.1+ Discord  RPC / Editor Presence Plugin
# No GitHub in icon for '766 Color Palette Swap Shader': https://user-images.githubusercontent.com/36577443/86539061-763d9600-bebf-11ea-950e-b24ba65be5df.png
# Success: A Dialogue Box
# Success: a mole game
# No GitHub in icon for 'A Star 2D Grid Node': https://user-images.githubusercontent.com/35619327/230246342-35f547c4-81d1-4563-82ac-4fbc83a3a2f1.png
# No GitHub in icon for 'AABB Static BoxCollider from Mesh': https://vt-vtwa-assets.varsitytutors.com/vt-vtwa/uploads/problem_question_image/image/1346/Cube__PSF_.png
# Success: Abandoned Spaceship Demo
# No GitHub in icon for 'abfi: Allegro Bitmap Font Importer': https://gitlab.com/snoopdouglas/abfi/-/raw/v3.0.0/.images/logo.png
# Success: About Dialog
# No GitHub in icon for 'Achievement System': https://imgur.com/vIftQvp.png
# No GitHub in icon for 'Acro's Hitboxes': https://i.imgur.com/DLcrq2Z.png
# Success: Acrylic Glass
# Success: Acrylic Glass
# Success: Action Behavior Tree
# Success: Action Command
# Success: Action Icon
# Success: Action Icon
# Success: Action List
# Success: ActionButton
# Success: ActionReaction
# Success: Active Rigid Body Ragdolls
# No GitHub in icon for 'AdaptiSound': https://i.imgur.com/8XgkQyp.png
# Success: ADB Helper
# Success: Additional APIs
# Success: Addon Toggler
# Success: AddonSave
# Success: Addonsave (4.1)
# Success: Adivery Plugin
# No GitHub in icon for 'AdMob': https://i.imgur.com/T3Beai0.png
# No GitHub in icon for 'AdMob': https://i.imgur.com/T3Beai0.png
# No GitHub in icon for 'AdMob (Legacy 3.3)': https://i.imgur.com/T3Beai0.png
# No GitHub in icon for 'AdMob (v2) (Legacy Godot 4.0)': https://i.imgur.com/T3Beai0.png
# Success: Advanced Character
# Success: Advanced FPS Controller Template
# No GitHub in icon for 'Advanced Inspector Exporter': https://user-images.githubusercontent.com/77918086/167289292-307e2190-031b-40e8-af71-3ca30e498255.png
# Success: Advanced Movement System Godot (AMSG) Template
# Success: Advanced Radial Menu
# Success: Advanced Random Stuff
# Success: Advanced Random Stuff
# Success: Advanced Rich Text Label
# Success: Advanced Save System
# Success: Advanced Search
# Success: AdvancedText
# No GitHub in icon for 'AES in GDScript': https://i.imgur.com/iZepZTl.png
# Success: Agar.io
# Success: Agones SDK Plugin
# Success: AI Assistant Hub
# No GitHub in icon for 'AI Assistants For Godot 4': https://registry.npmmirror.com/@lobehub/icons-static-png/1.46.0/files/dark/gemini-brand-color.png
# Success: AI Context Generator
# Success: AI dialog generator plugin
# Success: AI Horde Client
# Success: AI Use Cases Demo (With Video)
# Success: AI Voices/Dialogues Generator (AllTalk_TTS)
# Success: Aircraft
# No GitHub in icon for 'Airplane Mouse Controls': https://codeberg.org/ed3800/AirplaneMouseControlsForGodot3/raw/branch/main/icon/godotAssetIcon.jpg
# Success: Alexandria - alexandria.db
# Success: Alexandria - alexandria.netclient
# Success: Algodot
# Success: AlienNation
# Success: Alignment Tool
# Success: All Projectiles
# Success: AllSky Free
# Success: AlphaOS
# Success: AlternativeTimer
# Success: Alys - Precision Platformer
# Success: ambientcg
# Success: AmbientCG Material Downloader (Godot 4.3)
# Success: AMC Forth
# Success: AMP (Adaptive Music Player)
# Success: Anaglyph Camera
# Success: Analog Control
# Success: Analog Controller
# Success: Analog Stick
# Success: Analog Touch Control
# Success: AnchorsOnlyPreset
# Success: Android Admob Plugin
# Success: Android Billing Godot Plugin
# Success: Android Deeplink Plugin
# No GitHub in icon for 'Android Geolocation Plugin': https://karimibrahim.github.io/Godot-Geolocation-Android/icon.png
# No GitHub in icon for 'Android Godot Plugin Template': https://crackberry.com/sites/crackberry.com/files/topic_images/2013/ANDROID.png
# Success: Android Haptics
# No GitHub in icon for 'Android IAP Demo': https://user-images.githubusercontent.com/5276727/74893602-6e100e80-5395-11ea-9de5-0178fa3b008c.png
# Success: Android IAP Demo with C#
# Success: Android In-App Purchases (IAP) Demo
# Success: Android In-app Review Plugin
# Success: Android Internet Connection State Plugin
# Success: Android Notification Scheduler Plugin
# Success: Android RMB Emulator
# Success: Android Share Plugin
# Success: Android System Bar Color Changer
# Success: AndroidSystemBarControl
# No GitHub in icon for 'Anima': https://anima.ceceppa.me/demo/favicon.png
# Success: Anima for Godot 4
# No GitHub in icon for 'Animated Bow': https://i.ibb.co/qgxybX0/Desktop-19-10-2021-16-15-17-403.jpg
# No GitHub in icon for 'Animated Box Container': https://resources.halyul.dev/GramineaGroup/animated_box_container.png
# Success: Animated Camera
# Success: Animated Control Node
# Success: Animated Grid Container
# No GitHub in icon for 'Animated LowPoly Pistol': https://i.ibb.co/r7xhRG1/1.jpg
# No GitHub in icon for 'Animated LowPoly Skeleton': https://i.ibb.co/rdMFftH/skeleton.png
# No GitHub in icon for 'Animated LowPoly Slime': https://i.ibb.co/jMt7PVy/slime.png
# No GitHub in icon for 'Animated Panel Container': https://resources.halyul.dev/GramineaGroup/animated_panel_container.png
# Success: Animated Shape 2D
# Success: Animated Sprite to Animation Player Convertor
# Success: Animated Sprite to Animation Player Convertor 4.0
# Success: Animated Text
# Success: Animated Tiled Skybox
# No GitHub in icon for 'Animated Zombie': https://i.ibb.co/C5mb1T5/zombie-icon.jpg
# Success: AnimatedButton
# No GitHub in icon for 'Animation Folder Loader': https://i.imgur.com/eZlQlWM.png
# No GitHub in icon for 'Animation Frame Picker': https://images2.imgbox.com/31/d3/FqxKARrg_o.png
# Success: Animation Node Redirector
# Success: Animation Resetter
# Success: Animation Slider
# Success: Animation Slider
# Success: AnimationPlayer frames times in Milliseconds
# Success: AnimationPlayer Refactor
# Success: AnimationPlayer SpriteFrames Helper
# Success: Animator Import
# Success: AnimSheet - SpriteSheet to Animation Player
# Success: Anomaly Aces Table
# Success: Anti-cheating-value
# Success: Anti-cheating-value-plus
# Success: Antialiased Line2D - Better antialiasing for 2D line/polygon/circle drawing
# Success: Antialiased Line2D - Better antialiasing for 2D line/polygon/circle drawing
# Success: Antialiased Line2D Demo
# Success: Antialiased Line2D Demo
# No GitHub in icon for 'AntiSpecularNoise': https://s2.loli.net/2022/10/22/yiDoGX7zWMSv4fR.png
# Success: AnyIcon: type and class icons utility
# Success: Applinks
# Success: AppLovinMAX
# Success: Appwrite SDK
# Success: APRUM
# Success: Arabfunny Generator
# Success: Arabic Support
# Success: AraVox - Dialogue Writing Helper
# No GitHub in icon for 'Arc Dark theme': https://cdn.rawgit.com/Geequlim/godot-themes/master/icon.png
# Success: Arc2D
# Success: Archura's Credits
# Success: Arcweave Godot Plugin
# Success: Arcweave Godot Plugin
# Success: AreaOfSight2D
# No GitHub in icon for 'AreaProber2D': https://i.imgur.com/FGFyOMX.png
# Success: ArgParse
# Success: Arky Addons
# Success: Arm Performance Studio Integration
# No GitHub in icon for 'Array Modifier': https://user-images.githubusercontent.com/36821133/127785925-38b82dae-8823-4b69-8573-bfac779d14c8.png
# No GitHub in icon for 'Array Modifier': https://user-images.githubusercontent.com/36821133/127785925-38b82dae-8823-4b69-8573-bfac779d14c8.png
# Success: ArrayUtils
# Success: Arrow2D
# Success: Arrow3D
# No GitHub in icon for 'Arrows': https://bytebucket.org/lkokemohr/godot_arrow_plugin/raw/a1367973ee66d41260177299582f110b387f5f56/plugin_icon.png
# Success: Artificial Worm Brain AI
# No GitHub in icon for 'Aseprite Animation Importer': https://user-images.githubusercontent.com/7024016/99195898-85581d00-27aa-11eb-98cf-03d5caa53622.png
# Success: Aseprite Animation Importer - Godot 4
# Success: Aseprite Helper
# Success: Aseprite import
# Success: Aseprite Importer
# No GitHub in icon for 'Aseprite Importer': https://cdn.githubraw.com/MeagherGames/aseprite-importer-addon/ac0f482a8bb962275e9a86964099ffc5415475c9/icon.png
# No GitHub in icon for 'Aseprite importers': https://user-images.githubusercontent.com/7024016/236668185-f53ac341-26de-49a2-bc2d-86c080342ebf.png
# Success: Aseprite Wizard
# Success: Aseprite Wizard
# Success: AsepriteAnimSetter
# No GitHub in icon for 'AspectRatioResizeContainer': https://godotengine.org/assets/press/icon_color.png
# Success: Asset Atlas Replacer
# Success: Asset Dock
# Success: Asset Drawer
# Success: Assets Manager
# Success: AssetsPathGenerator
# Success: Assorted Controls
# Success: AStar Grid Pathfinding Demo (with tutorial Video)
# No GitHub in icon for 'Asteroid Mania': https://i.ibb.co/ws0t6Xb/logo.png
# Success: Async Resource Loader (C#)
# Success: Async Socket
# No GitHub in icon for 'Asynchronous Scene Loader': https://i.imgur.com/ZQF6zMx.png
# Success: Asynchronous Scene Loader
# Success: Asynchronous Task Manager
# Success: Atko.GDWeaver Assets
# No GitHub in icon for 'Atlas Importer': https://cdn.rawgit.com/GodotExplorer/atlas_importer/master/addons/atlas_importer/icon.png
# Success: Atlas Importer3
# Success: AtlasPlayer
# Success: Atmosphere shader
# Success: Atmosphere shader
# No GitHub in icon for 'Audio Booth': https://gitlab.com/Bitron/audio-booth/raw/1.0.1/icon.png
# Success: Audio BPM Sync Demo
# Success: Audio BPM Sync Demo
# Success: Audio Control
# Success: Audio Device Changer Demo
# No GitHub in icon for 'Audio Device Changer Demo': https://user-images.githubusercontent.com/5276727/74893602-6e100e80-5395-11ea-9de5-0178fa3b008c.png
# Success: Audio Effect Inspector
# Success: Audio Events
# Success: Audio Generator Demo
# No GitHub in icon for 'Audio Generator Demo': https://user-images.githubusercontent.com/5276727/74893602-6e100e80-5395-11ea-9de5-0178fa3b008c.png
# Success: Audio Haptics
# Success: Audio Loader
# Success: Audio Manager
# Success: Audio Manager 3D
# No GitHub in icon for 'Audio Mic Record Demo': https://user-images.githubusercontent.com/5276727/74893602-6e100e80-5395-11ea-9de5-0178fa3b008c.png
# Success: Audio Microphone Record Demo
# Success: Audio Mixer Visualizer
# Success: Audio Node Wrangler Addon
# No GitHub in icon for 'Audio Spectrum Demo': https://user-images.githubusercontent.com/5276727/74893602-6e100e80-5395-11ea-9de5-0178fa3b008c.png
# Success: Audio Spectrum Visualizer Demo
# Success: Audio Station
# Success: Audio Stream Player Clipper 2D
# Success: Audio Stream Player Clipper 3D
# Success: Audio Visualizer Plugin
# Success: AudioEffectGate
# Success: AudioGame RPG
# Success: AudioLogic
# Success: AudiosPlugin : Godot iOS Audio Plugin
# Success: AudioStream Subtitle
# Success: AudioStreamPlayerArea2D
# Success: AudioStreamPlayerArea2D
# Success: AudioStreamPlayerMultiple
# Success: AudioStreamPreview
# No GitHub in icon for 'Authoritative Server Client Framework (Fast-paced)': https://i.ibb.co/bJBHtRx/social-network-icon-g88d8b6d8b-640.png
# Success: Auto add class_name
# No GitHub in icon for 'Auto Expand Property Inspector': https://godotengine.org/assets/press/icon_color.png
# Success: Auto Export Version
# Success: Auto Export Version
# No GitHub in icon for 'Auto Material Setup': https://i.imgur.com/sKUy61D.png
# Success: Auto Night Mode
# Success: Auto Polygon2D Triangulation
# Success: Auto Screenshot
# Success: Auto Version Code
# No GitHub in icon for 'Auto Version Incrementor (Mono)': https://user-images.githubusercontent.com/39946030/124266568-00790400-daec-11eb-8ba8-5d4bd009648d.png
# Success: Auto Vertex Painter
# Success: Auto-Bus (auto event bus with signal nodes)
# Success: AutoAnim 2D Character Creator for Godot 3.5
# Success: AutoAssignIDs
# Success: AutoGridContainer
# Success: Autoload Demo
# No GitHub in icon for 'AutoMat plugin - automatically create and assign materials': https://user-images.githubusercontent.com/45795134/221383610-b85392b1-5dde-4529-bfb7-31aa544b923c.png
# Success: Automatic Layer Enums
# No GitHub in icon for 'AutoSaver Toggle for Godot Editor (C#)': https://i.imgur.com/BED3Duu.png
# Success: AutoScrollContainer
# No GitHub in icon for 'AutoSizeText': https://spielmannspiel.com/images/icons/AutoSizeText_256.png
# Success: Autotile Editor
# No GitHub in icon for 'AutotileGenerator': https://i.ibb.co/FYGBCD4/image.png
# No GitHub in icon for 'AutotileGenerator3x3min': https://i.ibb.co/sJbqj93/icon.png
# No GitHub in icon for 'aviones (Planes)': https://gitlab.com/gamedevargentina/aviones-curso/-/raw/main/graficos/ships/ship_0002.png
# Success: AwaitableHTTPRequest
# No GitHub in icon for 'Awaiter await-all': https://s1.imagehub.cc/images/2024/12/26/3013f857d9d0d37b7cddf79d86ceb0ed.png
# Success: Awesome Custom Cursor
# Success: Awesome Debug Log
# Success: Awesome Input Icon
# Success: Awesome Scene Manager
# Success: AWS Amplify
# Success: AWS Amplify
# No GitHub in icon for 'Axie Starter 3D': https://welcome.axie.tech/images/accents/axies/buba-right.png
# Success: ÃGUA DINÃ‚MICA / DYNAMIC WATER
# Success: B-Spline Plugin
# No GitHub in icon for 'Background Loading Demo': https://user-images.githubusercontent.com/5276727/74893602-6e100e80-5395-11ea-9de5-0178fa3b008c.png
# No GitHub in icon for 'Bad Words Filter': https://cdn-icons-png.flaticon.com/512/5058/5058251.png
# Success: Baked Lipsync
# Success: balldrop.
# Success: Balloon_Text
# Success: Bangla Unicode to ANSI Converter
# Success: Base32768 encoder/decoder
# No GitHub in icon for 'Base64 Manager': https://i.ibb.co/rkZhWh1/icon.png
# No GitHub in icon for 'BashInGodot': https://godot-bash.sciencesky.fr/icon.png
# No GitHub in icon for 'Basic 3d Starter': https://user-images.githubusercontent.com/110934679/273702389-4576e4aa-dba4-4503-acfc-042c42e96e79.png
# No GitHub in icon for 'Basic Dynamic Pool': https://godotengine.org/assets/logo_dark.svg
# Success: Basic FPS Player
# Success: Basic Menu
# Success: Basic physics based object pickup
# Success: Basic Platformer
# Success: Basic Settings Menu
# Success: Basic Shaders
# Success: Basic Top Down Shooter
# Success: Basic Water Material
# Success: Batch .scn to .tscn
# No GitHub in icon for 'Batch collisions': https://i.imgur.com/SCZS1Xo.png
# No GitHub in icon for 'Bayer Dithering Shader': https://files.catbox.moe/2aaqsm.png
# Success: Bazier-curve.Godot_template
# Success: BBCodeEdit (for script editor)
# Success: BDC - Ballistic Deflection Calculator
# Success: beatplayer
# Success: Beautify Code on Save
# Success: Beehave - behavior tree AI for Godot Engine
# Success: Behavior Tree for Groups
# Success: Behaviour Spawner
# Success: BehaviourToolkit - StateMachine and Behaviour Tree for AI & NPCs
# No GitHub in icon for 'Beholder': https://gitlab.com/mburkard/beholder-g4/-/raw/main/icon.png?ref_type=heads
# No GitHub in icon for 'Beholder': https://gitlab.com/mburkard/beholder/-/raw/master/icon.png
# Success: Better 3D Path (C#)
# Success: Better Animated Texture
# Success: Better Drag-and-drop Sprite
# No GitHub in icon for 'Better Processes': https://gitlab.com/greenfox/better-process-manager/-/raw/main/icon.png
# Success: Better Random Number Generator
# Success: Better Tab Container
# No GitHub in icon for 'Better Terrain': https://user-images.githubusercontent.com/33663279/228499461-f0620b45-3d9e-4e2d-a3d0-8b69f7f7c24f.png
# No GitHub in icon for 'Better Terrain 4.2': https://user-images.githubusercontent.com/33663279/228499461-f0620b45-3d9e-4e2d-a3d0-8b69f7f7c24f.png
# No GitHub in icon for 'Better Terrain in Gaea': https://user-images.githubusercontent.com/33663279/228499461-f0620b45-3d9e-4e2d-a3d0-8b69f7f7c24f.png
# Success: Better Texture Array
# Success: Better Third Person Camera 3D
# No GitHub in icon for 'Better UI': https://chrisroe.github.io/hosted/godoticon.png
# Success: Better Vircle
# Success: BetterTable
# Success: BFMachine
# Success: BHop3D
# Success: BiDi and Font Features Demo
# Success: Big number class
# No GitHub in icon for 'Bilinear Filtered Scaling': https://gitlab.com/ntfwc/godot-bilinear-filtered-scaling/raw/0150f0152ec17b8b778cd5b6de2366d598e9f520/icon.png
# Success: BiliveObserver
# Success: Binary Game
# Success: Binary Radian
# Success: Bindora : a reactive data binding library
# No GitHub in icon for 'BiomeGenerator': https://user-images.githubusercontent.com/33598732/257489249-55d8e740-05ba-4ef4-bec9-829d7fdf0006.png
# Success: Bit Flags Editor
# Success: Bit of reactivity
# Success: BitMap editor
# Success: Bitmap font creator
# Success: Bitmap Font Creator
# Success: Bitmap Font Importer
# Success: Bitmap font maker
# Success: BitMap Fonts Atlas Replacer
# Success: BitmapFontCutter
# Success: BitmapFontCutterPlus
# Success: BitmapTextureFont
# Success: BitText
# Success: Blackhole effect
# Success: Blank Starter Template (3D)
# Success: Blankit
# Success: BlastBullets2D
# Success: BlastBullets2D v2.0.0 | For Godot 4.4.1+
# Success: Blender 3D Shortcuts
# Success: Blender Helper
# Success: Blender Importer
# Success: Blender Spritesheet Import Plugin
# Success: Blender-Godot Pipeline
# Success: BlenderCam
# No GitHub in icon for 'Blendot Path Exporter': https://i.imgur.com/OO453tI.png
# Success: BlipKit
# Success: Block Coding
# Scraping page 1...
# Found 500 assets on page 1
# Success: Block Coding Demos
# Success: Block-based 3D Procedural Map Generation Demo
# Success: blockchain_sdk
# Success: Blocking dialog boxes
# Success: BloodyLogger
# Success: BMOD: Create sound effects like with FMOD but B-tier
# Success: Bob
# No GitHub in icon for 'Boids (2D/3D flocking)': https://git.gaze.systems/dusk/godot_boids/raw/branch/main/resources/flock_2d.svg
# No GitHub in icon for 'Bokeh Particle Depth of Field': https://i.imgur.com/N7g9PBK.png
# No GitHub in icon for 'BoneGizmo': https://i.imgur.com/WpPa68D.png
# Success: Bonnie Dialogue Manager for 4.0
# Success: Bonnie Dialogue Manager for 4.1
# Success: Bonnie Dialogue Manager for 4.2
# Success: Bordered Simplex Noise
# Success: BorderedPolygon2D
# Success: Borderless Display
# Success: Borderless Display
# Success: Bottled TileMap : Ultimate Godot TileMap plugin (3.5)
# No GitHub in icon for 'Bottom Panel Creator': https://upload.wikimedia.org/wikipedia/commons/thumb/6/6a/Godot_icon.svg/600px-Godot_icon.svg.png
# Success: Bottom Panel Shortcuts
# Success: Boujie Water Shader
# Success: BoxAspectContainer
# Success: BoxConstructor
# Success: BPB Placement
# Success: Branch
# Success: bs58
# No GitHub in icon for 'BSON for Godot': https://git.colormatic.org/ColormaticStudios/godot-bson/raw/branch/main/icon.svg
# Success: BTransition
# Success: BUFFer - Generic purpose buffer
# Success: BugReporter
# Success: Building Culler
# Success: Bullet Shower Demo
# Success: BulletUpHell - Bullethell plugin (big bug fixed!)
# Success: BulletUpHell - Bullethell plugin (big bug fixed!)
# No GitHub in icon for 'BumpToNormal': https://gitlab.com/Jitnaught/bumptonormal/-/raw/master/addons/bumptonormal/icon.png
# No GitHub in icon for 'BurstParticles2D': https://i.imgur.com/B3ls6zc.png
# Success: BurtTree
# Success: Butler Export Plugin
# Success: ByteKruncher
# No GitHub in icon for 'C# 3D Platform + State Machine - Demo': http://www.mortalkombatwarehouse.com/mkd/subzero.png
# No GitHub in icon for 'C# Coroutines like Unity': https://i.ibb.co/QP3pwrX/coroutines-Icon.png
# Success: C# GDExtension Bindgen
# Success: C# OnReady Plugin
# Success: C# Script Picker
# Success: Cables
# Success: CADLikeOrbit_Camera
# Success: Calculator GUI
# Success: CalculusVisualizations
# No GitHub in icon for 'Calendar Button': https://i.imgur.com/94wCTak.png
# Success: Calendar Library
# Success: Camera Control Script
# Success: Camera Flow
# No GitHub in icon for 'Camera Monitor': https://user-images.githubusercontent.com/12966814/145563174-6ac6e00f-11de-4cb7-8c2c-9e295875340e.png
# Success: Camera Shake 3D
# Success: Camera Shifter
# Success: Camera transition (2D & 3D)
# Success: CameraManager2D
# Success: CameraPositioner
# Success: CameraRegion2D
# Success: Candy Wrapper - Looping Arcade Platformer Game
# Success: Car Demo
# Success: CarbonGD
# Success: Card Framework
# Success: Card Game Framework
# Success: Card3D
# Success: Cardboard VR Camera 3D
# Success: CardEngine - Card games framework
# Success: cargo-godot
# Success: Casual Run Arcade Project - Endless Runner Base Game
# Success: Caution Tape Shader
# Success: Cel / Toon Shader
# Success: Celestial Bodies
# Success: Cellular Automata Studio
# Success: ChangeScenesHelper
# Success: Channel packer
# Success: Character Control
# Success: Character Controller
# Success: Character Controller C#
# No GitHub in icon for 'Character generator importer tool': https://gitlab.com/godot-tools/character-creator-tool-importer/-/raw/main/icon.png
# Success: Character generator importer tool
# Success: Character Input Controller
# No GitHub in icon for 'Character Outline': https://bitbucket.org/arlez80/character-outline/downloads/icon.PNG
# No GitHub in icon for 'CharacterCamera3D': https://i.stack.imgur.com/o775L.png
# Success: chart-gd
# Success: chart-gd
# Success: ChartGraph
# Success: CheatCoder
# Success: Cheatsheet
# Success: Checklist
# No GitHub in icon for 'Chess': https://git.crowdedgames.group/CatAClock/Chess/raw/branch/main/Chess.png
# Success: Chey's Background Addon - Editor BG
# Success: Chief Mints - Achievements for Godot 3
# Success: Children Dock
# Success: Chroma Key Shader
# No GitHub in icon for 'Chunk Manager': https://www.spigotmc.org/data/resource_icons/118/118205.jpg
# Success: Chunking and LOD
# Success: Cider Wiki
# No GitHub in icon for 'CineCam': https://i.imgur.com/S7Km3OC.png
# Success: CineCam: A Camera GDExtension
# Success: Cinematic Camera 2D
# Success: Cinematic Camera 2D
# Success: Cinematic Camera Shake
# Success: Circular Container
# Success: Class Name Hider
# No GitHub in icon for 'Classic 2D Shooter': https://kidscancode.org/godot_recipes/4.x/img/ship.png
# Success: Claude 3.5 Sonnet Chat API
# Success: Clerk.dev Authentication
# Success: Click Through Transparent Window C#
# Success: Clicker Game Template
# No GitHub in icon for 'Clientside Predictor (3D clientside prediction)': https://i.ibb.co/cbd8hTx/335056.png
# Success: Climb'n'glide character controller
# No GitHub in icon for 'Clipboard Panel': https://i.imgur.com/YiDjG5S.png
# Success: Clone
# No GitHub in icon for 'Cloud shader': https://bitbucket.org/arlez80/cloud-shader/downloads/icon.png
# Success: Clyde Dialogue
# Success: Clyde Dialogue
# Success: CocosLike Godot 4 Actions
# Success: Code Collapse Toggler
# Success: Code Editor Background
# Success: Code Editor Background 4.0
# Success: Code Jump
# Success: Code Snapshot
# Success: Code Snippets
# Success: Code Time
# Success: CodeCapture - plugin to capture screenshots of your code snippets
# Success: Codecks User Reports
# No GitHub in icon for 'CodeScope': https://codescope.app/cs/xcs_icon.png.pagespeed.ic.w0FtDgcKEP.png
# No GitHub in icon for 'CodeSimp': https://user-images.githubusercontent.com/13801315/152969383-af20b8df-9d00-4296-bbb5-012de8371530.png
# Success: Cog: UI Scripts
# No GitHub in icon for 'COGITO : Immersive Sim Template': https://static.wixstatic.com/media/321009_1a7dcd1c59b247cebc0abd175b8688d5~mv2.png
# Success: Cognite
# Success: Coins Generator 3D
# Success: Collapse Folders
# Success: CollapsibleContainer
# Success: Collision Groups 3D
# Success: Collision Path2D
# Success: Collision scanner
# Success: CollisionPolygonShape
# No GitHub in icon for 'Color Calibrator': https://gitlab.com/MrMinimal/godot-color-calibrator/-/raw/master/icon.png
# Success: Color Dither
# Success: Color Eater - Mobile Demo
# Success: Color Matrix System
# Success: Color Palette Manager
# Success: Color Palette Manager
# Success: Color Picker Text Button
# Success: Color Preview
# Success: Color-Keyed BMP Importer
# Success: ColorBlind Accesibility Tool
# Success: Colorblindness
# Success: ColPicker
# Success: Combat Area 2D
# Success: Combat Area 2D
# Success: Combat Collider
# No GitHub in icon for 'Comedot Ultimate Template [4.4]': https://i.imgur.com/UJnNERn.png
# No GitHub in icon for 'Comedot Ultimate Template [4.5]': https://i.imgur.com/UJnNERn.png
# Success: Command Export Plugin
# Success: Command Palette
# Success: Command Terminal
# Success: Command Tokenizer (beta)
# No GitHub in icon for 'Compass': https://gitlab.com/gamedevone1/godot-asset-library-tools/-/raw/5516600db04b68e565f621400670fc323eee4c55/addons/Compass/compass.png
# Success: Complex Numbers
# Success: Complex Shape Creation
# Success: Component Based Car Destruction System
# Success: Componentable
# Success: Composer
# Success: Composition
# Success: Composition Components
# Success: CompossedTextureBuilder
# Success: Compute Shader Heightmap Demo
# Success: Compute Shader Helper
# Success: Compute Shader Plus
# Success: Compute Shader Studio
# Success: Compute Texture Demo
# Success: Compute Worker
# Success: ComputeShadersExperiment
# Success: Concrete Material (HD)
# Success: Concrete Material (LD)
# Success: Config and Save Demo
# Success: Config Table Manager
# Success: Confirma Unit Testing (C#)
# Success: Connected
# Success: Console
# Success: Console and Textchat Node
# Success: ConsoleGD
# Success: Const Generator
# Success: Constructive Solid Geometry (CSG) Demo
# No GitHub in icon for 'Content Pack Manager': https://eumario.dev/images/content-pack-manager.png
# No GitHub in icon for 'Control / Input / Action re-binding': https://godotengine.org/themes/godotengine/assets/og_image.png
# Success: Control Gallery
# Success: Control Gallery Demo
# Success: Control Node Window
# Success: Control++
# Success: Control3D
# Success: Control3D
# Success: Control3D Nodes
# Success: ControlCamera3D
# No GitHub in icon for 'Controller': https://imgur.com/RPr2nm9.png
# Success: Controller Icons
# Success: Controller Icons
# Success: Controller Icons (Legacy - v2)
# Success: Controller Input Viewer
# Success: Controller use Template
# Success: Controllers Icons Local Multiplayer
# Success: ControlsRemap resource
# Success: ControlsRemap resource
# Success: Convention Cheat Sheet
# Success: ConvexConeShape3D
# Success: ConvoQuest Framework
# Success: Conway's Game Of Life Demo
# Success: Conzole advanced logger
# Success: CookieHTTPRequest
# Success: Copilot/CodeCompletion (Gemini, LMStudio, Ollama)
# Success: CopperDC - An in-game debug console
# Success: Copy Context AI | Vibe Coding Godot
# Success: Copy Correct Shader Parameters
# Success: Copy Files On Export
# Success: Copy Transform
# Success: cordot
# No GitHub in icon for 'CORE Framework': https://git.staropensource.de/StarOpenSource/CORE/raw/branch/stable/dist/core.png
# Success: Correct Conventional Naming
# Success: Cosineful Palettes [C#]
# Success: CounterTimer Node
# Success: Coyote Jump
# Success: cpolygon (Knife, Cut, Merge)
# Success: Cracked Mud Material
# Success: Creatures 3 Background Importer
# Success: Credits Screen
# Success: Creepy Eyes Looking at Cursor
# No GitHub in icon for 'CReverter (Composite Reverter aka Undo/Redo)': https://codeberg.org/svetogam/creverter/raw/branch/main/icon.png
# Success: Criss-Cross
# Success: Cross Origin Isolation Service Worker
# Success: CRT Lottes shader
# No GitHub in icon for 'CRT Monitor Shader': https://bitbucket.org/arlez80/godot-crt/downloads/icon.PNG
# Success: CRT-Geom shader
# Success: CRWTILES - 3D Tile/Map Tools
# Success: Crypth of the Necrodancer mechanics
# Success: Crypto UUID v4
# No GitHub in icon for 'CSConnector (Contextual Signal/Setup Connector)': https://codeberg.org/svetogam/csconnector/raw/commit/2d9a7797b275563cb38b3cbd7a5940898616fdc0/icon.png
# Success: CSG Converter
# Success: CSG Export (.OBJ Mesh)
# Success: CSG Exporter
# Success: CSG Terrain
# Success: CSG Toolkit - Enhance Your Blockout Speed
# No GitHub in icon for 'CSGMesher': https://codeberg.org/dbat/godot-plugin-csg-tools/media/branch/main/addons/csg_mesher/CSGMesher_icon.svg
# Success: CSGStairs (Godot 3)
# No GitHub in icon for 'CSGToMesh': https://gitlab.com/Jitnaught/csgtomesh/-/raw/master/addons/csgtomesh/icon.png
# No GitHub in icon for 'Csharp Console': https://user-images.githubusercontent.com/58595683/268513889-d17ee243-80b2-47dc-9acf-477ce4562e2c.png
# Success: CSharpObjectPool
# No GitHub in icon for 'CSLocator (Contextual Service Locator)': https://codeberg.org/svetogam/cslocator/raw/commit/a793a01c064d99ef74cea62df01e5a4569627c1f/icon.png
# Success: CSV - Localization template
# Success: Csv Animations Builder
# Success: CSV Data Importer
# Success: CSV Data Importer
# Success: CSV Object Importer
# Success: CSV to Dictionary Parser
# Success: CSV-Typed-Data-Importer
# Success: Ctrl+V Clipboard Image
# Success: Cube_Characters
# Success: Cubic Bezier Controls
# Success: Cubiix Project Template Addon
# Success: Cupcakes Framework
# Success: Cupcakes Framework
# Success: Cursor Shape Previewer
# No GitHub in icon for 'Curvature Shader': https://i.imgur.com/HudNebw.png
# No GitHub in icon for 'Curve Terrain': https://upload.wikimedia.org/wikipedia/commons/thumb/6/6a/Godot_icon.svg/2048px-Godot_icon.svg.png
# Success: CurvedArrow2D
# Success: CurveMesh3D
# Success: CurvePDFtoCDF
# Success: Custom "Play Scene" button
# Success: Custom BBCode Tags for RichTextLabel Demo (With Tutorial Video)
# Success: Custom Distraction Free Mode
# Success: Custom Gradient Texture
# Success: Custom HTML Loader
# Success: Custom Image Equalizer
# Success: Custom Observer Pattern for C#
# Success: Custom Play Buttons
# Success: Custom Project Runner
# Success: Custom Project Runner
# No GitHub in icon for 'Custom Theme Overrides': https://godotengine.org/assets/press/icon_color.png
# Success: Customizable Crosshair
# Success: Customizable Crosshair Lite
# Success: Customizable Packed Scene
# Success: CustomPathGizmo
# Success: Cute 3D Multiplayer Third Person Shooter
# Success: Cute Pong
# Success: Cutscener
# Success: CyberAsset+
# No GitHub in icon for 'Cybs Gameunit': https://gitlab.com/Cyberrebell/cybs-gameunit/-/raw/master/icon.png
# Success: D-Bus Nodes
# No GitHub in icon for 'DaemonSide': https://gitlab.com/aviangames/DaemonSide/-/raw/main/DaemonSide_Icon.png
# Success: Daicon
# Success: Damped Oscillator
# No GitHub in icon for 'Dance Game Demo': https://i.hizliresim.com/7lc57o.png
# Success: Dark Mode Signal
# No GitHub in icon for 'Dark Peace's BulletUpHell: BulletHell Engine (Godot 4)': https://img.itch.zone/aW1hZ2UvMTM3Njk0MS8xNTY3Njc3MS5wbmc=/250x600/fMwNlg.png
# No GitHub in icon for 'Dark Peace's BulletUpHell: BulletHell Engine (Godot 4.2)': https://img.itch.zone/aW1hZ2UvMTM3Njk0MS8xNTY3Njc3MS5wbmc=/250x600/fMwNlg.png
# No GitHub in icon for 'Dark Peace's BulletUpHell: BulletHell Engine (Godot4.1)': https://img.itch.zone/aW1hZ2UvMTM3Njk0MS8xNTY3Njc3MS5wbmc=/250x600/fMwNlg.png
# Success: Dark Peace's LaserBeam Node
# Success: DarkPeace's SuperSpector : Improve the Godot inspector
# No GitHub in icon for 'Data Folder Deleter': https://i.ibb.co/fQ8wgdQ/pngwing-com.png
# No GitHub in icon for 'Data Persistence - Easy Text File Saving & Reloading': https://robert-deforrest-reynolds.github.io/pineapple.png
# Success: Data to Image Coverter
# Success: Database
# Success: Dataclasses
# Success: Datalogue
# Success: DataSourceManager
# Success: DataTable
# Success: DataTable [GDScript]
# Success: Date Time
# Success: Date Time (Godot 4)
# No GitHub in icon for 'Date Time Addon': https://i.imgur.com/S7bFScK.png
# Success: DateChecker
# No GitHub in icon for 'DatePicker': https://i.imgur.com/UQ6HFFf.png
# Success: DatePickerButton
# Success: DateTime
# Success: DateTimePicker Plugin
# Success: Dear ImGui for Godot
# Success: Debanding material shader
# Success: Debug draw
# Success: Debug Draw 3D
# Success: Debug Draw 3D (4.2.2+)
# Success: Debug Draw 3D (C#)
# Success: Debug draw c#
# Success: Debug Interface Components
# Success: Debug Menu - Display in-game FPS/performance/hardware metrics
# Success: Debug Menu Demo
# Success: Debug Overlay
# Success: Debug Port Incrementer
# Success: Debug Start Screen
# Success: Debugger Launcher
# No GitHub in icon for 'DebugGUI Graph': https://user-images.githubusercontent.com/22682921/257229727-f915345c-3e21-4743-bb06-a64e0e560097.png
# No GitHub in icon for 'DecalCo': https://user-images.githubusercontent.com/54776415/86528906-c8c18700-beac-11ea-97f3-3ea422442e1a.png
# Success: Decals Demo
# Success: Decembrist Plugin for C#
# Success: Dedicated Server and Client Project
# No GitHub in icon for 'Deep Debug': https://user-images.githubusercontent.com/45795134/187693402-e1c70b0f-789e-44c0-87fb-b04ad013bb40.jpg
# Success: DeformableMesh
# Success: Delaunator GDScript
# No GitHub in icon for 'Delta Rollback': https://gitlab.com/BimDav/delta-rollback/-/raw/master/icon.png?ref_type=heads
# No GitHub in icon for 'Demo Platformer Game': https://indielibre.com/wp-content/uploads/2019/05/DeepinScreenshot_Seleccionar-%C3%A1rea_20190513145435-700x384.png
# Success: Demo-Project-BlastBullets2D
# Success: Depth Fog Screen Space PostFX
# Success: Desktop Pet
# Success: DestroHook
# Success: Destronoi
# Success: DestructiblePolygon2D
# Success: DestructiblePolygon2D
# Success: Destructibles CSharp
# Success: Destruction
# Success: Destruction
# Success: Dev Blocks
# Success: Dev Icons
# Success: Developer Console
# Success: Developer Console for Godot .NET 4
# Success: Development Time Tracker
# Success: DI: Dependency Injector
# Success: Diagnostic List
# Success: Dialegume
# Success: Dialink
# No GitHub in icon for 'Dialog and Quest System': https://i.imgur.com/q9DgIAj.png
# Success: Dialog Box
# Success: Dialog Graph Plugin
# Success: Dialog Tree Tool
# Success: Dialogbox
# Success: Dialogic - Dialogue editor
# Success: DialogSharp
# Success: Dialogue Editor
# Success: Dialogue Editor (G4)
# Success: Dialogue Engine
# Success: Dialogue Label
# Success: Dialogue Manager
# Success: Dialogue Manager 2
# Success: Dialogue Manager 3
# Success: Dialogue Nodes
# Success: Dialogue Nodes
# Success: Dialogue Nodes
# Success: Dialogue Trees C#
# Success: DialogueQuest
# Success: DialogueQuestTester
# Success: DialogueTreeEditor
# Success: Diamond Plated Aluminum Material
# Success: Dice Syntax Godot 3
# Success: Dice Syntax Godot4
# Success: Dicebag
# Success: Dicebag
# Success: DiceEngine - Simple DiceRoller
# Success: Dice_Roll
# Success: Dictionary Inspector
# Success: Dictionary Inspector
# Success: Diff margin
# No GitHub in icon for 'DigiVGamepad': https://gitlab.com/DigiGodotPlugins/DigiVGamepad/raw/master/icon.png
# No GitHub in icon for 'DigiVR': https://gitlab.com/DigiGodotPlugins/DigiVR/raw/master/icon.png
# Success: DIISIS
# Success: Dijkstra Map Pathfinding
# Success: Direct Dictionary Edit
# Success: Directory Watcher
# Success: Directory Watcher
# Success: Disable Nodes
# Success: Discord Game SDK
# No GitHub in icon for 'Discord RPC': https://ik.imagekit.io/godette/discord-rpc.png
# Success: Discord RPC Python wrapper for Godot
# Success: Discord Social SDK
# No GitHub in icon for 'Discord.gd': https://cdn.discordapp.com/attachments/360062738615107605/871011659471286282/icon.png
# Success: Discrete Swipe Screen Area Plugin
# Success: Dispatch Queue
# Success: Dispatch Queue (Godot 3)
# Success: Doc Export Platform
# Success: Dock Shader Editor
# Success: Dock Slot Expander
# Success: Dockable Container
# No GitHub in icon for 'Dockable Output': https://bitbucket-assetroot.s3.amazonaws.com/c/photos/2020/Jan/27/2925161499-1-dockableoutput-logo_avatar.png
# Success: Docs Checklist
# Success: Dodge the Creeps Assets (Unfinished)
# Success: Dodge the Creeps Demo
# Success: Dodge_The_Creeps_Cpp
# Success: DokiVN - Visual Novel Lib
# No GitHub in icon for 'Dolly Camera Controller': https://gitlab.com/thespoonfulone/godot-dolly-zoom/-/raw/main/addons/dolly-camera-controller/assets/icons/DollyIcon.png
# No GitHub in icon for 'dolly-gd': https://www.pngitem.com/pimgs/m/136-1360011_transparent-camera-emoji-png-emoji-camera-icon-png.png
# Success: Donut Collision Polygon 2D
# No GitHub in icon for 'Doodly Jumping': https://gitlab.com/mnilles/doodly-jumping/raw/4c861498f642c8efcf16fc4b67efcce082809f33/enemies/img/small_blue.png
# Success: Doom Clone
# Success: DotnetQuestSystem
# Success: dotUtils
# Success: Double_HSlider
# No GitHub in icon for 'Draftsman': https://gitlab.com/LuckyBastard/draftsman/-/raw/master/icon.png
# Success: drag and drop
# Success: Drag And Drop
# Success: Drag and Drop (GUI) Demo
# Success: Drag and Drop 3D
# Success: Drag and drop controller
# Success: Drag and Drop Item NET
# Success: Drag Control Node
# Success: Drag Polygon2D
# Success: Drag&Drop Nodes to Scene
# Success: Drag-and-drop Sprite
# Success: DraggableSprite2D
# Success: Dragonfruit
# No GitHub in icon for 'Draw Anywhere': https://cdn.discordapp.com/attachments/360062738615107605/932968729208315955/plugin_icon.png
# Success: Draw3D
# Success: Draw3D
# Success: DrawnArea2D
# No GitHub in icon for 'DRPG Framework': https://i.imgur.com/hf0FJ05.png
# No GitHub in icon for 'DSCN Plugin': https://i.imgur.com/o2ZojSR.png
# No GitHub in icon for 'DTDA ML - Machine Learning models': https://www.dtda.fr/images/favicon-144x144.png
# Success: DTL (Dungeon Template Library)
# No GitHub in icon for 'dual quaternion skinning demo': https://bitbucket.org/bigbiglobster/dqs_demo/raw/2679c0e59fb1f008b636197ba8a1e743b3d4dc53/dqsicon.png
# No GitHub in icon for 'DualEditor': https://i.ibb.co/tDGf6cd/2D-3D-5.png
# Success: Duelyst Animated Sprites
# Success: Dungeon Generator
# Success: DungeonCrawler3D
# Success: DV's Behavior Tree
# Success: DwarfImpulse - A Camera Shake Plugin for C#
# Success: DwTexture
# No GitHub in icon for 'Dynamic Camera 2D': https://img.icons8.com/arcade/512/compact-camera.png
# Success: Dynamic Camera System
# Success: Dynamic Catenary
# Success: Dynamic Connection: Remove Signal Connection Boilerplate
# Success: Dynamic Crosshair Shader
# Success: Dynamic Day Night Cycles
# Success: Dynamic Day-night sky
# Success: Dynamic Event Manager
# No GitHub in icon for 'Dynamic Gravity Kinematic Character': https://i.ytimg.com/vi/6nOgGUO0syA/hqdefault.jpg
# Success: Dynamic Inventory System
# No GitHub in icon for 'Dynamic Split Screen Demo': https://user-images.githubusercontent.com/5276727/74895233-cd701d80-5399-11ea-9215-ae7136b5a665.png
# Success: Dynamic Split Screen Demo
# Success: Dynamic TileMap Layers Demo
# No GitHub in icon for 'DynamicWater2D': https://git.gaze.systems/dusk/dynamic_water_2d/raw/branch/main/resources/icon.png
# Success: Easing Functions
# Success: Easy Animated 2D Moving Platforms
# Success: Easy Aspect Ratio
# Success: Easy C++
# No GitHub in icon for 'Easy Charts': https://user-images.githubusercontent.com/45271396/215348215-02d6a6d2-24f3-4343-91f9-cc168399c8f6.svg
# ...
# Success: Todot
# Success: Todot
# No GitHub in icon for 'Toggle Code Generation': https://user-images.githubusercontent.com/12966814/87144518-70d6b600-c2da-11ea-811d-ed6faaac31b5.png
# Success: Toggle External Editor
# Success: Toki Pona RichTextLabel
# Success: Tool Button
# Success: Tool Button
# Success: Tooltips Pro
# Success: Top Down Camera
# Success: Top Down Twin Stick Shooter
# Success: Top-down Action RPG Template
# Success: Topdown Pixelart Starter Project
# No GitHub in icon for 'TortoiseHg Mercurial Integration': https://bytebucket.org/lkokemohr/godot_tortoisehg_integration/raw/c9b817e1af026a6efa0d43587da45964ada0b29a/plugin_icon.png
# Success: TotalJSON
# Success: Touch JoyPad (Gamepad)
# Success: Touch Screen Joystick
# Success: Tower Defense Game Template
# No GitHub in icon for 'Tracer': https://terraria.wiki.gg/images/2/2e/Void_Bag.png
# No GitHub in icon for 'Tracery': https://tracery.io/images/tracery-logo6.png
# Success: Trackball Camera
# Success: Trackball Camera
# Success: Trackball Camera
# Success: Tracking Transparency
# Success: Trail2D
# No GitHub in icon for 'TrailMesh': https://user-images.githubusercontent.com/567207/268916534-e4db668e-1a7f-43e4-8489-b978dfe04f4c.png
# Success: TrailRenderer
# Success: Trajectory Lib
# Success: Transform Container
# Success: Transform Transfer for Godot
# Success: Transform Variance
# Success: Transit
# No GitHub in icon for 'Transition Type Demo': https://i.imgur.com/V91Cs7L.png
# No GitHub in icon for 'Translation editor': https://zylannprods.fr/images/godot/plugins/translation_editor/assetlib_icon.png
# Success: Translation Preview
# Success: Translations From JSON (Godot 3.x)
# Success: Translations From JSON (Godot 4.x)
# Success: Transparency Dither
# Success: Tree3D
# Success: Trello Reporting Tool
# No GitHub in icon for 'TrenchBroom Loader': https://git.mrag.nl/nimble/tbloader-addonlib/raw/branch/master/addons/tbloader/icon.png
# Success: Triangular Grid Demo (With Video)
# Success: Truck Town Demo
# Success: Turgy's Behavior Tree Plugin
# Success: Turn Based Combat (3D)
# Success: Turn Videos into Games - With Example YT Video
# Success: Turnity
# Success: Turret Madness
# Success: Turtle
# Success: Tween Demo
# Success: Tween Interpolation Demo
# Success: Tween Suite
# Success: TweenAnimator
# No GitHub in icon for 'Twin Stick 2D Shoot Em Up': https://git.crowdedgames.group/CatAClock/Twin-Stick-2D-Shoot-Em-Up/raw/branch/main/demo/Non-Godot/Icon.png
# Success: Twine story importer
# Success: Twitch Chat Manager
# Success: Twitcher
# Success: TwitchIRCClient
# Success: TwoVoip
# No GitHub in icon for 'Typed Dictionary NET': https://i.imgur.com/78BO2vB.png
# Success: TypingGameEngine
# Success: UberPath2D
# Success: UDIM Shader Material
# Success: UI Design Tool
# Success: Ui Juicer
# No GitHub in icon for 'UI-Expander': https://user-images.githubusercontent.com/6388730/283870573-8333f31b-70e7-418c-b1c2-3f1ba835f2a6.png
# Success: UID Explorer Plugin
# Success: Ultimate Character Controller (UCharacterBody3D)
# Success: Ultimate Crosshairs
# Success: Ultimate Platformer Controller 2D
# Success: Ultimate Retro Shader Collection
# Success: Undo / Redo
# Success: Unicode Normalizer
# Success: Unidot Importer - .unitypackage Asset Translator
# No GitHub in icon for 'UniParticles3D': https://www.yarncatgames.com/uniparticles3d/icon.png
# Success: Unique ID Node
# No GitHub in icon for 'unirest gdscript': https://i.imgur.com/Z3b1bn7.png
# Success: UniTask
# Success: Universal Fade
# Success: Universal Fade
# Success: Universal Godot Utils – Debugging, Encryption & More
# Success: Universal Mod Manager
# No GitHub in icon for 'Universal Save/Load System': https://stupidratstudio.github.io/thoth/icon.png
# Success: Unofficial LaunchDarkly client-side SDK
# Success: Unreal Collision Importer
# Success: Untrue Organization Classes
# Success: Unused MD5 File Cleaner
# No GitHub in icon for 'Useful Shader Nodes for Godot 4': https://i.imgur.com/QOBzeLd.png
# No GitHub in icon for 'usefulScripts': https://gitlab.com/pointerstudio/kabk/godot/usefulScripts/-/raw/main/gdignore/icon.jpg
# Success: User Input WhiteList
# Success: Utility AI
# Success: Utility AI (GDExtension)
# Success: Utility AI C#
# Success: uuid
# Success: UUID v5 Generator
# Success: UV Inspector
# Success: UV Tools
# Success: Value Track to Bezier Track Converter
# Success: Values With Modifiers
# Success: Vaporwave Sky
# Success: VarEdit - Variant File Inspector
# Success: VarGen
# Success: Variable Rate Shading (VRS) Demo
# Success: VarTree
# Success: VCamera
# Success: VCS Export Platform
# Success: Vector Resource
# Success: Vector Shape Nodes
# Success: Vector2 Array Resource Editor
# Success: VectorizeImage
# No GitHub in icon for 'Vehicle Controller 2D': https://i.imgur.com/CYRITDe.png
# Success: Verlet Rope .NET (Physics Ropes)
# Success: Versatile Atlas Texture
# Success: Versatile Mobile Joystick
# Success: Version
# Success: VersionCheck
# Success: Vertere.gd
# Success: Vertex Animation Demo
# Success: Vertex Color Import Swapper
# Success: Very Simple Twitch
# Success: vest
# Success: Video Export Platform
# Success: Viewport Spy
# No GitHub in icon for 'vim-motion': https://creazilla-store.fra1.digitaloceanspaces.com/icons/3254509/vim-icon-md.png
# No GitHub in icon for 'Vircle': https://gitlab.com/Marty_Friedrich/vircle/-/raw/main/addons/vircle/icon.png
# No GitHub in icon for 'Virtual Analog': https://gitlab.com/mncrypticsilver/virtual-analog/raw/master/Example%20Project/Virtual%20Analog/vanalog_icon.PNG
# Success: Virtual Joystick
# Success: Virtual Joystick
# Success: Virtual Joystick
# Success: Virtual Joystick for Godot 3
# Success: Visibility Collision Shape Editor
# Success: Vision Cone 2D
# Success: VisionCone3D
# No GitHub in icon for 'Visual Behavior Tree': https://user-images.githubusercontent.com/13792627/93459566-78d35780-f914-11ea-9514-6f403f1e13c1.png
# Success: Visual Grid
# Success: Visual Novel Template
# No GitHub in icon for 'Visual Script Circle Pop Demo': https://user-images.githubusercontent.com/5276727/35007810-3ecf4e3e-fb03-11e7-9f32-5849b45e7f66.png
# Success: Visual Script Editor Extention
# No GitHub in icon for 'Visual Script Multitouch View Demo': https://user-images.githubusercontent.com/5276727/35007815-3f821a1e-fb03-11e7-98d4-ac9c6e762ab8.png
# Success: Visual Scripting Custom Node Library
# Success: Visual Shader - Extras
# No GitHub in icon for 'Visual Shader Derive Z Node': https://i.imgur.com/3MO1uBg.jpeg
# No GitHub in icon for 'Visual Shader Height Blend Node': https://i.imgur.com/0yj4DBt.jpeg
# Success: Visual Shader Node Library
# No GitHub in icon for 'Visual Shader Normal Combine Node': https://i.imgur.com/npZKEir.jpeg
# No GitHub in icon for 'Visual Shader Normal Strength Node': https://i.imgur.com/9YgKvZ6.png
# No GitHub in icon for 'Visual Shader Parallax Mapping Node': https://i.imgur.com/93MOjEM.png
# No GitHub in icon for 'Visual Shader Pixel Normal World Node': https://i.imgur.com/wrN0krU.png
# No GitHub in icon for 'Visual Shader UV Manipulation Node': https://i.imgur.com/ziorC1y.jpeg
# No GitHub in icon for 'Visual Shader UV Nodes Pack': https://i.imgur.com/D3qmv4W.png
# No GitHub in icon for 'Visual Shader Vector Transform Node': https://i.imgur.com/2LVJyRJ.png
# Success: Visual Signals 3D
# Success: Visual State Machine
# Success: Visual Studio Debugger
# Success: VisualFSM
# Success: Visualize
# Success: VisualScript CustomNodes
# Success: VisualScriptNew
# Success: VisualShader IdMap
# Success: VisualShader-Extras-4.0
# Success: vkaParticleTool
# Success: VMFLib
# Success: VNDS-GodotPlugin
# Success: Voicechat Client
# Success: Voicechat Server
# No GitHub in icon for 'VOID': https://upload.wikimedia.org/wikipedia/commons/3/3d/RectangleRome.jpg
# Success: Volume Layered Shader
# Success: Volume Renderer
# No GitHub in icon for 'Volume Sliders (Singleton example)': https://i.imgur.com/vBZabOM.png
# No GitHub in icon for 'Volumetric Fog': https://i.imgur.com/h2pgqk2.png
# Success: Volumetric Fog Demo
# Success: Volumetric forest
# Success: Volumetrics Plugin
# Success: Voodoo Spritesheet Generator
# No GitHub in icon for 'VoronoiShatter - Procedurally fracture 3D meshes': https://i.postimg.cc/sxG3cGnW/voronoishatter.png
# Success: VostokMods Exporter
# Success: Vox Importer
# Success: Voxel
# Success: Voxel Destruction
# Success: Voxel Factory
# Success: Voxel Game Demo
# Success: Voxel Level Editor
# Success: Voxel Line
# Success: Voxel-Core
# Success: VoxelGenerator2D
# No GitHub in icon for 'VoxelOctree': https://www.braindead.bzh/files/2018-02/voxeloctree.png
# No GitHub in icon for 'Vpainter': https://i.postimg.cc/C54nGTPB/logo.png
# Success: VPainter - Paint vertex colors
# Success: VR Input Simulator
# Success: VR Mobile Camera
# Success: VR movement tracking
# Success: VR Physics Template
# No GitHub in icon for 'VR Tools': http://logmein-edu.ru/icon.png
# No GitHub in icon for 'VRM Importer and MToon Shader - Humanoid 3d Avatar Model Format': https://user-images.githubusercontent.com/39946030/120100280-d307f780-c0f4-11eb-8e3e-820a5a338974.png
# No GitHub in icon for 'VRM Importer for 3D Avatars and MToon Shader': https://user-images.githubusercontent.com/39946030/120100280-d307f780-c0f4-11eb-8e3e-820a5a338974.png
# Success: VTileMap
# No GitHub in icon for 'WAD Level Loader': https://s018.radikal.ru/i523/1711/e5/8d0b94c650d6t.jpg
# Success: Wario ware clone
# No GitHub in icon for 'WAT - Unit Testing Framework': https://i.imgur.com/ajEeZ7k.png
# No GitHub in icon for 'WAT Unit Testing Framework': https://i.imgur.com/DmmUryu.png
# No GitHub in icon for 'WAT Unit Testing Framework (For Godot Mono)': https://i.imgur.com/DmmUryu.png
# No GitHub in icon for 'Water shader': https://i.imgur.com/c8sUFNU.png
# Success: Water Temple Demo
# Success: Water2D Node
# Success: WaterMap
# Success: Waterways - River Generation
# Success: Waterways .NET (River Generation Tool)
# Success: Waterways Demo
# Success: WAV File Reader
# Success: Wave Function Collapse (WFC)
# Success: Wave Function Collapse (WFC) 2D/3D Generator
# Success: Wave function collapse 3D
# Success: Waving Tree
# Success: Way Point
# Success: Wayfarer Framework
# No GitHub in icon for 'Waypoint Map': https://gitlab.com/victoriasmedley94/godotwaypointmap/-/raw/master/icon.png
# Success: WBS Custom Windows Popups
# No GitHub in icon for 'WCSpawnPool': https://gitlab.com/worstconcept/wcspawnpool/-/raw/master/icon.png
# Success: WDebugger - A Git-friendly Debugger
# Success: Weather 2D
# No GitHub in icon for 'Weather System': https://codeberg.org/matiaslavik/GodotWeatherSystem/raw/branch/main/icon.png
# Success: Weather System 2D
# Success: Web Sprite
# Success: WebBus (yandex games, crazy games, poki)
# Success: WebRadio
# Success: WebRTC (SIPSorcery)
# No GitHub in icon for 'WebRTC and Nakama addon': https://gitlab.com/snopek-games/godot-nakama-webrtc/-/raw/master/icon.png
# No GitHub in icon for 'WebRTC Minimal Demo': https://user-images.githubusercontent.com/5276727/74893602-6e100e80-5395-11ea-9de5-0178fa3b008c.png
# Success: WebRTC plugin - Godot 3.5
# Success: WebRTC plugin - Godot 4.0
# Success: WebRTC plugin - Godot 4.1+
# No GitHub in icon for 'WebRTC Signaling Demo': https://user-images.githubusercontent.com/5276727/74893602-6e100e80-5395-11ea-9de5-0178fa3b008c.png
# Success: WebSocket
# Success: WebSocket Chat Demo
# No GitHub in icon for 'WebSocket Chat Demo': https://user-images.githubusercontent.com/5276727/74893602-6e100e80-5395-11ea-9de5-0178fa3b008c.png
# Success: Websocket Lobby Demo 4.0
# Success: WebSocket Minimal Demo
# No GitHub in icon for 'WebSocket Minimal Demo': https://user-images.githubusercontent.com/5276727/74893602-6e100e80-5395-11ea-9de5-0178fa3b008c.png
# No GitHub in icon for 'Websocket Multiplayer Demo': https://user-images.githubusercontent.com/5276727/74893602-6e100e80-5395-11ea-9de5-0178fa3b008c.png
# Success: WebSocket Multiplayer Demo
# No GitHub in icon for 'Weeping Angel Example': https://i.imgur.com/hTe0G5e.png
# Success: Weighted Choice
# Success: Widgets
# Success: widgets by code (gdscript)
# Success: WiggleBone
# Success: Wiggly Appendage (3.x)
# Success: Wiggly Appendage (4.x)
# Success: WindColors
# Success: Window Drag Demo
# No GitHub in icon for 'Window Management Demo': https://user-images.githubusercontent.com/5276727/35007781-39640804-fb03-11e7-8ee7-20a8bdfb4ebb.png
# Success: Window Management Demo
# Success: Window-B-Gone
# Success: Windows 95 UI Theme
# No GitHub in icon for 'WindowsV2': https://i.imgur.com/X7OrN7g.png
# No GitHub in icon for 'WIP 0.5 - Abstract State Machine Graphic (ASM)': https://cdn0.iconfinder.com/data/icons/seo-and-marketing-circular-2/90/56-512.png
# Success: Wire Connections
# Success: Wireframe Tool
# Success: Wiring
# Success: Without coding 2D Plateformer creator tool
# Success: Work Clock
# Success: Workday Timer
# Success: Worktime Stopwatch
# Success: World Editor
# No GitHub in icon for 'World of Alpheratz (Platformer Demo)': https://s1.ax1x.com/2023/05/03/p9YNVBV.png
# Success: Worldmap Builder - Skill Trees and Level Select Menus
# No GitHub in icon for 'WPGTK Theme': https://git.bellsworne.tech/Bellsworne/wpgtk-godot/raw/commit/d0973b625493092e2060eeb2c6bdd2eecc0c4788/icon.png
# Success: WRAP IT UP - Arcade Game
# Success: Wyvernbox - Inventory System
# Success: Wyvernbox - Inventory System
# Success: Wyvernshield - RPG Combat System Framework
# Success: Wyvernshield 2 - Character Upgrades for Combat Systems
# Success: xBRZ Pixel Filter
# No GitHub in icon for 'xBRZ Screen-Filter': https://godotengine.org/themes/godotengine/assets/og_image.png
# Success: xchange-scene
# Success: XDateTime
# No GitHub in icon for 'XMLReader': https://user-images.githubusercontent.com/63984796/201493635-d931c5fc-a7af-411f-9b78-767e5abfc030.png
# Success: XOXOFactory
# No GitHub in icon for 'XR Browser (XR Fragments compatible)': https://xrfragment.org/example/assets/logo.png
# Success: XR Character Body Centric Movement Demo
# Success: XR Debug Konsole Plugin
# Success: XR Input Simulator
# Success: XR Kit
# Success: XR Origin Centric Movement Demo
# No GitHub in icon for 'XRController Midi Player': https://gitlab.com/Cyberrebell/xr-controller-midi-player/-/raw/master/icon.png
# No GitHub in icon for 'XSM 2.0 - eXtended State Machine': https://gitlab.com/atnb/xsm/-/raw/master/icon.png
# No GitHub in icon for 'XSM 4': https://gitlab.com/atn_games/xsm2-g4/-/raw/main/icon.png
# No GitHub in icon for 'XSM: eXtended State Machine': https://gitlab.com/atnb/xsm/-/raw/master/icon.png
# No GitHub in icon for 'Xsolla SDK': https://i.ibb.co/FhLMcJh/3-AD500-A2-A3-DE-4-B71-A4-D4-24984-A9-C392-E.png
# No GitHub in icon for 'Yamms - Yet another MultiMesh Scatter': https://user-images.githubusercontent.com/127634166/224762100-c2d0dec8-5b2c-4125-aee1-1bf38f917e29.png
# Success: Yandex games SDK (non official)
# Success: Yandex games SDK 4.3+ (non official)
# Success: Yandex Metrica
# Success: Yandex-Games
# Success: YAT - Yet Another Terminal (C#)
# Success: YATI (Yet Another Tiled Importer) for Godot 4
# Success: Yet Another Behavior Tree
# Success: yet another godot game template
# Success: Yet Another Scene Manager
# Success: YH Mod Assistant
# Success: You Can Do It!
# No GitHub in icon for 'Your Buil': https://codeberg.org/svetogam/yourbuil/raw/commit/d853e252d6f734a1c061e06bd1288723207f7f14/icon.png
# No GitHub in icon for 'YouTube Sub Counter': https://user-images.githubusercontent.com/73933309/115988679-197caa80-a5bb-11eb-8771-93951453a157.png
# No GitHub in icon for 'YouTube's button effect': https://i.ibb.co/cQ8F7xq/icon.png
# No GitHub in icon for 'Zalance SDK': https://d2webpuomtrsrt.cloudfront.net/images/logos/logo-diamond-black-400x400.png
# Success: Zara Survival Engine (C#)
# Success: ZeroNet
# Success: zip::launcher
# Success: Zodot (Data Validation)
# No GitHub in icon for 'Zone Area2D Editor': https://user-images.githubusercontent.com/170968/48174285-afe38580-e307-11e8-8765-12589388371f.png
# Success: Zone Loading System
# No GitHub in icon for 'Zoomy': https://i.imgur.com/nZGa98M.png
# Success: ZzSprite Godot
# Success: [Archived] GDN-SQLite
# No GitHub in icon for '[DEPRECATED] Blockchain SDK by Enjin [DEPRECATED]': https://cdn.enjin.io/files/images/logo-mark-color.png
# Success: [Deprecated] Resonate — Audio Manager (Sound & Music)
# Success: [OLD] Post Process
# Scraping page 8...
# No more assets found on page 8. Stopping.
#
# === SAVING 3217 ASSETS WITH GITHUB ===
#
# === SAVING 758 ASSETS WITHOUT GITHUB ===
# Step 1 complete

# %% [markdown]
# Step 2 - Find GitHub URLS not found in Step 1, save to `github_from_viewfiles.csv` and `non_github_assets_final.csv`

# %%
def extract_github_from_viewfiles():
    github_from_viewfiles = []
    non_github_assets = []
    
    with open('assets_without_github.csv', 'r', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        assets = list(reader)
    
    print(f"Processing {len(assets)} assets without GitHub...")
    
    for i, asset in enumerate(assets):
        print(f"Processing {i+1}/{len(assets)}: {asset['title']}")
        
        try:
            response = requests.get(asset['asset_url'])
            response.raise_for_status()
            
            soup = BeautifulSoup(response.content, 'html.parser')
            
            view_files_btn = soup.find('a', class_='btn btn-default')
            if view_files_btn and view_files_btn.find('i', class_='glyphicon-folder-open'):
                view_files_url = view_files_btn.get('href', '')
                
                if 'github.com' in view_files_url:
                    repo_match = re.search(r'github\.com/([^/]+/[^/]+)', view_files_url)
                    if repo_match:
                        repo_path = repo_match.group(1)
                        repo_path = repo_path.split('/tree/')[0].split('/blob/')[0]
                        asset['github_url'] = f"https://github.com/{repo_path}"
                        github_from_viewfiles.append(asset)
                        print(f"  Success: {asset['github_url']}")
                    else:
                        print(f"  GitHub found but regex failed: {view_files_url}")
                        non_github_assets.append(asset)
                else:
                    print(f"  Non-GitHub view files: {view_files_url}")
                    non_github_assets.append(asset)
            else:
                print(f"  No View Files button found")
                non_github_assets.append(asset)
            
        except Exception as e:
            print(f"  Error processing {asset['title']}: {e}")
            non_github_assets.append(asset)
        
        time.sleep(3)
    
    return github_from_viewfiles, non_github_assets

github_from_viewfiles, non_github_assets = extract_github_from_viewfiles()

print(f"\n=== SAVING {len(github_from_viewfiles)} GITHUB REPOS FROM VIEW FILES ===")
with open('github_from_viewfiles.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(['title', 'category', 'license', 'author', 'asset_url', 'github_url'])
    for asset in github_from_viewfiles:
        writer.writerow([
            asset.get('title', ''),
            asset.get('category', ''),
            asset.get('license', ''),
            asset.get('author', ''),
            asset.get('asset_url', ''),
            asset.get('github_url', '')
        ])

non_github_assets.sort(key=lambda x: x.get('title', '').lower())

print(f"\n=== SAVING {len(non_github_assets)} NON-GITHUB ASSETS (ALPHABETICAL) ===")
with open('non_github_assets_final.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(['title', 'category', 'license', 'author', 'asset_url'])
    for asset in non_github_assets:
        writer.writerow([
            asset.get('title', ''),
            asset.get('category', ''),
            asset.get('license', ''),
            asset.get('author', ''),
            asset.get('asset_url', '')
        ])

print("Step 2 complete")
# Out:
# Processing 758 assets without GitHub...
# Processing 1/758: Kenney Prototype Tools
#   Non-GitHub view files: https://gitlab.com/MrMinimal/godot-kenney-prototype-tools
# Processing 2/758: .nw Level Importer
#   Non-GitHub view files: https://gitlab.com/xzirox/nw-level-importer
# Processing 3/758: 2.5D Sprite Rotator
#   Success: https://github.com/styr0x/2.5D-Sprite-Rotator--Godot-4-
# Processing 4/758: 2.5D World Map with Selection
#   Success: https://github.com/rafgro/godot25dmap
# Processing 5/758: 2048 Demo
#   Success: https://github.com/DeanNevan/Godot4-Beta7-Test1-2048
# Processing 6/758: 2090s Language System
#   Success: https://github.com/NeroNekro/Godot_Language_System
# Processing 7/758: 2090s Storage System
#   Success: https://github.com/NeroNekro/Godot_Storage_System
# Processing 8/758: 2D Camera Controller Singleton / with Dev Tools
#   Success: https://github.com/jessejburton/GodotCameraController2D
# Processing 9/758: 2D Camera Limiter
#   Success: https://github.com/markopolojorgensen/godot_2d_camera_limiter
# Processing 10/758: 2D Dodge The Creeps Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 11/758: 2D Dodge The Creeps Demo (Mono version)
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 12/758: 2D Dungeon Generator
#   Non-GitHub view files: https://bitbucket.org/signalsin/godot-dungeon-generator
# Processing 13/758: 2D Finite State Machine Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 14/758: 2D Flipscreen Library with Scrolling
#   Non-GitHub view files: https://gitlab.com/chucklepie-productions/flipscreen-template
# Processing 15/758: 2D Flocking Demo
#   Success: https://github.com/meloonics/Flocking
# Processing 16/758: 2D GD Paint Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 17/758: 2D HDR Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 18/758: 2D Hexagonal Map Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 19/758: 2D in 3D Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 20/758: 2D Isometric Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 21/758: 2D Kinematic Character Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 22/758: 2D Kinematic Character Demo CS
#   Success: https://github.com/MugenTwo/2d-kinematic-character-demo-cs
# Processing 23/758: 2D Light Masks Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 24/758: 2D Lights and Shadows Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 25/758: 2D Movement Controller (C#)
#   Success: https://github.com/LeoYZhang/PlatformerController
# Processing 26/758: 2D Navigation Astar Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 27/758: 2D Navigation Astar Demo CS
#   Success: https://github.com/MugenTwo/2d-navigation-a-star-demo-cs
# Processing 28/758: 2D Navigation Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 29/758: 2D Navigation Demo CS
#   Success: https://github.com/MugenTwo/2d-navigation-demo-cs
# Processing 30/758: 2D outline shader
#   Success: https://github.com/Julian-Vos/asset-library-2D-outline-shader-4
# Processing 31/758: 2D outline shader
#   Success: https://github.com/Julian-Vos/asset-library-2D-outline-shader-3
# Processing 32/758: 2D Particles Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 33/758: 2D Physics Platformer Demo (RigidBody)
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 34/758: 2D Physics Platformer Demo (Rigidbody) CS
#   Success: https://github.com/MugenTwo/2d-platformer-demo-cs
# Processing 35/758: 2D Platformer Demo (KinematicBody)
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 36/758: 2D Platformer Pathfinding Tool
#   Success: https://github.com/Thinh-T-Diep/2D-platformer-pathfinding-godot
# Processing 37/758: 2D Role Playing Game Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 38/758: 2D Screen-Space Shaders Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 39/758: 2D Sprite Shaders Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 40/758: 2D Tools
#   Success: https://github.com/KoppiGames/godot-tools
# Processing 41/758: 3D Animated Robot
#   Success: https://github.com/awindahl/Animated-3D-Robot
# Processing 42/758: 3D Course Editor
#   Non-GitHub view files: https://bitbucket.org/arlez80/course-editor
# Processing 43/758: 3D FPP Interaction Template
#   Success: https://github.com/TheRadMatt/3D-FPP-Interaction-Demo
# Processing 44/758: 3D Hover canvasitem
#   Success: https://github.com/knowercoder/3D-Hover-Shader
# Processing 45/758: 3D in 2D Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 46/758: 3D Inverse Kinematics Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 47/758: 3D Kinematic Character Demo CS
#   Success: https://github.com/MugenTwo/3d-kinematic-character-demo-cs
# Processing 48/758: 3D Material Testers Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 49/758: 3D Navmesh Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 50/758: 3D Platformer - Starter
#   Success: https://github.com/SilverDemons-PK/3D-Platformer-Kit
# Processing 51/758: 3D Platformer Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 52/758: 3D print shader
#   Success: https://github.com/q8geek/Godot-4-3D-Print-Shader
# Processing 53/758: 3D Tiles For Godot
#   Success: https://github.com/Battle-Road-Labs/3D-Tiles-For-Godot
# Processing 54/758: 3D Trail in C#
#   Success: https://github.com/q8geek/Godot-4-Basic-3D-Trail
# Processing 55/758: 3D Truck Town Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 56/758: 766 Color Palette Swap Shader
#   Success: https://github.com/AlbertoLuviano/SHADER---PaletteSwap766
# Processing 57/758: A Star 2D Grid Node
#   Success: https://github.com/Firemanarg/godot-astar-2d-grid-node
# Processing 58/758: AABB Static BoxCollider from Mesh
#   Success: https://github.com/Rybadour/AABB-Box-from-Mesh-Godot-Plugin
# Processing 59/758: abfi: Allegro Bitmap Font Importer
#   Non-GitHub view files: https://gitlab.com/snoopdouglas/abfi
# Processing 60/758: Achievement System
#   Success: https://github.com/5FB5/gd-achievements
# Processing 61/758: Acro's Hitboxes
#   Success: https://github.com/AcroProjects/AcrosHitboxes
# Processing 62/758: AdaptiSound
#   Success: https://github.com/MrWalkmanDev/AdaptiSound
# Processing 63/758: AdMob
#   Success: https://github.com/Poing-Studios/godot-admob-plugin
# Processing 64/758: AdMob
#   Success: https://github.com/Poing-Studios/godot-admob-editor
# Processing 65/758: AdMob (Legacy 3.3)
#   Success: https://github.com/Poing-Studios/godot-admob-editor
# Processing 66/758: AdMob (v2) (Legacy Godot 4.0)
#   Success: https://github.com/Poing-Studios/godot-admob-editor
# Processing 67/758: Advanced Inspector Exporter
#   Success: https://github.com/Multirious/gd-advanced-inspector-exporter
# Processing 68/758: AES in GDScript
#   Success: https://github.com/beamer159/AES-in-GDScript
# Processing 69/758: AI Assistants For Godot 4
#   Success: https://github.com/Godot4-Addons/ai_assistant_for_godot
# Processing 70/758: Airplane Mouse Controls
#   Non-GitHub view files: https://codeberg.org/ed3800/AirplaneMouseControlsForGodot3
# Processing 71/758: Android Geolocation Plugin
#   Success: https://github.com/KarimIbrahim/Godot-Geolocation-Android
# Processing 72/758: Android Godot Plugin Template
#   Success: https://github.com/fernacas-dev/android-godot-plugin-template
# Processing 73/758: Android IAP Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 74/758: Anima
#   Success: https://github.com/ceceppa/anima
# Processing 75/758: Animated Bow
#   Success: https://github.com/ImageParSeconde/Animated-FPS-BOW
# Processing 76/758: Animated Box Container
#   Success: https://github.com/GramineaGroup/animated_box_container_cs
# Processing 77/758: Animated LowPoly Pistol
#   Success: https://github.com/ImageParSeconde/Animated-Low-Poly-Pistol
# Processing 78/758: Animated LowPoly Skeleton
#   Success: https://github.com/ImageParSeconde/Animated-LowPoly-Skeleton
# Processing 79/758: Animated LowPoly Slime
#   Success: https://github.com/ImageParSeconde/-Animated-LowPoly-Slime
# Processing 80/758: Animated Panel Container
#   Success: https://github.com/GramineaGroup/animated_panel_container_cs
# Processing 81/758: Animated Zombie
#   Success: https://github.com/ImageParSeconde/Animated-Zombie
# Processing 82/758: Animation Folder Loader
#   Success: https://github.com/atsard/godot-animation-folder-loader
# Processing 83/758: Animation Frame Picker
#   Success: https://github.com/AniMesuro/Animation-Frame-Picker-for-Godot
# Processing 84/758: AntiSpecularNoise
#   Success: https://github.com/DeanNevan/Godot-AntiSpecularNoise
# Processing 85/758: Arc Dark theme
#   Success: https://github.com/Geequlim/godot-themes
# Processing 86/758: AreaProber2D
#   Success: https://github.com/Strauji/Godot-AreaProber2D
# Processing 87/758: Array Modifier
#   Success: https://github.com/miskatonicstudio/godot-array-modifier
# Processing 88/758: Array Modifier
#   Success: https://github.com/miskatonicstudio/godot-array-modifier
# Processing 89/758: Arrows
#   Non-GitHub view files: https://bitbucket.org/lkokemohr/godot_arrow_plugin
# Processing 90/758: Aseprite Animation Importer
#   Success: https://github.com/nklbdev/godot-aseprite-animation-importer
# Processing 91/758: Aseprite Importer
#   Success: https://github.com/MeagherGames/aseprite-importer-addon
# Processing 92/758: Aseprite importers
#   Success: https://github.com/nklbdev/godot-4-aseprite-importers
# Processing 93/758: AspectRatioResizeContainer
#   Success: https://github.com/kenyoni-software/godot-addons
# Processing 94/758: Asteroid Mania
#   Success: https://github.com/FonderElite/Asteroid-Mania
# Processing 95/758: Asynchronous Scene Loader
#   Success: https://github.com/NovemberDev/GodotAsyncSceneLoader
# Processing 96/758: Atlas Importer
#   Success: https://github.com/GodotExplorer/atlas_importer
# Processing 97/758: Audio Booth
#   Non-GitHub view files: https://gitlab.com/Bitron/audio-booth
# Processing 98/758: Audio Device Changer Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 99/758: Audio Generator Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 100/758: Audio Mic Record Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 101/758: Audio Spectrum Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 102/758: Authoritative Server Client Framework (Fast-paced)
#   Success: https://github.com/sboron/godot4-fast-paced-network-fps-tps
# Processing 103/758: Auto Expand Property Inspector
#   Success: https://github.com/LunatikGames/AutoExpandPropertyInspector_Godot_Plugin
# Processing 104/758: Auto Material Setup
#   Success: https://github.com/Thane5/godot-auto-material-setup
# Processing 105/758: Auto Version Incrementor (Mono)
#   Success: https://github.com/ComradeDunks/Godot4.4-Auto-Version-Incrementor-Mono
# Processing 106/758: AutoMat plugin - automatically create and assign materials
#   Success: https://github.com/Rytelier/Godot-AutoMat
# Processing 107/758: AutoSaver Toggle for Godot Editor (C#)
#   Success: https://github.com/vrravalos/AutoSaver-for-Godot
# Processing 108/758: AutoSizeText
#   Success: https://github.com/SpielmannSpiel/AutoSizeText
# Processing 109/758: AutotileGenerator
#   Success: https://github.com/ticial/AutotileGenerator
# Processing 110/758: AutotileGenerator3x3min
#   Success: https://github.com/ticial/AutotileGenerator
# Processing 111/758: aviones (Planes)
#   Non-GitHub view files: https://gitlab.com/gamedevargentina/aviones-curso
# Processing 112/758: Awaiter await-all
#   Success: https://github.com/Nightre/godot-await-all
# Processing 113/758: Axie Starter 3D
#   Success: https://github.com/axieinfinity/godot-axie-starter-3d
# Processing 114/758: Background Loading Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 115/758: Bad Words Filter
#   Success: https://github.com/rockgem/bad-words-filter
# Processing 116/758: Base64 Manager
#   Success: https://github.com/mxt08-real/Base64-Manager
# Processing 117/758: BashInGodot
#   Success: https://github.com/ThomasGysemans/BashInGodot
# Processing 118/758: Basic 3d Starter
#   Success: https://github.com/TechnoLukas/Godot4-Basic3dStarter
# Processing 119/758: Basic Dynamic Pool
#   Success: https://github.com/q8geek/Godot-4-Basic-Dynamic-Pool
# Processing 120/758: Batch collisions
#   Success: https://github.com/DiV4/godot3.2.1_batch_collisions
# Processing 121/758: Bayer Dithering Shader
#   Success: https://github.com/N0cturneDev/Bayer-Dithering-Shader
# Processing 122/758: Beholder
#   Non-GitHub view files: https://gitlab.com/mburkard/beholder-g4
# Processing 123/758: Beholder
#   Non-GitHub view files: https://gitlab.com/mburkard/beholder
# Processing 124/758: Better Processes
#   Non-GitHub view files: https://gitlab.com/greenfox/better-process-manager
# Processing 125/758: Better Terrain
#   Success: https://github.com/Portponky/better-terrain
# Processing 126/758: Better Terrain 4.2
#   Success: https://github.com/Portponky/better-terrain
# Processing 127/758: Better Terrain in Gaea
#   Success: https://github.com/Portponky/better-terrain-in-gaea
# Processing 128/758: Better UI
#   Success: https://github.com/chrisroe/Godot-Better-UI
# Processing 129/758: Bilinear Filtered Scaling
#   Non-GitHub view files: https://gitlab.com/ntfwc/godot-bilinear-filtered-scaling
# Processing 130/758: BiomeGenerator
#   Success: https://github.com/1419427247/BiomeGeneratorDemo
# Processing 131/758: Blendot Path Exporter
#   Success: https://github.com/azimuthdeveloper/Blendot-Path-Tool
# Processing 132/758: Boids (2D/3D flocking)
#   Non-GitHub view files: https://git.gaze.systems/dusk/godot_boids
# Processing 133/758: Bokeh Particle Depth of Field
#   Success: https://github.com/Bauxitedev/godot-particle-dof
# Processing 134/758: BoneGizmo
#   Success: https://github.com/thimenesup/BoneGizmo
# Processing 135/758: Bottom Panel Creator
#   Success: https://github.com/thememers/Godot_Bottom_Panel
# Processing 136/758: BSON for Godot
#   Non-GitHub view files: https://git.colormatic.org/ColormaticStudios/godot-bson
# Processing 137/758: BumpToNormal
#   Non-GitHub view files: https://gitlab.com/Jitnaught/bumptonormal
# Processing 138/758: BurstParticles2D
#   Success: https://github.com/uzkbwza/BurstParticles2D
# Processing 139/758: C# 3D Platform + State Machine - Demo
#   Success: https://github.com/nonunknown/godot-csharp-3d-platform-fsm-demo
# Processing 140/758: C# Coroutines like Unity
#   Success: https://github.com/Brian-McElroy/GodotCoroutineslikeUnity
# Processing 141/758: Calendar Button
#   Success: https://github.com/ivanskodje-godotengine/godot-plugin-calendar-button
# Processing 142/758: Camera Monitor
#   Success: https://github.com/zaevi/Godot-Camera-Monitor
# Processing 143/758: Character generator importer tool
#   Non-GitHub view files: https://gitlab.com/godot-tools/character-creator-tool-importer
# Processing 144/758: Character Outline
#   Non-GitHub view files: https://bitbucket.org/arlez80/character-outline
# Processing 145/758: CharacterCamera3D
#   Success: https://github.com/robotnik-dev/character_camera_3d
# Processing 146/758: Chess
#   Non-GitHub view files: https://git.crowdedgames.group/CatAClock/Chess
# Processing 147/758: Chunk Manager
#   Success: https://github.com/Voidbrew/chunk_manager
# Processing 148/758: CineCam
#   Success: https://github.com/PotatoGolden76/cinecam
# Processing 149/758: Classic 2D Shooter
#   Success: https://github.com/godotrecipes/classic_shmup
# Processing 150/758: Clientside Predictor (3D clientside prediction)
#   Success: https://github.com/decipher2k/Clientside-Predictor-for-Godot
# Processing 151/758: Clipboard Panel
#   Success: https://github.com/Thane5/godot-clipboard-panel
# Processing 152/758: Cloud shader
#   Non-GitHub view files: https://bitbucket.org/arlez80/cloud-shader
# Processing 153/758: CodeScope
#   Non-GitHub view files: https://codescope.app
# Processing 154/758: CodeSimp
#   Success: https://github.com/jamesin4d/codesimp
# Processing 155/758: COGITO : Immersive Sim Template
#   Success: https://github.com/Phazorknight/Cogito
# Processing 156/758: Color Calibrator
#   Non-GitHub view files: https://gitlab.com/MrMinimal/godot-color-calibrator
# Processing 157/758: Comedot Ultimate Template [4.4]
#   Success: https://github.com/InvadingOctopus/comedot
# Processing 158/758: Comedot Ultimate Template [4.5]
#   Success: https://github.com/invadingoctopus/comedot
# Processing 159/758: Compass
#   Non-GitHub view files: https://gitlab.com/gamedevone1/godot-asset-library-tools
# Processing 160/758: Content Pack Manager
#   Success: https://github.com/eumario/content-pack-manager
# Processing 161/758: Control / Input / Action re-binding
#   Success: https://github.com/JarLowrey/GodotActionBinding
# Processing 162/758: Controller
#   Success: https://github.com/cyperpunk-bonsai/controller
# Processing 163/758: CORE Framework
#   Non-GitHub view files: https://git.staropensource.de/StarOpenSource/CORE-distrib-assetlibrary
# Processing 164/758: CReverter (Composite Reverter aka Undo/Redo)
#   Non-GitHub view files: https://codeberg.org/svetogam/creverter
# Processing 165/758: CRT Monitor Shader
#   Non-GitHub view files: https://bitbucket.org/arlez80/godot-crt
# Processing 166/758: CSConnector (Contextual Signal/Setup Connector)
#   Non-GitHub view files: https://codeberg.org/svetogam/csconnector
# Processing 167/758: CSGMesher
#   Non-GitHub view files: https://codeberg.org/dbat/godot-plugin-csg-tools
# Processing 168/758: CSGToMesh
#   Non-GitHub view files: https://gitlab.com/Jitnaught/csgtomesh
# Processing 169/758: Csharp Console
#   Success: https://github.com/MolikoDeveloper/Csharp-Console-Godot
# Processing 170/758: CSLocator (Contextual Service Locator)
#   Non-GitHub view files: https://codeberg.org/svetogam/cslocator
# Processing 171/758: Curvature Shader
#   Success: https://github.com/NovemberDev/godot_curvature_shader
# Processing 172/758: Curve Terrain
#   Success: https://github.com/pyscripter99/Curve_Terrain
# Processing 173/758: Custom Theme Overrides
#   Success: https://github.com/kenyoni-software/godot-addons
# Processing 174/758: Cybs Gameunit
#   Non-GitHub view files: https://gitlab.com/Cyberrebell/cybs-gameunit
# Processing 175/758: DaemonSide
#   Non-GitHub view files: https://gitlab.com/aviangames/DaemonSide
# Processing 176/758: Dance Game Demo
#   Success: https://github.com/emirthab/dance-game-godot
# Processing 177/758: Dark Peace's BulletUpHell: BulletHell Engine (Godot 4)
#   Success: https://github.com/Dark-Peace/BulletUpHell
# Processing 178/758: Dark Peace's BulletUpHell: BulletHell Engine (Godot 4.2)
#   Success: https://github.com/Dark-Peace/BulletUpHell
# Processing 179/758: Dark Peace's BulletUpHell: BulletHell Engine (Godot4.1)
#   Success: https://github.com/Dark-Peace/BulletUpHell
# Processing 180/758: Data Folder Deleter
#   Non-GitHub view files: https://gitlab.com/KutayGuler/godot-data-folder-deleter
# Processing 181/758: Data Persistence - Easy Text File Saving & Reloading
#   Success: https://github.com/Robert-DeForrest-Reynolds/Godot-Text-File-Data-Persistence
# Processing 182/758: Date Time Addon
#   Success: https://github.com/Aendryr/Godot-Date-Time-Input
# Processing 183/758: DatePicker
#   Success: https://github.com/chrisizeful/DatePicker
# Processing 184/758: DebugGUI Graph
#   Success: https://github.com/WeaverDev/DebugGUIGraph
# Processing 185/758: DecalCo
#   Success: https://github.com/Master-J/DecalCo
# Processing 186/758: Deep Debug
#   Success: https://github.com/Rytelier/Godot-DeepDebug
# Processing 187/758: Delta Rollback
#   Non-GitHub view files: https://gitlab.com/BimDav/delta-rollback/
# Processing 188/758: Demo Platformer Game
#   Success: https://github.com/CeesarLeon2002/platformer-godot-game
# Processing 189/758: Dialog and Quest System
#   Success: https://github.com/Miziziziz/GodotDialogAndQuestSystem
# Processing 190/758: DigiVGamepad
#   Non-GitHub view files: https://gitlab.com/DigiGodotPlugins/DigiVGamepad
# Processing 191/758: DigiVR
#   Non-GitHub view files: https://gitlab.com/DigiGodotPlugins/DigiVR
# Processing 192/758: Discord RPC
#   Success: https://github.com/Abdera7mane/discord-rpc-gdscript
# Processing 193/758: Discord.gd
#   Success: https://github.com/3ddelano/discord.gd
# Processing 194/758: Dockable Output
#   Non-GitHub view files: https://bitbucket.org/MoonbrickGames/dockableoutput
# Processing 195/758: Dolly Camera Controller
#   Non-GitHub view files: https://gitlab.com/thespoonfulone/godot-dolly-zoom
# Processing 196/758: dolly-gd
#   Success: https://github.com/florianvazelle/dolly-gd
# Processing 197/758: Doodly Jumping
#   Non-GitHub view files: https://gitlab.com/mnilles/doodly-jumping
# Processing 198/758: Draftsman
#   Non-GitHub view files: https://gitlab.com/LuckyBastard/draftsman
# Processing 199/758: Draw Anywhere
#   Success: https://github.com/3ddelano/draw-anywhere-godot
# Processing 200/758: DRPG Framework
#   Success: https://github.com/Bobbinson/3d-dungeon-godot-4
# Processing 201/758: DSCN Plugin
#   Success: https://github.com/TwistedTwigleg/DSCN_Plugin
# Processing 202/758: DTDA ML - Machine Learning models
#   Success: https://github.com/dtdagames/dtda_ml
# Processing 203/758: dual quaternion skinning demo
#   Non-GitHub view files: https://bitbucket.org/bigbiglobster/dqs_demo/
# Processing 204/758: DualEditor
#   Success: https://github.com/Meta-Ben/DualEditor
# Processing 205/758: Dynamic Camera 2D
#   Success: https://github.com/emirthab/dynamic-camera
# Processing 206/758: Dynamic Gravity Kinematic Character
#   Non-GitHub view files: https://bitbucket.org/CaioFelipe/godotkinematiccharacter/
# Processing 207/758: Dynamic Split Screen Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 208/758: DynamicWater2D
#   Non-GitHub view files: https://git.gaze.systems/dusk/dynamic_water_2d
# Processing 209/758: Easy Charts
#   Success: https://github.com/fenix-hub/godot-engine.easy-charts
# Processing 210/758: Easy Charts (4.x)
#   Success: https://github.com/fenix-hub/godot-engine.easy-charts
# Processing 211/758: Easy Savefiles
#   Non-GitHub view files: https://git.gay/kaneraZh/easy_savefiles
# Processing 212/758: Easy Sheet Manager
#   Success: https://github.com/nonunknown/godot-sheet-manager
# Processing 213/758: EasyBlend
#   Success: https://github.com/nobuyukinyuu/Godot-EasyBlend
# Processing 214/758: Editor debugger
#   Success: https://github.com/Zylann/godot_editor_debugger_plugin
# Processing 215/758: Editor debugger
#   Success: https://github.com/Zylann/godot_editor_debugger_plugin
# Processing 216/758: Editor Discord Presence
#   Success: https://github.com/3ddelano/godot-editor-discord-presence
# Processing 217/758: editor-log-highlighter
#   Success: https://github.com/ClumsyInker/godot-editor-log-highlighter
# Processing 218/758: Elgato Stream Deck Integration
#   Success: https://github.com/BoyneGames/streamdeck-godot-plugin
# Processing 219/758: EngA - Engine Agnostic Framework
#   Non-GitHub view files: https://gitlab.com/engine-agnostic-code-project/godot-4.3
# Processing 220/758: EnhancedGridMap
#   Success: https://github.com/DanchieGO/EnhancedGridMap
# Processing 221/758: Export On Save
#   Non-GitHub view files: https://gitlab.com/snopek-games/godot-export-on-save-addon
# Processing 222/758: ExtendTimer
#   Success: https://github.com/Keldowin/ExtendTimer
# Processing 223/758: EzNet
#   Success: https://github.com/RoyasDev/EzNet
# Processing 224/758: Ezpz Inspector
#   Success: https://github.com/dilaura-exp/Ezpz-Inspector
# Processing 225/758: Fancy particles
#   Success: https://github.com/Ark2000/fancy-particles
# Processing 226/758: File Structure Export
#   Success: https://github.com/Coffeeworld/file-structure-export-plugin
# Processing 227/758: FileSystemView
#   Success: https://github.com/zaevi/godot-filesystem-view
# Processing 228/758: Finite Stack Machine
#   Non-GitHub view files: https://gitlab.com/reefpirate/finite_stack_machine
# Processing 229/758: Finite State Machine
#   Non-GitHub view files: https://codeberg.org/HexagonNico/FiniteStateMachine
# Processing 230/758: Fire Bullets
#   Success: https://github.com/Melon-The-Dev/Fire-Bullets-Godot-Plugin
# Processing 231/758: Fire Shader
#   Non-GitHub view files: https://bitbucket.org/arlez80/fire
# Processing 232/758: First Person Controller
#   Success: https://github.com/ashrafulislambd/fpscontroller
# Processing 233/758: First Person Controller (FPS)
#   Success: https://github.com/Linko-3D/First-Person-Controller-FPS
# Processing 234/758: First person player
#   Success: https://github.com/mxt08-real/player
# Processing 235/758: Flawless 2D Shadows
#   Success: https://github.com/Rokle/Flawless-2D-Shadows
# Processing 236/758: Flipbook Particles
#   Non-GitHub view files: https://gitlab.com/MrMinimal/godot-flipbook-particles
# Processing 237/758: FlowerInventory
#   Success: https://github.com/Abab-bk/FlowerIventory
# Processing 238/758: FlowerInventory - GD4
#   Success: https://github.com/Abab-bk/FlowerIventory
# Processing 239/758: Foamy Ocean
#   Success: https://github.com/creikey/foamy-ocean
# Processing 240/758: Follower
#   Success: https://github.com/mxt08-real/follow
# Processing 241/758: FPS Controller (Mono)
#   Success: https://github.com/ismailgamedev/FPS-Controller-Mono
# Processing 242/758: FPS Hands
#   Non-GitHub view files: https://codeberg.org/Bytez/godot-fps-hands
# Processing 243/758: Fractal Shaders
#   Success: https://github.com/Chaosus/GDFractals
# Processing 244/758: Free Look Camera
#   Success: https://github.com/MarcPhi/godot-free-look-camera
# Processing 245/758: Function Type Auto-complete
#   Success: https://github.com/kahanscious/godot-function-autocomplete
# Processing 246/758: Game Base 2D
#   Success: https://github.com/GuilhermeGSousa/game-base-2D
# Processing 247/758: Gameboard SDK Plugin
#   Non-GitHub view files: https://gitlab.com/publiclastgameboard/godot-sdk
# Processing 248/758: GD-OpenBlive
#   Success: https://github.com/Fantety/GD-OpenBlive
# Processing 249/758: GD-SimpleKnob
#   Success: https://github.com/nobuyukinyuu/GD-SimpleKnob
# Processing 250/758: GD-Sync | Advanced Multiplayer Plugin
#   Success: https://github.com/GD-Sync/GD-Sync
# Processing 251/758: GDCastleDB
#   Non-GitHub view files: https://bitbucket.org/arlez80/gdcastledb
# Processing 252/758: GDCastleDB for Godot Engine 4
#   Non-GitHub view files: https://bitbucket.org/arlez80/gdcastledb4
# Processing 253/758: GDFormat
#   Non-GitHub view files: https://gitlab.com/DonatienBdR/gdformat-plugin
# Processing 254/758: GDGotm
#   Success: https://github.com/PlayGotm/GDGotm
# Processing 255/758: GDLog
#   Success: https://github.com/MagdielM/GDLog
# Processing 256/758: GDLuau: Luau C/C++ API bindings
#   Success: https://github.com/Manonox/GDLuau
# Processing 257/758: GDMosquitto
#   Success: https://github.com/GDWired/GDMosquitto
# Processing 258/758: GDMUT - C# Unit Tester
#   Success: https://github.com/Spycemyster/GDMUT
# Processing 259/758: GDNative-Ropesim
#   Success: https://github.com/mphe/GDNative-Ropesim
# Processing 260/758: gdods
#   Non-GitHub view files: https://git.sr.ht/~jelle/gdods
# Processing 261/758: GDPaho
#   Success: https://github.com/GDWired/GDPaho
# Processing 262/758: GDPeg
#   Non-GitHub view files: https://bitbucket.org/arlez80/gdpeg
# Processing 263/758: GDPeg for Godot Engine 4
#   Non-GitHub view files: https://bitbucket.org/arlez80/gdpeg4
# Processing 264/758: GDScript Input Field Plugin
#   Non-GitHub view files: https://radicle.blujai831.dev/nodes/git.blujai831.dev/rad:z4F8WgyUHy3v3v2EKV8ut97x7Gvn8/remotes/z6MkjrgG9kQc1LQTXD2G2UpiVdeEYzu1MfiQrdCd2pMWXq7g/tree/for-godot-4.1
# Processing 265/758: GDScript Macros
#   Success: https://github.com/rainlizard/GDScriptMacros
# Processing 266/758: GDScript OTP
#   Success: https://github.com/fenix-hub/godot-engine.otp
# Processing 267/758: GDScript Parsers
#   Non-GitHub view files: https://bitbucket.org/arlez80/godot-byte-code-parser
# Processing 268/758: GDScript Promise Async Utils
#   Success: https://github.com/kuruk-mm/gdscript-promise-async-utils
# Processing 269/758: GDScript syntax highlighting for GNU Nano text editor
#   Success: https://github.com/Rito13/nano-gdscript
# Processing 270/758: gdunzip
#   Non-GitHub view files: https://git.sr.ht/~jelle/gdunzip
# Processing 271/758: Gemini Protocol
#   Non-GitHub view files: https://gitlab.com/mocchapi/godot-4-gemini-protocol
# Processing 272/758: GestureControlledCamera2D - Godot 3.x
#   Success: https://github.com/Federico-Ciuffardi/GestureControlledCamera2D
# Processing 273/758: GestureControlledCamera2D - Godot 4.x
#   Success: https://github.com/Federico-Ciuffardi/GestureControlledCamera2D
# Processing 274/758: Ginq
#   Success: https://github.com/kaluluosi/Ginq
# Processing 275/758: Git SHA Project Setting
#   Success: https://github.com/kenyoni-software/godot-addons
# Processing 276/758: Git User Data
#   Success: https://github.com/ACB-prgm/GitDataPlugin
# Processing 277/758: Github To Itch
#   Success: https://github.com/LeonardMeagher2/github_to_itch
# Processing 278/758: Gizmo3D
#   Success: https://github.com/chrisizeful/Gizmo3D
# Processing 279/758: Global position and rotation in Inspector
#   Success: https://github.com/Login1990/global_position_edit
# Processing 280/758: GMUI
#   Success: https://github.com/JustDooooIt/GMUI
# Processing 281/758: GO P2P
#   Success: https://github.com/GodotOnlineCOM/GodotOnline-P2P-Plugin
# Processing 282/758: GoBoxDialog
#   Success: https://github.com/K0RIS/GoBoxDialog
# Processing 283/758: Godiscord
#   Success: https://github.com/Shuflduf/Godiscord
# Processing 284/758: GodoGram - Telegram API
#   Success: https://github.com/Delalex/GodoGram
# Processing 285/758: godot - backpacks
#   Non-GitHub view files: https://gitee.com/L_HM/backpack_grid
# Processing 286/758: Godot .NET Scene-Oriented Unit Test
#   Non-GitHub view files: https://gitlab.com/jfletcher94/gd-net-scout
# Processing 287/758: Godot 3D mesh slicing
#   Success: https://github.com/SYBIOTE/Godot-Mesh-slicer
# Processing 288/758: Godot 4 interior mapping shader no cubemap
#   Success: https://github.com/Rytelier/Godot-4-interior-mapping-shader-no-cubemap
# Processing 289/758: Godot 4.1 3D Terrain Plugin (heightmap, mapbox)
#   Success: https://github.com/sboron/terrain-tool-godot4
# Processing 290/758: Godot Awesome Debug Print
#   Success: https://github.com/AustinDoss/Godot-Awesome-Debug-Print
# Processing 291/758: Godot Beautifier
#   Success: https://github.com/cdpude/GodotBeautifier
# Processing 292/758: Godot Bone Editor
#   Non-GitHub view files: https://bitbucket.org/arlez80/bone-editor
# Processing 293/758: Godot Compass
#   Success: https://github.com/vi4hu/godot_compass
# Processing 294/758: Godot Compass
#   Success: https://github.com/vi4hu/godot_compass
# Processing 295/758: Godot Cookies
#   Success: https://github.com/Joy-less/GodotCookies
# Processing 296/758: Godot Coroutines (Unity like)
#   Non-GitHub view files: https://codeberg.org/Michieal/Godot-Coroutines
# Processing 297/758: Godot CQRS
#   Success: https://github.com/HellboyHeaven/godot-cqrs
# Processing 298/758: Godot Engine JWT
#   Success: https://github.com/fenix-hub/godot-engine.jwt
# Processing 299/758: Godot Essentials
#   Non-GitHub view files: https://gitlab.com/godot-tools/godot-essentials
# Processing 300/758: Godot file auto-open
#   Non-GitHub view files: https://gitlab.com/pahool_gamedev/godot_file_autoopen_addon
# Processing 301/758: Godot Finder
#   Non-GitHub view files: https://gitlab.com/joao-pedro-braz/godot-finder/
# Processing 302/758: Godot Game Settings
#   Success: https://github.com/PunchablePlushie/godot-game-settings
# Processing 303/758: Godot GIF (4.1)
#   Success: https://github.com/BOTLANNER/godot-gif
# Processing 304/758: Godot GIF (4.4.1)
#   Success: https://github.com/BOTLANNER/godot-gif
# Processing 305/758: Godot Inheritance Dock
#   Success: https://github.com/willnationsdev/godot-inheritance-dock
# Processing 306/758: Godot MIDI Player
#   Non-GitHub view files: https://bitbucket.org/arlez80/godot-midi-player
# Processing 307/758: Godot MIDI Player for Godot Engine 4
#   Non-GitHub view files: https://bitbucket.org/arlez80/godot-midi-player-g4
# Processing 308/758: Godot Mod Loader
#   Success: https://github.com/GodotModding/godot-mod-loader
# Processing 309/758: Godot Mod Player
#   Non-GitHub view files: https://bitbucket.org/arlez80/godot-mod-player
# Processing 310/758: Godot Mod Player for Godot Engine 4
#   Non-GitHub view files: https://bitbucket.org/arlez80/godot-mod-player-g4
# Processing 311/758: Godot Motion Matching
#   Success: https://github.com/GuilhermeGSousa/godot-motion-matching
# Processing 312/758: Godot Navigation Lite
#   Success: https://github.com/MilosLukic/Godot-Navigation-Lite
# Processing 313/758: Godot NExt (Node Extensions)
#   Success: https://github.com/godot-extended-libraries/godot-next
# Processing 314/758: Godot Node FSM Plugin [Finite State Machine]
#   Non-GitHub view files: https://gitlab.com/sunetraalex/godot-node-fsm-plugin
# Processing 315/758: Godot Open Dialogue
#   Non-GitHub view files: https://bitbucket.org/jsena42/godot-open-dialogue/
# Processing 316/758: Godot OpenHMD driver
#   Success: https://github.com/GodotVR/godot-openhmd-asset
# Processing 317/758: Godot Palette Swap
#   Success: https://github.com/HeartoLazor/godot_palette_swap
# Processing 318/758: Godot Plugin Refresher
#   Success: https://github.com/godot-extended-libraries/godot-plugin-refresher
# Processing 319/758: Godot Raymarching
#   Success: https://github.com/bruce965/godot-raymarching
# Processing 320/758: Godot Retro
#   Success: https://github.com/Ahopness/GodotRetro
# Processing 321/758: Godot Rich Presence
#   Success: https://github.com/WesleiRamos/Godot-Rich-Presence
# Processing 322/758: Godot RL Agents
#   Success: https://github.com/edbeeching/godot_rl_agents_plugin
# Processing 323/758: Godot Rollback Netcode (Godot 3)
#   Non-GitHub view files: https://gitlab.com/snopek-games/godot-rollback-netcode/
# Processing 324/758: Godot Rollback Netcode (Godot 4)
#   Non-GitHub view files: https://gitlab.com/snopek-games/godot-rollback-netcode/
# Processing 325/758: Godot Scene Exporter
#   Success: https://github.com/Clancey/GodotExport
# Processing 326/758: Godot Simple Text Menu
#   Success: https://github.com/henriquelalves/GodotSimpleTextMenu
# Processing 327/758: Godot Solana SDK
#   Success: https://github.com/Virus-Axel/godot-solana-sdk
# Processing 328/758: Godot Space Mouse
#   Success: https://github.com/cybereality/godot-space-mouse
# Processing 329/758: Godot Stereo 3D
#   Success: https://github.com/cybereality/godot-stereo-3d
# Processing 330/758: Godot Super Scaling
#   Success: https://github.com/cybereality/godot-super-scaling
# Processing 331/758: Godot Super Wakatime
#   Success: https://github.com/BudzioT/Godot_Super-Wakatime
# Processing 332/758: Godot Text Interface Engine
#   Success: https://github.com/henriquelalves/GodotTIE
# Processing 333/758: Godot Text Interface Engine (Godot v3.x)
#   Success: https://github.com/henriquelalves/GodotTIE
# Processing 334/758: Godot Texture Atlas
#   Success: https://github.com/KAUTARUMA/godot-texture-atlas
# Processing 335/758: Godot Timed Input
#   Success: https://github.com/hatmix/godot-timed-input
# Processing 336/758: Godot TOML Parser
#   Success: https://github.com/XBenichi/Godot-TOML-Parser
# Processing 337/758: Godot Touch Input Manager - Godot 3.x
#   Success: https://github.com/Federico-Ciuffardi/GodotTouchInputManager
# Processing 338/758: Godot Touch Input Manager - Godot 4.x
#   Success: https://github.com/Federico-Ciuffardi/GodotTouchInputManager
# Processing 339/758: Godot Touch Input Manager Demo - Godot 3.x
#   Success: https://github.com/Federico-Ciuffardi/GodotTouchInputManager-Demo
# Processing 340/758: Godot Touch Input Manager Demo - Godot 4.x
#   Success: https://github.com/Federico-Ciuffardi/GodotTouchInputManager-Demo
# Processing 341/758: Godot VN
#   Non-GitHub view files: https://gitlab.com/Code_Man/Godot_VN
# Processing 342/758: Godot WebXR Template
#   Success: https://github.com/msub2/godot-webxr-template
# Processing 343/758: godot-dynamic-quality-scaling
#   Success: https://github.com/thmasn/godot-dynamic-quality-scaling#godot-dynamic-quality-scaling
# Processing 344/758: Godot-MirrorInstance
#   Success: https://github.com/19PHOBOSS98/Godot-MirrorInstance
# Processing 345/758: Godot-MMD
#   Success: https://github.com/sselecirPyM/Godot-MMD
# Processing 346/758: godot-queue
#   Non-GitHub view files: https://codeberg.org/anyreso/godot-queue
# Processing 347/758: Godot-Stuff ECS 3.2
#   Non-GitHub view files: https://gitlab.com/godot-stuff/gs-ecs
# Processing 348/758: Godot-Stuff ECS 3.3
#   Non-GitHub view files: https://gitlab.com/godot-stuff/gs-ecs
# Processing 349/758: Godot-Stuff ECS 3.4
#   Non-GitHub view files: https://gitlab.com/godot-stuff/gs-ecs
# Processing 350/758: Godot-Stuff ECS 3.5
#   Non-GitHub view files: https://gitlab.com/godot-stuff/gs-ecs
# Processing 351/758: Godot-Stuff ECS 4.0
#   Non-GitHub view files: https://gitlab.com/godot-stuff/gs-ecs
# Processing 352/758: Godot-Stuff Logger 3.0
#   Non-GitHub view files: https://gitlab.com/godot-stuff/gs-logger
# Processing 353/758: Godot-Stuff Logger 3.1
#   Non-GitHub view files: https://gitlab.com/godot-stuff/gs-logger
# Processing 354/758: Godot-Stuff Logger 3.2
#   Non-GitHub view files: https://gitlab.com/godot-stuff/gs-logger
# Processing 355/758: Godot-Stuff Logger 3.3
#   Non-GitHub view files: https://gitlab.com/godot-stuff/gs-logger
# Processing 356/758: Godot-Stuff Logger 3.4
#   Non-GitHub view files: https://gitlab.com/godot-stuff/gs-logger
# Processing 357/758: Godot-Stuff Logger 3.5
#   Non-GitHub view files: https://gitlab.com/godot-stuff/gs-logger
# Processing 358/758: Godot-Stuff Logger 4.0
#   Non-GitHub view files: https://gitlab.com/godot-stuff/gs-logger
# Processing 359/758: Godot-Stuff Project Manager
#   Non-GitHub view files: https://gitlab.com/godot-stuff/gs-project-manager
# Processing 360/758: Godot-WeChatPay-Android-Plugin
#   Success: https://github.com/dsyze/Godot-WeChatPay-Android-Plugin
# Processing 361/758: Godot4 LAN Servers Discovery (serversscan)
#   Success: https://github.com/Nightscratch/Godot4-LAN-Servers-Discovery
# Processing 362/758: Godot4-Coroutine
#   Success: https://github.com/BimDav/Godot4-Coroutines
# Processing 363/758: GodotBLE
#   Success: https://github.com/Fantety/GodotBLE
# Processing 364/758: GodotBoy GDExtention
#   Non-GitHub view files: https://gitlab.com/greenfox/godot-boy
# Processing 365/758: GodotEnv
#   Success: https://github.com/coelhucas/godotenv
# Processing 366/758: GodotGPT
#   Success: https://github.com/jespereggers/GodotGPT
# Processing 367/758: GodotGPT
#   Success: https://github.com/brb-fr/GodotGPT
# Processing 368/758: GodotIRC
#   Success: https://github.com/AlexHoratio/GodotIRC
# Processing 369/758: GodotMetaMaskLogin
#   Success: https://github.com/NumDev2310/GodotMetaMaskLogin
# Processing 370/758: GoGodot
#   Success: https://github.com/Oranjoose/GoGodot
# Processing 371/758: Google Maps
#   Non-GitHub view files: https://codeberg.org/paperweights/godot-gmaps
# Processing 372/758: Google Play Games Services Plugin for Godot
#   Success: https://github.com/StudioAdriatic/PGSGP
# Processing 373/758: Google Sheets as Database C#
#   Success: https://github.com/nonunknown/Godot-SheetDB
# Processing 374/758: Gopilot Assist
#   Non-GitHub view files: https://gitlab.com/Marty_Friedrich/gopilot-interface
# Processing 375/758: Gopilot Utils (LLMs and embedding)
#   Non-GitHub view files: https://gitlab.com/Marty_Friedrich/gopilot-utils
# Processing 376/758: GPUNoiseTexture(2D/3D)
#   Success: https://github.com/2Retr0/GodotGPUNoiseTexture
# Processing 377/758: Gravity Objects
#   Success: https://github.com/Jummit/Godot-Gravity-Objects
# Processing 378/758: GUI Drag And Drop Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 379/758: GUI in 3D Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 380/758: GUI Input Mapping Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 381/758: GUI Rich Text/BBcode Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 382/758: GUI Translation Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 383/758: Gype
#   Success: https://github.com/godothub/gype
# Processing 384/758: Hair Shader
#   Success: https://github.com/Bauxitedev/godot-hair-shader
# Processing 385/758: HathoraHTTPRequest
#   Non-GitHub view files: https://gitlab.com/arkelen/hathorahttprequest
# Processing 386/758: HathoraHTTPRequest
#   Non-GitHub view files: https://gitlab.com/arkelen/hathorahttprequest-godot4
# Processing 387/758: HealthBar2D
#   Success: https://github.com/vi4hu/godot_health_bar_2d
# Processing 388/758: HealthBar2D
#   Success: https://github.com/vi4hu/godot_health_bar_2d
# Processing 389/758: Hexagonal Grid Utils
#   Non-GitHub view files: https://gitlab.com/gratuito/hexgridgodot
# Processing 390/758: HexGrid library for Godot 4.0+
#   Success: https://github.com/HugoEnzo/HexGrid_Godot_4.0
# Processing 391/758: Hexgrid Mono
#   Non-GitHub view files: https://bitbucket.org/the1krutz/godot-hexgrid-mono
# Processing 392/758: Hide Private Properties
#   Success: https://github.com/kenyoni-software/godot-addons
# Processing 393/758: HighscoreManager
#   Success: https://github.com/schmertenk/HighscoreManager
# Processing 394/758: How Collision and Layer Masks Works
#   Success: https://github.com/alexbosquin/godot-collision-mask-layer
# Processing 395/758: HTML5 File Dialogs
#   Non-GitHub view files: https://gitlab.com/mocchapi/godot-4-html5-file-dialogs
# Processing 396/758: HTML5 Popups
#   Non-GitHub view files: https://gitlab.com/mocchapi/godot-4-html5-popups/
# Processing 397/758: HTTPEventSource for Server Sent Events
#   Non-GitHub view files: https://gitlab.com/DaGammla/godot-http-event-source
# Processing 398/758: Hunspell Spellchecker
#   Success: https://github.com/brunogbrito/Godot-Hunspell
# Processing 399/758: Icon Explorer
#   Success: https://github.com/kenyoni-software/godot-addons
# Processing 400/758: Icons Patcher
#   Success: https://github.com/kenyoni-software/godot-addons
# Processing 401/758: IdeaBoard
#   Success: https://github.com/folt-a/godot-idea-board
# Processing 402/758: Import Cleaner
#   Success: https://github.com/zaevi/ImportCleaner
# Processing 403/758: Importality
#   Success: https://github.com/nklbdev/godot-4-importality
# Processing 404/758: Improved Resource Picker
#   Success: https://github.com/MakovWait/improved_resource_picker
# Processing 405/758: Improved Resource Picker 4.x
#   Success: https://github.com/MakovWait/improved_resource_picker
# Processing 406/758: Inputty
#   Non-GitHub view files: https://codeberg.org/MxSophie/Inputty
# Processing 407/758: Instancing Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 408/758: Interior Mapping Shader
#   Non-GitHub view files: https://bitbucket.org/arlez80/godot-interior-mapping/
# Processing 409/758: intro-gd
#   Success: https://github.com/farhadi-erfan/intro-gd
# Processing 410/758: Inventory Demo with bags and chests
#   Success: https://github.com/Rokle/Godot-Inventory-Demo
# Processing 411/758: Inventory Example
#   Success: https://github.com/hajstersztyk/Inventory-Example
# Processing 412/758: Inventory Manager Asset
#   Success: https://github.com/Escandiuzzi/Inventory-Manager-Asset-Godot
# Processing 413/758: Joypads Demo / Tool
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 414/758: JSON Beautifier
#   Non-GitHub view files: https://codeberg.org/Yeldham/json-beautifier-for-godot
# Processing 415/758: JSON Schema validator
#   Success: https://github.com/Sahedo/JSON-Shema-validator
# Processing 416/758: Kanban
#   Non-GitHub view files: https://gitlab.com/SwePopper/GodotKanban
# Processing 417/758: Kenney Spritesheet Importer
#   Non-GitHub view files: https://bitbucket.org/iseesharp83workspace/kenney-spritesheet-importer-godot-plugin/
# Processing 418/758: Key Prompts System
#   Success: https://github.com/CliveDev0413/key-prompts-system-godot
# Processing 419/758: Keychain
#   Success: https://github.com/Orama-Interactive/Keychain
# Processing 420/758: Launchy
#   Success: https://github.com/nobuyukinyuu/launchy
# Processing 421/758: LDtk Importer
#   Success: https://github.com/JoshLee0915/GodotLDtkImporter
# Processing 422/758: License Manager
#   Success: https://github.com/kenyoni-software/godot-addons
# Processing 423/758: LinuxLikeConsole
#   Success: https://github.com/cobrapitz/LinuxLikeConsole
# Processing 424/758: Loading Autoload Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 425/758: Loading Scene Changer Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 426/758: Loading with Threads Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 427/758: LogDuck - Your Logging Buddy for Godot 4.x
#   Success: https://github.com/ZeeWeasel/LogDuck
# Processing 428/758: LogFox
#   Success: https://github.com/HakaikuXiao/LogFox
# Processing 429/758: Loggie
#   Success: https://github.com/Shiva-Shadowsong/loggie
# Processing 430/758: LootLockerSDK
#   Success: https://github.com/lootlocker/godot-sdk
# Processing 431/758: Ludare Godot
#   Success: https://github.com/medstone/LudareGodot
# Processing 432/758: Majordomo
#   Success: https://github.com/BenjaTK/Majordomo
# Processing 433/758: Makefile Launcher
#   Success: https://github.com/samdze/godot-makefile-launcher-plugin
# Processing 434/758: Mannequiny: Open 3D Mannequin
#   Success: https://github.com/GDquest/godot-3d-mannequin
# Processing 435/758: Map Generator Sample
#   Success: https://github.com/CheapMeow/Godot-MapGeneratorSampleProject
# Processing 436/758: Marker2D
#   Success: https://github.com/marcozee03/Marker2D
# Processing 437/758: Material Modifier
#   Success: https://github.com/Thane5/godot-material-modifier
# Processing 438/758: Material Modifier
#   Success: https://github.com/Thane5/godot-material-modifier
# Processing 439/758: Maze Generator using TileMapLayer
#   Non-GitHub view files: https://teapot.informationsanarchistik.de/Megamichi/maze-generator-assets-lib
# Processing 440/758: MeshBatcher
#   Success: https://github.com/OrigamiDev-Pete/MeshBatcher
# Processing 441/758: MeshLibraryFrameInstance3D
#   Success: https://github.com/martcarrefour/MeshLibraryFrameInstance3D
# Processing 442/758: MessageBox
#   Success: https://github.com/tlitookilakin/message_box
# Processing 443/758: MetaMultimesh3D
#   Non-GitHub view files: https://codeberg.org/dbat/godot-plugin-meta-multimesh3d
# Processing 444/758: Midi Visualizer
#   Success: https://github.com/50tu/Godot-Midi-Visualizer
# Processing 445/758: Mind Game
#   Success: https://github.com/adammikulis/MindGame
# Processing 446/758: MiniScript C#
#   Success: https://github.com/raiyni/miniscript-cs
# Processing 447/758: Mirror3D
#   Success: https://github.com/Joy-less/Mirror3D
# Processing 448/758: Mobile Sensors Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 449/758: Mod Loader Dev Tool Brotato Content Loader Template
#   Success: https://github.com/BrotatoMods/ML_Dev_Tool_Content_Loader_minimal_Tempalte
# Processing 450/758: Mod.io For Godot
#   Success: https://github.com/aNaOH/modio-godot
# Processing 451/758: Modifiers Node
#   Success: https://github.com/samdze/godot-modifiers-plugin
# Processing 452/758: Modular Components
#   Success: https://github.com/AlecSouthward/Modular-Components
# Processing 453/758: More Compression
#   Success: https://github.com/Hunam6/more-compression
# Processing 454/758: More Effective Godot Coroutines (C#)
#   Success: https://github.com/WeaverDev/More-Effective-Godot-Coroutines
# Processing 455/758: Mosaic Shader
#   Non-GitHub view files: https://bitbucket.org/arlez80/godot-mosaic-shader/
# Processing 456/758: Motion Blur
#   Success: https://github.com/Bauxitedev/godot-motion-blur
# Processing 457/758: Motion Blur 4.0
#   Success: https://github.com/davisbrandon02/motion-blur-godot-4.0
# Processing 458/758: Movement 2: A sequel to 2D Platformer demos
#   Success: https://github.com/TheoTheTorch/MOVEMENT-2
# Processing 459/758: Movement 2: A sequel to 2D Platformer demos (3.5)
#   Success: https://github.com/TheoTheTorch/MOVEMENT-2
# Processing 460/758: Movie Maker Timestamp
#   Non-GitHub view files: https://gitlab.com/timkrief/movie_maker_timestamp
# Processing 461/758: Multi-Scene Editor
#   Success: https://github.com/eruhlinteractive/godot_multi_scene_editor
# Processing 462/758: MultiMesh Scatter
# ...
# Processing 609/758: simple random position generator
#   Success: https://github.com/mohamadbagherblack/simple-random-position-generator
# Processing 610/758: Simple Scene Manager
#   Success: https://github.com/symbol24/Simple-Scene-Manager
# Processing 611/758: Simple Skybox
#   Success: https://github.com/Chaosus/GDSimpleSkybox
# Processing 612/758: Simple Test Harness
#   Success: https://github.com/AdrienQuillet/godot-simple-test-harness
# Processing 613/758: Simple-First-Person-Controller
#   Success: https://github.com/Linko-3D/Godot-Simple-First-Person-Controller
# Processing 614/758: SimpleBoards: Free Leaderboard Service
#   Success: https://github.com/isetr/simpleboards_godot
# Processing 615/758: SimpleDialogueBox
#   Success: https://github.com/majorendian/SimpleDialogueBox-Godot-3.0
# Processing 616/758: SimpleState
#   Non-GitHub view files: https://gitlab.com/addons-by-aura/simple-state/
# Processing 617/758: Singleton Scripts Shortcut
#   Success: https://github.com/rainlizard/SingletonScriptsShortcut
# Processing 618/758: Sketchfab
#   Success: https://github.com/sketchfab/godot-plugin
# Processing 619/758: Slime Shooter - Godot & FOSS Learning Project
#   Non-GitHub view files: https://codeberg.org/FreedCreative/SlimeShooter
# Processing 620/758: Smart Graphics Settings
#   Success: https://github.com/lucasbecker-dev/godot-smart-graphics-settings
# Processing 621/758: SmoothScroll
#   Success: https://github.com/SpyrexDE/SmoothScroll
# Processing 622/758: SmoothScroll
#   Success: https://github.com/SpyrexDE/SmoothScroll
# Processing 623/758: Snake
#   Success: https://github.com/Xydium/AssetLibContributions
# Processing 624/758: Snap Placement System
#   Non-GitHub view files: https://gitlab.com/ikinami/godot-drag-and-place-template
# Processing 625/758: Snappy
#   Success: https://github.com/jgillich/godot-snappy
# Processing 626/758: Snippets Editor Plugin
#   Success: https://github.com/gswashburn/Snippets-EditorPlugin
# Processing 627/758: Snopek State Machine
#   Non-GitHub view files: https://gitlab.com/snopek-games/godot-state-machine
# Processing 628/758: SoftNoise
#   Success: https://github.com/PerduGames/SoftNoise-GDScript-
# Processing 629/758: Sokoban Cube
#   Success: https://github.com/To-Fujita/Godot_v3.2-Sokoban_Cube
# Processing 630/758: Sound Manager
#   Non-GitHub view files: https://gitlab.com/Xecestel/sound-manager
# Processing 631/758: SparrowAtlas Editor
#   Success: https://github.com/Pocku/godot-sparrowatlas-editor
# Processing 632/758: Spatial Gardener
#   Success: https://github.com/dreadpon/godot_spatial_gardener
# Processing 633/758: SPIRV Importer
#   Success: https://github.com/teamclouday/SPIRV-Importer
# Processing 634/758: Sprite Baker
#   Success: https://github.com/DwanaG/SpriteBaker
# Processing 635/758: Sprite Mask
#   Non-GitHub view files: https://gitlab.com/Quantum_Martin/sprite-mask
# Processing 636/758: Sprite Quick Offset
#   Success: https://github.com/K3nIchi/sprite_quick_offset
# Processing 637/758: Sprite2D Rect Editor
#   Non-GitHub view files: https://gitlab.com/andrej-petrovic/sprite2d-rect-editor
# Processing 638/758: SpritesheetFromFiles
#   Success: https://github.com/davidkbd/Godot_SpritesheetFromFiles
# Processing 639/758: Squiggles Core 4X
#   Success: https://github.com/QueenOfSquiggles/Squiggles-Core-4X
# Processing 640/758: Stair-stepping Demo
#   Success: https://github.com/JheKWall/Godot-Stair-Step-Demo
# Processing 641/758: Start.io Godot Android Plugin
#   Success: https://github.com/fernacas-dev/godot-startio-android-plugin
# Processing 642/758: State Graph
#   Success: https://github.com/MrBSmith/StateGraph
# Processing 643/758: State Machine
#   Success: https://github.com/AlecSouthward/state-machine
# Processing 644/758: State Machine for Platformer Games
#   Success: https://github.com/CeesarLeon2002/state-machine-for-platformer-games
# Processing 645/758: Statechart Sharp: a state machine plugin
#   Success: https://github.com/laoguowangCP/godot-statechart-sharp
# Processing 646/758: Steam Template
#   Success: https://github.com/Malcolm-Q/SteamGodotTemplate
# Processing 647/758: Sticky Scribe - A flexible TODO list, task manager, bug tracker, and notes tool for Godot 3
#   Non-GitHub view files: https://gitlab.com/ace24713/stickyscribegodot
# Processing 648/758: Sticky Scribe - A flexible TODO list, task manager, bug tracker, and notes tool for Godot 4
#   Non-GitHub view files: https://gitlab.com/ace24713/stickyscribegodot
# Processing 649/758: STN LCD-esque Shader
#   Non-GitHub view files: https://bitbucket.org/arlez80/lcd-shader
# Processing 650/758: Stopwatch
#   Non-GitHub view files: https://gitlab.com/swolford/godot-stopwatch
# Processing 651/758: Stopwatch
#   Success: https://github.com/GuaraProductions/Stopwatch
# Processing 652/758: Storage Manager
#   Success: https://github.com/davidkbd/Godot_StorageManager
# Processing 653/758: String utilities
#   Success: https://github.com/mxt08-real/String-utilities
# Processing 654/758: Stylish Menu Demo
#   Non-GitHub view files: https://gitlab.com/coledingo1/stylish-menu-demo
# Processing 655/758: SubViewportContainerStretch
#   Non-GitHub view files: https://gitlab.com/Royerson/godot-plugin-subviewportcontainerstretch
# Processing 656/758: SuperChart-draggable&zoomable
#   Success: https://github.com/DeanNevan/Godot-2D-Super-Chart
# Processing 657/758: SuperLightning
#   Success: https://github.com/DeanNevan/Godot-2D-Super-Lightning
# Processing 658/758: Sweep
#   Non-GitHub view files: https://gitlab.com/derin-gamedev/sweep
# Processing 659/758: Switch Manager
#   Success: https://github.com/AlecSouthward/Switch-Manager
# Processing 660/758: TableDB
#   Success: https://github.com/GeCreator/TableDB
# Processing 661/758: Taffer's Loader
#   Non-GitHub view files: https://codeberg.org/Taffer/godot-resourceloader
# Processing 662/758: Taffer's Logger
#   Non-GitHub view files: https://codeberg.org/Taffer/godot-logger
# Processing 663/758: Tappy Plane
#   Non-GitHub view files: https://gitlab.com/CesarLeon/TappyPlane
# Processing 664/758: TCG Layout (.NET only)
#   Success: https://github.com/Jaete/TCG-Hand-Layout
# Processing 665/758: Telegram Bot API
#   Success: https://github.com/fenix-hub/godot-engine.telegram-bot
# Processing 666/758: Template for Hole.io style games
#   Success: https://github.com/Go3DGoGodot/Hole.io-made-in-Godot
# Processing 667/758: Template for pathfinding games
#   Success: https://github.com/xolatgames/Pathfinding
# Processing 668/758: TemplateSaver
#   Success: https://github.com/D0RYU/TemplateSaver
# Processing 669/758: Terrain Editor
#   Success: https://github.com/Zylann/godot_terrain_plugin
# Processing 670/758: Texture Progress of Subunits
#   Success: https://github.com/JarLowrey/TextureProgressOfSubunits
# Processing 671/758: TextureButtonColored
#   Success: https://github.com/kenyoni-software/godot-addons
# Processing 672/758: TexturePacker Importer (SpriteSheet, AtlasTexture)
#   Success: https://github.com/CodeAndWeb/texturepacker-godot-plugin
# Processing 673/758: TexturePacker Importer (SpriteSheet, AtlasTexture, TileSet) for Godot 3
#   Success: https://github.com/CodeAndWeb/texturepacker-godot-plugin
# Processing 674/758: TexturePacker Importer (SpriteSheet, AtlasTexture, TileSet) for Godot 3.5
#   Success: https://github.com/CodeAndWeb/texturepacker-godot-plugin
# Processing 675/758: Third Person Controller
#   Success: https://github.com/WaffleAWT/Godot-4.3-Third-Person-Controller
# Processing 676/758: Third Person Controller
#   Success: https://github.com/Sombresonge/Third-Person-Controller
# Processing 677/758: ThrowOut
#   Non-GitHub view files: https://gitlab.com/tomsart/throwout
# Processing 678/758: TileSetCutter
#   Success: https://github.com/JeromeOrtali/TileSetCutter
# Processing 679/758: Todo Cards
#   Success: https://github.com/WhalesState/godot-todo-cards
# Processing 680/758: TODO Manager (Godot 3.x)
#   Success: https://github.com/OrigamiDev-Pete/TODO_Manager
# Processing 681/758: TODO Manager (Godot 4)
#   Success: https://github.com/OrigamiDev-Pete/TODO_Manager
# Processing 682/758: Toggle Code Generation
#   Success: https://github.com/zaevi/godot-toggle-code-generation
# Processing 683/758: TortoiseHg Mercurial Integration
#   Non-GitHub view files: https://bitbucket.org/lkokemohr/godot_tortoisehg_integration
# Processing 684/758: Tracer
#   Success: https://github.com/wyvernbw/tracer.gd
# Processing 685/758: Tracery
#   Success: https://github.com/Althar93/GDTracery
# Processing 686/758: TrailMesh
#   Success: https://github.com/tcmug/godot_trailmesh
# Processing 687/758: Transition Type Demo
#   Success: https://github.com/Ark2000/Trans-Type-Demo
# Processing 688/758: Translation editor
#   Success: https://github.com/Zylann/godot_translation_editor
# Processing 689/758: TrenchBroom Loader
#   Non-GitHub view files: https://git.mrag.nl/nimble/tbloader-addonlib
# Processing 690/758: Twin Stick 2D Shoot Em Up
#   Non-GitHub view files: https://git.crowdedgames.group/CatAClock/Twin-Stick-2D-Shoot-Em-Up
# Processing 691/758: Typed Dictionary NET
#   Success: https://github.com/PattyHoswell/Godot-NET-Typed-Dictionary
# Processing 692/758: UI-Expander
#   Success: https://github.com/omid3098/expander-addon
# Processing 693/758: UniParticles3D
#   Success: https://github.com/DanielSnd/UniParticles3D
# Processing 694/758: unirest gdscript
#   Success: https://github.com/fenix-hub/unirest-gdscript
# Processing 695/758: Universal Save/Load System
#   Success: https://github.com/stupidratstudio/thoth
# Processing 696/758: Useful Shader Nodes for Godot 4
#   Success: https://github.com/ReKylee/Useful-Shader-Nodes-for-Godot-4
# Processing 697/758: usefulScripts
#   Non-GitHub view files: https://gitlab.com/pointerstudio/kabk/godot/usefulScripts
# Processing 698/758: Vehicle Controller 2D
#   Success: https://github.com/ivanskodje-godotengine/Vehicle-Controller-2D
# Processing 699/758: vim-motion
#   Success: https://github.com/wovri-github/godot-vim-joshnajera
# Processing 700/758: Vircle
#   Non-GitHub view files: https://gitlab.com/Marty_Friedrich/vircle
# Processing 701/758: Virtual Analog
#   Non-GitHub view files: https://gitlab.com/mncrypticsilver/virtual-analog
# Processing 702/758: Visual Behavior Tree
#   Success: https://github.com/fian46/addons-btree
# Processing 703/758: Visual Script Circle Pop Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 704/758: Visual Script Multitouch View Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 705/758: Visual Shader Derive Z Node
#   Success: https://github.com/Foyezes/Godot-Derive-Z-Node
# Processing 706/758: Visual Shader Height Blend Node
#   Success: https://github.com/Foyezes/Godot-HeightBlend-Node
# Processing 707/758: Visual Shader Normal Combine Node
#   Success: https://github.com/Foyezes/Godot-Normal-Combine-Node
# Processing 708/758: Visual Shader Normal Strength Node
#   Success: https://github.com/Foyezes/Godot-Normal-Strength-Node
# Processing 709/758: Visual Shader Parallax Mapping Node
#   Success: https://github.com/Foyezes/Godot-Parallax-Mapping-Node
# Processing 710/758: Visual Shader Pixel Normal World Node
#   Success: https://github.com/Foyezes/Godot-Pixel-Normal-World-Node
# Processing 711/758: Visual Shader UV Manipulation Node
#   Success: https://github.com/Foyezes/Godot-UV-Manipulation-Node
# Processing 712/758: Visual Shader UV Nodes Pack
#   Success: https://github.com/Foyezes/Visual-Shader-UV-Nodes-Pack
# Processing 713/758: Visual Shader Vector Transform Node
#   Success: https://github.com/Foyezes/Godot-Vector-Transform-Node
# Processing 714/758: VOID
#   Success: https://github.com/dbiton/VOID
# Processing 715/758: Volume Sliders (Singleton example)
#   Success: https://github.com/ManuelArtz/Volume-Sliders-Singleton-example-
# Processing 716/758: Volumetric Fog
#   Success: https://github.com/Bauxitedev/volumetric-fog-demo
# Processing 717/758: VoronoiShatter - Procedurally fracture 3D meshes
#   Success: https://github.com/robertvaradan/voronoishatter
# Processing 718/758: VoxelOctree
#   Success: https://github.com/BraindeadBZH/VoxelOctreePlugin
# Processing 719/758: Vpainter
#   Success: https://github.com/nx7r/Vpainter
# Processing 720/758: VR Tools
#   Success: https://github.com/anunknowperson/godot-vr-tools
# Processing 721/758: VRM Importer and MToon Shader - Humanoid 3d Avatar Model Format
#   Success: https://github.com/V-Sekai/godot-vrm
# Processing 722/758: VRM Importer for 3D Avatars and MToon Shader
#   Success: https://github.com/V-Sekai/godot-vrm
# Processing 723/758: WAD Level Loader
#   Success: https://github.com/Chaosus/GDWADLevelLoader
# Processing 724/758: WAT - Unit Testing Framework
#   Success: https://github.com/CodeDarigan/WAT
# Processing 725/758: WAT Unit Testing Framework
#   Success: https://github.com/AlexDarigan/WAT
# Processing 726/758: WAT Unit Testing Framework (For Godot Mono)
#   Success: https://github.com/AlexDarigan/WAT
# Processing 727/758: Water shader
#   Success: https://github.com/faculezcano/godot-water-shader
# Processing 728/758: Waypoint Map
#   Non-GitHub view files: https://gitlab.com/victoriasmedley94/godotwaypointmap
# Processing 729/758: WCSpawnPool
#   Non-GitHub view files: https://gitlab.com/worstconcept/wcspawnpool
# Processing 730/758: Weather System
#   Non-GitHub view files: https://codeberg.org/matiaslavik/GodotWeatherSystem
# Processing 731/758: WebRTC and Nakama addon
#   Non-GitHub view files: https://gitlab.com/snopek-games/godot-nakama-webrtc
# Processing 732/758: WebRTC Minimal Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 733/758: WebRTC Signaling Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 734/758: WebSocket Chat Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 735/758: WebSocket Minimal Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 736/758: Websocket Multiplayer Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 737/758: Weeping Angel Example
#   Success: https://github.com/bypell/weeping-angel-godot
# Processing 738/758: Window Management Demo
#   Success: https://github.com/godotengine/godot-demo-projects
# Processing 739/758: WindowsV2
#   Success: https://github.com/brb-fr/windows-v2
# Processing 740/758: WIP 0.5 - Abstract State Machine Graphic (ASM)
#   Success: https://github.com/nonunknown/abstract-state-machine
# Processing 741/758: World of Alpheratz (Platformer Demo)
#   Success: https://github.com/Ark2000/world_of_alpheratz
# Processing 742/758: WPGTK Theme
#   Non-GitHub view files: https://git.bellsworne.tech/Bellsworne/wpgtk-godot
# Processing 743/758: xBRZ Screen-Filter
#   Success: https://github.com/LanzaSchneider/godot-xBRZ
# Processing 744/758: XMLReader
#   Success: https://github.com/ACB-prgm/XMLReader
# Processing 745/758: XR Browser (XR Fragments compatible)
#   Non-GitHub view files: https://codeberg.org/coderofsalvation/xrfragment-godot
# Processing 746/758: XRController Midi Player
#   Non-GitHub view files: https://gitlab.com/Cyberrebell/xr-controller-midi-player
# Processing 747/758: XSM 2.0 - eXtended State Machine
#   Non-GitHub view files: https://gitlab.com/atnb/xsm
# Processing 748/758: XSM 4
#   Non-GitHub view files: https://gitlab.com/atn_games/xsm2-g4
# Processing 749/758: XSM: eXtended State Machine
#   Non-GitHub view files: https://gitlab.com/atnb/xsm
# Processing 750/758: Xsolla SDK
#   Success: https://github.com/godot279/XsollaSDK
# Processing 751/758: Yamms - Yet another MultiMesh Scatter
#   Success: https://github.com/Mattiny/yamms
# Processing 752/758: Your Buil
#   Non-GitHub view files: https://codeberg.org/svetogam/yourbuil
# Processing 753/758: YouTube Sub Counter
#   Success: https://github.com/takelime/Godot-YouTube-API
# Processing 754/758: YouTube's button effect
#   Success: https://github.com/SpyrexDE/YoutubeButtonEffect
# Processing 755/758: Zalance SDK
#   Success: https://github.com/ZalanceInc/zalance-godot-sdk
# Processing 756/758: Zone Area2D Editor
#   Success: https://github.com/xphere/godot-zone
# Processing 757/758: Zoomy
#   Success: https://github.com/nobuyukinyuu/zoomy
# Processing 758/758: [DEPRECATED] Blockchain SDK by Enjin [DEPRECATED]
#   Success: https://github.com/enjin/enjin-godot-sdk
#
# === SAVING 579 GITHUB REPOS FROM VIEW FILES ===
#
# === SAVING 179 NON-GITHUB ASSETS (ALPHABETICAL) ===
# Step 2 complete

# %% [markdown]
# Step 3 - Create `raw_github_rankings.csv`

# %%
class GitHubAPI:
    def __init__(self):
        load_dotenv()
        self.token = os.getenv('GITHUB_TOKEN')
        if not self.token:
            raise ValueError("GITHUB_TOKEN environment variable not set")
        
        self.base_url = 'https://api.github.com'
        self.session = requests.Session()
        self.session.headers.update({
            'Authorization': f'Bearer {self.token}',
            'Accept': 'application/vnd.github+json',
            'X-GitHub-Api-Version': '2022-11-28',
            'User-Agent': 'GodotAssetAnalyzer/1.0'
        })
    
    def get_repo_stats(self, repo_path):
        api_url = f"{self.base_url}/repos/{repo_path}"
        
        try:
            response = self.session.get(api_url)
            
            print(f"    API Response: {response.status_code}")
            if 'X-RateLimit-Remaining' in response.headers:
                print(f"    Rate limit remaining: {response.headers['X-RateLimit-Remaining']}")
            
            if response.status_code == 403:
                print(f"    403 Error response: {response.text[:200]}")
                return {'stars': 0, 'forks': 0, 'last_updated': '', 'api_success': False, 'rate_limited': True}
            
            if response.status_code == 404:
                print(f"    Repository not found: {repo_path}")
                return {'stars': 0, 'forks': 0, 'last_updated': '', 'api_success': False}
            
            response.raise_for_status()
            data = response.json()
            
            return {
                'stars': data.get('stargazers_count', 0),
                'forks': data.get('forks_count', 0),
                'last_updated': data.get('updated_at', ''),
                'api_success': True
            }
        except Exception as e:
            print(f"  API error for {repo_path}: {e}")
            return {'stars': 0, 'forks': 0, 'last_updated': '', 'api_success': False}

# %%
def process_github_csvs():
    github_api = GitHubAPI()
    
    try:
        with open('github_api_progress.csv', 'r', encoding='utf-8') as f:
            reader = csv.DictReader(f)
            final_data = list(reader)
            processed_urls = {repo['github_url'] for repo in final_data}
            print(f"Resuming from checkpoint: {len(final_data)} already processed")
    except FileNotFoundError:
        final_data = []
        processed_urls = set()
    
    all_repos = []
    
    csv_files = ['assets_with_github.csv', 'github_from_viewfiles.csv']
    
    for csv_file in csv_files:
        try:
            with open(csv_file, 'r', encoding='utf-8') as f:
                reader = csv.DictReader(f)
                repos = list(reader)
                all_repos.extend(repos)
                print(f"Loaded {len(repos)} repos from {csv_file}")
        except FileNotFoundError:
            print(f"File {csv_file} not found, skipping")
    
    print(f"\nProcessing {len(all_repos)} total repositories...")
    
    for i, repo in enumerate(all_repos):
        github_url = repo.get('github_url', '')
        
        if github_url in processed_urls:
            print(f"Skipping {i+1}/{len(all_repos)}: {repo.get('title')} (already processed)")
            continue
            
        print(f"\nProcessing {i+1}/{len(all_repos)}: {repo.get('title', 'NO TITLE')}")
        
        github_repo = ''
        if github_url and 'github.com' in github_url:
            repo_match = re.search(r'github\.com/([^/]+/[^/]+)', github_url)
            if repo_match:
                github_repo = repo_match.group(1)
                github_repo = github_repo.split('/tree/')[0].split('/blob/')[0]
        
        if github_repo:
            print(f"  Making API call for {github_repo}")
            stats = github_api.get_repo_stats(github_repo)
            
            if stats.get('rate_limited'):
                print("Rate limit hit, stopping processing")
                break
            
            final_repo = {
                'title': repo.get('title', ''),
                'github_url': github_url,
                'github_repo': github_repo,
                'stars': stats['stars'],
                'forks': stats['forks'],
                'last_updated': stats['last_updated'],
                'category': repo.get('category', ''),
                'license': repo.get('license', ''),
                'author': repo.get('author', ''),
                'api_success': stats['api_success']
            }
            
            final_data.append(final_repo)
            processed_urls.add(github_url)
            print(f"  Stars: {stats['stars']}, Forks: {stats['forks']}, Success: {stats['api_success']}")
        else:
            print(f"  Could not extract github_repo from URL, skipping")
        
        if len(final_data) % 10 == 0:
            with open('github_api_progress.csv', 'w', newline='', encoding='utf-8') as f:
                if final_data:
                    writer = csv.DictWriter(f, fieldnames=final_data[0].keys())
                    writer.writeheader()
                    writer.writerows(final_data)
            print(f"  Checkpoint saved: {len(final_data)} repos processed")
        
        time.sleep(1.1)
    
    return final_data

final_repos = process_github_csvs()

print(f"\n=== SAVING {len(final_repos)} REPOS WITH RAW GITHUB DATA ===")
with open('raw_github_rankings.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(['title', 'github_url', 'github_repo', 'stars', 'forks', 'last_updated', 'category', 'license', 'author', 'api_success'])
    
    for repo in final_repos:
        writer.writerow([
            repo['title'],
            repo['github_url'],
            repo['github_repo'],
            repo['stars'],
            repo['forks'],
            repo['last_updated'],
            repo['category'],
            repo['license'],
            repo['author'],
            repo['api_success']
        ])

print("Step 3 complete - raw data with duplicates preserved")
# Out:
# Loaded 3217 repos from assets_with_github.csv
# Loaded 579 repos from github_from_viewfiles.csv
#
# Processing 3796 total repositories...
#
# Processing 1/3796: Godot Atlas Cutter
#   Making API call for newold3/Auto-Slice-Atlas
#     API Response: 200
#     Rate limit remaining: 4999
#   Stars: 8, Forks: 1, Success: True
#
# Processing 2/3796: Packed Scene Instantiater
#   Making API call for Lazy-Rabbit-2001/godot-addon-packed-scene-instantiater
#     API Response: 200
#     Rate limit remaining: 4998
#   Stars: 1, Forks: 0, Success: True
#
# Processing 3/3796: Takin Game Template
#   Making API call for TinyTakinTeller/TakinGodotTemplate
#     API Response: 200
#     Rate limit remaining: 4997
#   Stars: 306, Forks: 20, Success: True
#
# Processing 4/3796: Godot 3D Flight Control Tutorial
#   Making API call for UtMan88/Godot3DFlightControls
#     API Response: 200
#     Rate limit remaining: 4996
#   Stars: 11, Forks: 0, Success: True
#
# Processing 5/3796: Thirdperson Controller (.NET)
#   Making API call for vaporvee/gd-net-thirdpersoncontroller
#     API Response: 200
#     Rate limit remaining: 4995
#   Stars: 12, Forks: 3, Success: True
#
# Processing 6/3796: 3D Cross The Road Template
#   Making API call for vertexcube/3D-Cross-The-Road-Template
#     API Response: 404
#     Rate limit remaining: 4994
#     Repository not found: vertexcube/3D-Cross-The-Road-Template
#   Stars: 0, Forks: 0, Success: False
#
# Processing 7/3796: 3d Maze Generator
#   Making API call for mojoyup1528/maze_generator3D
#     API Response: 200
#     Rate limit remaining: 4993
#   Stars: 0, Forks: 0, Success: True
#
# Processing 8/3796: Alexandria - alexandria.netserver
#   Making API call for BtheDestroyer/godot-alexandria
#     API Response: 200
#     Rate limit remaining: 4991
#   Stars: 8, Forks: 0, Success: True
#
# Processing 9/3796: DungeonCrawler3D
#   Making API call for Rebelion-Board-game/DungonCrawler
#     API Response: 200
#     Rate limit remaining: 4990
#   Stars: 24, Forks: 2, Success: True
#
# Processing 10/3796: Follow Parent
#   Making API call for KarlTheCool/FollowParent
#     API Response: 200
#     Rate limit remaining: 4988
#   Stars: 6, Forks: 1, Success: True
#   Checkpoint saved: 10 repos processed
#
# Processing 11/3796: GdScript2All
#   Making API call for Lcbx/GdScript2All
#     API Response: 200
#     Rate limit remaining: 4987
#   Stars: 205, Forks: 7, Success: True
#
# Processing 12/3796: Godot Tiled Tools
#   Making API call for Frontrider/Godot-Tiled-Tools
#     API Response: 200
#     Rate limit remaining: 4986
#   Stars: 2, Forks: 0, Success: True
#
# Processing 13/3796: Godot-Spyglass
#   Making API call for NovaDC/Godot-Spyglass
#     API Response: 200
#     Rate limit remaining: 4985
#   Stars: 1, Forks: 1, Success: True
#
# Processing 14/3796: GodotTouchCamera
#   Making API call for DionHo/GodotTouchCamera
#     API Response: 200
#     Rate limit remaining: 4984
#   Stars: 5, Forks: 0, Success: True
#
# Processing 15/3796: Kenney's UI Audio
#   Making API call for Loppansson/kenney-ui-audio-for-godot
#     API Response: 200
#     Rate limit remaining: 4983
#   Stars: 3, Forks: 0, Success: True
#
# Processing 16/3796: localization_with_google_sheet
#   Making API call for palmasop/localization_with_google_sheet
#     API Response: 200
#     Rate limit remaining: 4982
#   Stars: 3, Forks: 0, Success: True
#
# Processing 17/3796: RhythmNotifier - Sync Your Game to the Beat of the Music (Sound & Audio)
#   Making API call for michaelgundlach/rhythm_notifier
#     API Response: 200
#     Rate limit remaining: 4981
#   Stars: 30, Forks: 5, Success: True
#
# Processing 18/3796: TextEditor Integration
#   Making API call for fenix-hub/godot-engine.text-editor
#     API Response: 200
#     Rate limit remaining: 4979
#   Stars: 144, Forks: 16, Success: True
#
# Processing 19/3796: TODO 4
#   Making API call for Vacui/TODO_4
#     API Response: 200
#     Rate limit remaining: 4978
#   Stars: 11, Forks: 0, Success: True
#
# Processing 20/3796: Virtual Joystick
#   Making API call for MarcoFazioRandom/Virtual-Joystick-Godot
#     API Response: 200
#     Rate limit remaining: 4977
#   Stars: 839, Forks: 87, Success: True
#   Checkpoint saved: 20 repos processed
#
# Processing 21/3796: Visibility shortcut
#   Making API call for Janders1800/godot-visibility-shortcut
#     API Response: 200
#     Rate limit remaining: 4976
#   Stars: 2, Forks: 0, Success: True
#
# Processing 22/3796: "Immersive" First Person Controller
#   Making API call for Levox98/Godot_First-Person-Controller
#     API Response: 200
#     Rate limit remaining: 4975
#   Stars: 43, Forks: 2, Success: True
#
# Processing 23/3796: .mtl loader
#   Making API call for Quakermann/.mtl-loader
#     API Response: 200
#     Rate limit remaining: 4973
#   Stars: 3, Forks: 1, Success: True
#
# Processing 24/3796: 1$ gesture recogniser and recorder
#   Making API call for blurymind/1dollar_gesture_recogniser
#     API Response: 200
#     Rate limit remaining: 4972
#   Stars: 9, Forks: 9, Success: True
#
# Processing 25/3796: 10 Simple Shader Examples (with Video)
#   Making API call for Goldenlion5648/ShaderExamplesWithVideo
#     API Response: 200
#     Rate limit remaining: 4971
#   Stars: 14, Forks: 6, Success: True
#
# Processing 26/3796: 10+ GDScript Tips Script (With Video)
#   Making API call for Goldenlion5648/GDScriptTipsForGodot
#     API Response: 200
#     Rate limit remaining: 4970
#   Stars: 2, Forks: 1, Success: True
#
# Processing 27/3796: 2, 4, 8 Godot-multidirectional-joystick
#   Making API call for JstnJrg/Godot_multidirectional_joystick
#     API Response: 200
#     Rate limit remaining: 4969
#   Stars: 16, Forks: 0, Success: True
#
# Processing 28/3796: 2.5D Demo
#   Making API call for godotengine/godot-demo-projects
#     API Response: 200
#     Rate limit remaining: 4968
#   Stars: 6935, Forks: 1834, Success: True
# Skipping 29/3796: 2.5D Game Demo (already processed)
#
# Processing 30/3796: 2D Action Compute Resource
#   Making API call for KijouShihona/2DActionComputeResource
#     API Response: 200
#     Rate limit remaining: 4967
#   Stars: 0, Forks: 0, Success: True
# Skipping 31/3796: 2D Bullet Shower Demo (already processed)
#
# Processing 32/3796: 2D Camera Controller - Multitarget follow + FXs
#   Making API call for AsyncStudio/godot-smartcamera-2d
#     API Response: 200
#     Rate limit remaining: 4966
#   Stars: 1, Forks: 0, Success: True
#   Checkpoint saved: 30 repos processed
#
# Processing 33/3796: 2D Controls Toolkit
#   Making API call for CiaNCI-Studio/2D-Controls-Toolkit
#     API Response: 200
#     Rate limit remaining: 4965
#   Stars: 4, Forks: 0, Success: True
#
# Processing 34/3796: 2D CRPG Character Controller
#   Making API call for genderfreak/godot-2d-crpg-character-controller
#     API Response: 200
#     Rate limit remaining: 4964
#   Stars: 9, Forks: 0, Success: True
#
# Processing 35/3796: 2D drawing by code (gdscript)
#   Making API call for aiafrasinei/godot_2d_draw_by_code
#     API Response: 200
#     Rate limit remaining: 4963
#   Stars: 4, Forks: 0, Success: True
#
# Processing 36/3796: 2D Editor Light Toggle
#   Making API call for aXu-AP/LightToggle2D
#     API Response: 200
#     Rate limit remaining: 4962
#   Stars: 0, Forks: 0, Success: True
#
# Processing 37/3796: 2D grid based movement
#   Making API call for IconocatStudio/godot2dgridmovement
#     API Response: 200
#     Rate limit remaining: 4961
#   Stars: 12, Forks: 2, Success: True
#
# Processing 38/3796: 2D Hexagon TileMapLayer Navigation Class
#   Making API call for DubiousDuck/hexagon-2d-navigation-godot
#     API Response: 200
#     Rate limit remaining: 4960
#   Stars: 7, Forks: 1, Success: True
#
# Processing 39/3796: 2D Hexagonal Map Navigation Demo
#   Making API call for Dimithrandir/godot_2d_hex_map_nav_demo
#     API Response: 200
#     Rate limit remaining: 4959
#   Stars: 13, Forks: 2, Success: True
# Skipping 40/3796: 2D in 3D Viewport Demo (already processed)
# Skipping 41/3796: 2D Lights and Shadows Demo (already processed)
# Skipping 42/3796: 2D Lights as Mask Demo (already processed)
#
# Processing 43/3796: 2D Liquid Simulator
#   Making API call for L-Marcel/2D-Liquid-Simulator
#     API Response: 200
#     Rate limit remaining: 4958
#   Stars: 18, Forks: 1, Success: True
# Skipping 44/3796: 2D Liquid Simulator - 4.3+ (already processed)
# Skipping 45/3796: 2D Particles Demo (already processed)
# Skipping 46/3796: 2D Physics Tests Demo (already processed)
# Skipping 47/3796: 2D Physics Tests Demo (already processed)
#
# Processing 48/3796: 2D Planar Movement
#   Making API call for steventrouble/godot-8dir
#     API Response: 200
#     Rate limit remaining: 4957
#   Stars: 2, Forks: 2, Success: True
#
# Processing 49/3796: 2D Platformer - Starter Kit
#   Making API call for AdilDevStuff/2D-Platformer-Starter-Kit
#     API Response: 200
#     Rate limit remaining: 4956
#   Stars: 22, Forks: 6, Success: True
#   Checkpoint saved: 40 repos processed
# Skipping 50/3796: 2D Platformer Demo (already processed)
#
# Processing 51/3796: 2D Platformer Toolkit
#   Making API call for finn753/platformer-toolkit
#     API Response: 200
#     Rate limit remaining: 4955
#   Stars: 23, Forks: 6, Success: True
#
# Processing 52/3796: 2D Procedural Map Generator
#   Making API call for DereferenceMyPointer/2D-Map-Generator
#     API Response: 200
#     Rate limit remaining: 4954
#   Stars: 3, Forks: 0, Success: True
#
# Processing 53/3796: 2D Revealer
#   Making API call for delVhariant/2d-revealer-godot
#     API Response: 200
#     Rate limit remaining: 4953
#   Stars: 2, Forks: 0, Success: True
#
# Processing 54/3796: 2D Shapes
#   Making API call for TechnocatDev/2d-shapes
#     API Response: 200
#     Rate limit remaining: 4952
#   Stars: 29, Forks: 1, Success: True
#
# Processing 55/3796: 2D Strategy Camera
#   Making API call for Thomas737/godot-strategy-camera
#     API Response: 200
#     Rate limit remaining: 4951
#   Stars: 1, Forks: 0, Success: True
#
# Processing 56/3796: 2D Tactical RPG Demo
#   Making API call for HopeMetal/2DTacticalRPGDemo
#     API Response: 200
#     Rate limit remaining: 4950
#   Stars: 25, Forks: 4, Success: True
#
# Processing 57/3796: 2D Train/Railroad Demo
#   Making API call for moonbench/simple-godot-train
#     API Response: 200
#     Rate limit remaining: 4949
#   Stars: 118, Forks: 15, Success: True
# Skipping 58/3796: 2D Train/Railroad Demo (already processed)
#
# Processing 59/3796: 2D Wheeled Vehicle Template
#   Making API call for vrojak/godot-wheeled-vehicle-template
#     API Response: 200
#     Rate limit remaining: 4947
#   Stars: 30, Forks: 5, Success: True
#
# Processing 60/3796: 2DLights-Benchmark-Demo
#   Making API call for TheDuriel/Godot-2DLights-Benchmark
#     API Response: 200
#     Rate limit remaining: 4946
#   Stars: 28, Forks: 2, Success: True
# Skipping 61/3796: 3D Anti-Aliasing Demo (already processed)
#
# Processing 62/3796: 3D asset pack preview renederer
#   Making API call for aitordsgn03/Asset-Pack-Preview-Generator
#     API Response: 200
#     Rate limit remaining: 4945
#   Stars: 3, Forks: 0, Success: True
#   Checkpoint saved: 50 repos processed
#
# Processing 63/3796: 3D Auto Collision Generator
#   Making API call for ThGnommy/godot_3d_auto_collision_generator
#     API Response: 200
#     Rate limit remaining: 4944
#   Stars: 57, Forks: 5, Success: True
#
# Processing 64/3796: 3D Basis Workspace
#   Making API call for aftrosrs/Basic3DSetup
#     API Response: 200
#     Rate limit remaining: 4943
#   Stars: 2, Forks: 0, Success: True
#
# Processing 65/3796: 3D Car with Settingspanel
#   Making API call for BeytoA/3D-Car-With-Settingspanel
#     API Response: 200
#     Rate limit remaining: 4942
#   Stars: 26, Forks: 4, Success: True
#
# Processing 66/3796: 3D Controls Toolkit
#   Making API call for CiaNCI-Studio/3D-Controls-Toolkit
#     API Response: 200
#     Rate limit remaining: 4941
#   Stars: 20, Forks: 1, Success: True
#
# Processing 67/3796: 3D Destructible Procedural Smooth Terrain
#   Making API call for alpapaydin/Godot4-3D-Smooth-Destructible-Terrain
#     API Response: 200
#     Rate limit remaining: 4940
#   Stars: 22, Forks: 3, Success: True
#
# Processing 68/3796: 3D Enemy Toolkit
#   Making API call for CiaNCI-Studio/3D-Enemy-Toolkit
#     API Response: 200
#     Rate limit remaining: 4939
#   Stars: 18, Forks: 2, Success: True
#
# Processing 69/3796: 3D First Person WASD Input Actions
#   Making API call for BoQsc/Godot-WASD_Input_Setup_for_first-person-POV
#     API Response: 200
#     Rate limit remaining: 4938
#   Stars: 0, Forks: 0, Success: True
#
# Processing 70/3796: 3D Gallery
#   Making API call for citizenken/godot-3d-gallery
#     API Response: 200
#     Rate limit remaining: 4937
#   Stars: 3, Forks: 0, Success: True
#
# Processing 71/3796: 3D Gizmo Tool
#   Making API call for BuckWildGames/Godot4xGizmo
#     API Response: 200
#     Rate limit remaining: 4936
#   Stars: 1, Forks: 1, Success: True
# Skipping 72/3796: 3D Global Illumination Demo (already processed)
# Skipping 73/3796: 3D Graphics Settings Demo (already processed)
#
# Processing 74/3796: 3D GridMap and non GridMap Navmesh Demos
#   Making API call for Victoralm/AGridMap_Pathfollow
#     API Response: 200
#     Rate limit remaining: 4935
#   Stars: 8, Forks: 0, Success: True
#   Checkpoint saved: 60 repos processed
# Skipping 75/3796: 3D in 2D Viewport demo (already processed)
# Skipping 76/3796: 3D Kinematic Character Demo (already processed)
# Skipping 77/3796: 3D Labels and Texts Demo (already processed)
# Skipping 78/3796: 3D Lights and Shadows Demo (already processed)
#
# Processing 79/3796: 3D Low-Poly Exterior Plants
#   Making API call for Malcolmnixon/Shapespark-Low-Poly-Exterior-Plants
#     API Response: 200
#     Rate limit remaining: 4934
#   Stars: 10, Forks: 2, Success: True
#
# Processing 80/3796: 3d Male Base Mesh
#   Making API call for BoQsc/Godot-Male-Base-Mesh
#     API Response: 200
#     Rate limit remaining: 4932
#   Stars: 0, Forks: 0, Success: True
#
# Processing 81/3796: 3D Multiplayer Bobmerman
#   Making API call for Prime-Eight/cautious-guacamole
#     API Response: 200
#     Rate limit remaining: 4931
#   Stars: 10, Forks: 1, Success: True
# Skipping 82/3796: 3D Navigation Demo (already processed)
#
# Processing 83/3796: 3D Node Graph
#   Making API call for walksanatora/GodotNodeGraph3D
#     API Response: 200
#     Rate limit remaining: 4930
#   Stars: 1, Forks: 0, Success: True
#
# Processing 84/3796: 3D Outline
#   Making API call for Reisflocke/godot-3d-outline
#     API Response: 200
#     Rate limit remaining: 4929
#   Stars: 15, Forks: 5, Success: True
# Skipping 85/3796: 3D Particles Demo (already processed)
# Skipping 86/3796: 3D Physics Tests Demo (already processed)
# Skipping 87/3796: 3D Physics Tests Demo (already processed)
#
# Processing 88/3796: 3D Pixel-Perfect Outline
#   Making API call for LanzaSchneider/godot-3d_pixel_perfect_outline
#     API Response: 200
#     Rate limit remaining: 4928
#   Stars: 17, Forks: 3, Success: True
#
# Processing 89/3796: 3D Planet Generator
#   Making API call for remijean/godot-3d-planet-generator
#     API Response: 200
#     Rate limit remaining: 4927
#   Stars: 47, Forks: 4, Success: True
#
# Processing 90/3796: 3D Platform Template
#   Making API call for vertexcube/3D_Platform_Template
#     API Response: 404
#     Rate limit remaining: 4926
#     Repository not found: vertexcube/3D_Platform_Template
#   Stars: 0, Forks: 0, Success: False
#
# Processing 91/3796: 3D Platformer Robot
#   Making API call for AGChow/3D-Godot-Robot-Platformer-Character
#     API Response: 200
#     Rate limit remaining: 4925
#   Stars: 36, Forks: 2, Success: True
#
# Processing 92/3796: 3D reflecting laser Godot.
#   Making API call for Remysaurus/GodotReflectingLaser3D
#     API Response: 200
#     Rate limit remaining: 4924
#   Stars: 5, Forks: 1, Success: True
#   Checkpoint saved: 70 repos processed
#
# Processing 93/3796: 3D Refraction Shader
#   Making API call for NathanWarden/godot_refraction_shader
#     API Response: 200
#     Rate limit remaining: 4923
#   Stars: 4, Forks: 2, Success: True
# Skipping 94/3796: 3D Resolution Scaling Demo (already processed)
# Skipping 95/3796: 3D RigidBody Character Demo (already processed)
#
# Processing 96/3796: 3d Rotate Direct Constant Smooth
#   Making API call for JohnnyRouddro/3d_rotate_direct_constant_smooth
#     API Response: 200
#     Rate limit remaining: 4922
#   Stars: 18, Forks: 3, Success: True
#
# Processing 97/3796: 3D RTS Camera
#   Making API call for EmilHakala/3D-RTS-Camera
#     API Response: 200
#     Rate limit remaining: 4921
#   Stars: 12, Forks: 1, Success: True
#
# Processing 98/3796: 3D Shooter Kit
#   Making API call for CiaNCI-Studio/ShooterKit
#     API Response: 200
#     Rate limit remaining: 4920
#   Stars: 1, Forks: 0, Success: True
#
# Processing 99/3796: 3D Targeting System
#   Making API call for JohnnyRouddro/Godot_3D_Targeting_System
#     API Response: 200
#     Rate limit remaining: 4919
#   Stars: 13, Forks: 4, Success: True
#
# Processing 100/3796: 3D Targeting System Ultimate
#   Making API call for kreaninw/3D-Targeting-Syetem-Ultimate
#     API Response: 200
#     Rate limit remaining: 4917
#   Stars: 5, Forks: 2, Success: True
#
# Processing 101/3796: 3D Text Plugin
#   Making API call for SIsilicon/Godot-3D-text-plugin
#     API Response: 200
#     Rate limit remaining: 4916
#   Stars: 86, Forks: 9, Success: True
# Skipping 102/3796: 3D Viewport Scaling Demo (already processed)
#
# Processing 103/3796: 3D Visualized Path
#   Making API call for markeel/godot-vizpath
#     API Response: 200
#     Rate limit remaining: 4915
#   Stars: 14, Forks: 1, Success: True
# Skipping 104/3796: 3D Voxel Demo (already processed)
#
# Processing 105/3796: 3D Water Surface
#   Making API call for khairul169/3d-simplewater
#     API Response: 200
#     Rate limit remaining: 4914
#   Stars: 28, Forks: 5, Success: True
# Skipping 106/3796: 3D Waypoints Demo (already processed)
# Skipping 107/3796: 3D Waypoints Demo (already processed)
#
# Processing 108/3796: 3DCamera for Fighing Game
#   Making API call for GatitoMimoso00/3D-Fighting-Camera
#     API Response: 200
#     Rate limit remaining: 4913
#   Stars: 1, Forks: 0, Success: True
#   Checkpoint saved: 80 repos processed
#
# Processing 109/3796: 4-Directional Animation
#   Making API call for mechPenSketch/4-dir_Anim
#     API Response: 200
#     Rate limit remaining: 4912
#   Stars: 0, Forks: 0, Success: True
#
# Processing 110/3796: 4.1+ Discord  RPC / Editor Presence Plugin
#   Making API call for vaporvee/discord-rpc-godot
#     API Response: 200
#     Rate limit remaining: 4911
#   Stars: 222, Forks: 12, Success: True
#
# Processing 111/3796: A Dialogue Box
#   Making API call for Divirad/ADialogueBox
#     API Response: 200
#     Rate limit remaining: 4910
#   Stars: 6, Forks: 1, Success: True
#
# Processing 112/3796: a mole game
#   Making API call for lulersoft/godot_mole_game
#     API Response: 200
#     Rate limit remaining: 4909
#   Stars: 17, Forks: 8, Success: True
#
# Processing 113/3796: Abandoned Spaceship Demo
#   Making API call for perfoon/Abandoned-Spaceship-Godot-Demo
#     API Response: 200
#     Rate limit remaining: 4908
#   Stars: 329, Forks: 23, Success: True
#
# Processing 114/3796: About Dialog
#   Making API call for NovaDC/Godot-About-Dialog
#     API Response: 200
#     Rate limit remaining: 4907
#   Stars: 1, Forks: 0, Success: True
#
# Processing 115/3796: Acrylic Glass
#   Making API call for pattlebass/Godot-Acrylic
#     API Response: 200
#     Rate limit remaining: 4906
#   Stars: 12, Forks: 0, Success: True
# Skipping 116/3796: Acrylic Glass (already processed)
#
# Processing 117/3796: Action Behavior Tree
#   Making API call for gsioteam/action_behavior_tree
#     API Response: 200
#     Rate limit remaining: 4905
#   Stars: 22, Forks: 1, Success: True
#
# Processing 118/3796: Action Command
#   Making API call for gsioteam/ActionCommand
#     API Response: 200
#     Rate limit remaining: 4904
#   Stars: 2, Forks: 0, Success: True
#
# Processing 119/3796: Action Icon
#   Making API call for KoBeWi/Godot-Action-Icon
#     API Response: 200
#     Rate limit remaining: 4903
#   Stars: 78, Forks: 9, Success: True
#   Checkpoint saved: 90 repos processed
# Skipping 120/3796: Action Icon (already processed)
#
# Processing 121/3796: Action List
#   Making API call for acegiak/Godot4-Action-List
#     API Response: 200
#     Rate limit remaining: 4902
#   Stars: 3, Forks: 0, Success: True
#
# Processing 122/3796: ActionButton
#   Making API call for HappyHeads/ActionButton
#     API Response: 200
#     Rate limit remaining: 4901
#   Stars: 12, Forks: 2, Success: True
#
# Processing 123/3796: ActionReaction
#   Making API call for SrColoma/ActionReaction
#     API Response: 200
#     Rate limit remaining: 4900
#   Stars: 3, Forks: 2, Success: True
#
# Processing 124/3796: Active Rigid Body Ragdolls
#   Making API call for R3X-G1L6AME5H/Godot-Active-Ragdolls
#     API Response: 200
#     Rate limit remaining: 4899
#   Stars: 57, Forks: 5, Success: True
#
# Processing 125/3796: ADB Helper
#   Making API call for DevinPentecost/godot-adb-helper
#     API Response: 200
#     Rate limit remaining: 4898
#   Stars: 2, Forks: 1, Success: True
#
# Processing 126/3796: Additional APIs
#   Making API call for Tio-Henry/Additional-APIs
#     API Response: 200
#     Rate limit remaining: 4897
#   Stars: 2, Forks: 0, Success: True
#
# Processing 127/3796: Addon Toggler
#   Making API call for etherealxx/godot-addon-toggler
#     API Response: 200
#     Rate limit remaining: 4896
#   Stars: 2, Forks: 0, Success: True
#
# Processing 128/3796: AddonSave
#   Making API call for Can202/godot_save
#     API Response: 200
#     Rate limit remaining: 4895
#   Stars: 4, Forks: 3, Success: True
# Skipping 129/3796: Addonsave (4.1) (already processed)
#
# Processing 130/3796: Adivery Plugin
#   Making API call for DexterFstone/godot-adivery
#     API Response: 200
#     Rate limit remaining: 4894
#   Stars: 8, Forks: 0, Success: True
#
# Processing 131/3796: Advanced Character
#   Making API call for Ieida/rigid_character_body_3d
#     API Response: 200
#     Rate limit remaining: 4893
#   Stars: 16, Forks: 0, Success: True
#   Checkpoint saved: 100 repos processed
#
# Processing 132/3796: Advanced FPS Controller Template
#   Making API call for Jeh3no/Godot-Advanced-FPS-Controller-Template
#     API Response: 200
#     Rate limit remaining: 4892
#   Stars: 47, Forks: 5, Success: True
#
# Processing 133/3796: Advanced Movement System Godot (AMSG) Template
#   Making API call for ywmaa/Advanced-Movement-System-Godot
#     API Response: 200
#     Rate limit remaining: 4891
#   Stars: 490, Forks: 39, Success: True
#
# Processing 134/3796: Advanced Radial Menu
#   Making API call for diklor/advanced_radial_menu
#     API Response: 200
#     Rate limit remaining: 4890
#   Stars: 51, Forks: 8, Success: True
#
# Processing 135/3796: Advanced Random Stuff
#   Making API call for don-tnowe/godot-advanced-random
#     API Response: 200
#     Rate limit remaining: 4889
#   Stars: 19, Forks: 2, Success: True
# Skipping 136/3796: Advanced Random Stuff (already processed)
#
# Processing 137/3796: Advanced Rich Text Label
#   Making API call for DazzlePixel/Advanced-Rich-Text-Label
#     API Response: 200
#     Rate limit remaining: 4888
#   Stars: 0, Forks: 0, Success: True
#
# Processing 138/3796: Advanced Save System
#   Making API call for rdmtt/Godot-3.1-Advanced-Save-System
#     API Response: 200
#     Rate limit remaining: 4887
#   Stars: 67, Forks: 3, Success: True
#
# Processing 139/3796: Advanced Search
#   Making API call for media/Patchcoat
#     API Response: 404
#     Rate limit remaining: 4886
#     Repository not found: media/Patchcoat
#   Stars: 0, Forks: 0, Success: False
#
# Processing 140/3796: AdvancedText
#   Making API call for rakugoteam/AdvancedText
#     API Response: 200
#     Rate limit remaining: 4885
#   Stars: 36, Forks: 3, Success: True
#
# Processing 141/3796: Agar.io
#   Making API call for mbMayer/Godot-Agar.io
#     API Response: 200
#     Rate limit remaining: 4884
#   Stars: 0, Forks: 1, Success: True
#
# Processing 142/3796: Agones SDK Plugin
#   Making API call for AndreMicheletti/godot-agones-sdk
#     API Response: 200
#     Rate limit remaining: 4883
#   Stars: 74, Forks: 6, Success: True
#   Checkpoint saved: 110 repos processed
#
# Processing 143/3796: AI Assistant Hub
#   Making API call for FlamxGames/godot-ai-assistant-hub
#     API Response: 200
#     Rate limit remaining: 4882
#   Stars: 70, Forks: 9, Success: True
#
# Processing 144/3796: AI Context Generator
#   Making API call for rainlizard/AI-Context-Generator
#     API Response: 200
#     Rate limit remaining: 4881
#   Stars: 9, Forks: 0, Success: True
#
# Processing 145/3796: AI dialog generator plugin
#   Making API call for krishsharma0413/godot-AI-Dialog
#     API Response: 200
#     Rate limit remaining: 4880
#   Stars: 9, Forks: 0, Success: True
#
# Processing 146/3796: AI Horde Client
#   Making API call for Haidra-Org/AI-Horde-Client-Addon
#     API Response: 200
#     Rate limit remaining: 4878
#   Stars: 65, Forks: 11, Success: True
#
# Processing 147/3796: AI Use Cases Demo (With Video)
#   Making API call for Goldenlion5648/AIShowcaseForGames
#     API Response: 200
#     Rate limit remaining: 4877
#   Stars: 5, Forks: 0, Success: True
#
# Processing 148/3796: AI Voices/Dialogues Generator (AllTalk_TTS)
#   Making API call for anthonyc06/GodotAIVoices
#     API Response: 200
#     Rate limit remaining: 4876
#   Stars: 5, Forks: 1, Success: True
#
# Processing 149/3796: Aircraft
#   Making API call for wmigor/godot-aircraft-plugin
#     API Response: 200
#     Rate limit remaining: 4875
#   Stars: 2, Forks: 0, Success: True
# Skipping 150/3796: Alexandria - alexandria.db (already processed)
# Skipping 151/3796: Alexandria - alexandria.netclient (already processed)
#
# Processing 152/3796: Algodot
#   Making API call for lucasvanmol/algodot
#     API Response: 200
#     Rate limit remaining: 4874
#   Stars: 5, Forks: 1, Success: True
#
# Processing 153/3796: AlienNation
#   Making API call for katcho10/AlienNation
#     API Response: 200
#     Rate limit remaining: 4873
#   Stars: 3, Forks: 0, Success: True
#
# Processing 154/3796: Alignment Tool
#   Making API call for zaevi/godot-alignment-tool
#     API Response: 200
#     Rate limit remaining: 4872
#   Stars: 18, Forks: 4, Success: True
#   Checkpoint saved: 120 repos processed
#
# Processing 155/3796: All Projectiles
#   Making API call for OscarVezz/all-projectiles
#     API Response: 200
#     Rate limit remaining: 4871
#   Stars: 45, Forks: 1, Success: True
#
# Processing 156/3796: AllSky Free
#   Making API call for rpgwhitelock/AllSkyFree_Godot
#     API Response: 200
#     Rate limit remaining: 4870
#   Stars: 338, Forks: 21, Success: True
#
# Processing 157/3796: AlphaOS
#   Making API call for KoreTeknology/AlphaOS
#     API Response: 200
#     Rate limit remaining: 4869
#   Stars: 26, Forks: 1, Success: True
#
# Processing 158/3796: AlternativeTimer
#   Making API call for pokeparadox/VisaudFx
#     API Response: 200
#     Rate limit remaining: 4868
#   Stars: 0, Forks: 0, Success: True
#
# Processing 159/3796: Alys - Precision Platformer
#   Making API call for godotessentials/alys
#     API Response: 200
#     Rate limit remaining: 4866
#   Stars: 55, Forks: 10, Success: True
#
# Processing 160/3796: ambientcg
#   Making API call for mohsenph69/godot-ambientcg
#     API Response: 200
#     Rate limit remaining: 4865
#   Stars: 7, Forks: 0, Success: True
#
# Processing 161/3796: AmbientCG Material Downloader (Godot 4.3)
#   Making API call for VenitStudios/AmbientCG
#     API Response: 200
#     Rate limit remaining: 4864
#   Stars: 13, Forks: 1, Success: True
#
# Processing 162/3796: AMC Forth
#   Making API call for Eccentric-Anomalies/AMC-Forth
#     API Response: 200
#     Rate limit remaining: 4863
#   Stars: 11, Forks: 0, Success: True
#
# Processing 163/3796: AMP (Adaptive Music Player)
#   Making API call for DatLycan/AMP
#     API Response: 200
#     Rate limit remaining: 4861
#   Stars: 20, Forks: 2, Success: True
#
# Processing 164/3796: Anaglyph Camera
#   Making API call for SIsilicon/Godot-Anaglyph-Camera
#     API Response: 200
#     Rate limit remaining: 4860
#   Stars: 10, Forks: 2, Success: True
#   Checkpoint saved: 130 repos processed
#
# Processing 165/3796: Analog Control
#   Making API call for matheus-s-arruda/joystick_Plugin_Godot_Engine
#     API Response: 200
#     Rate limit remaining: 4859
#   Stars: 4, Forks: 0, Success: True
#
# Processing 166/3796: Analog Controller
#   Making API call for thiagobruno/godot_analogcontroller
#     API Response: 200
#     Rate limit remaining: 4857
#   Stars: 24, Forks: 3, Success: True
#
# Processing 167/3796: Analog Stick
#   Making API call for sami8github/Godot-Analog-Stick
#     API Response: 200
#     Rate limit remaining: 4856
#   Stars: 11, Forks: 4, Success: True
#
# Processing 168/3796: Analog Touch Control
#   Making API call for CiaNCI-Studio/AnalogTouchControl
#     API Response: 200
#     Rate limit remaining: 4855
#   Stars: 0, Forks: 0, Success: True
#
# Processing 169/3796: AnchorsOnlyPreset
#   Making API call for user-attachments/assets
#     API Response: 404
#     Rate limit remaining: 4854
#     Repository not found: user-attachments/assets
#   Stars: 0, Forks: 0, Success: False
#
# Processing 170/3796: Android Admob Plugin
#   Making API call for cengiz-pz/godot-android-admob-plugin
#     API Response: 200
#     Rate limit remaining: 4853
#   Stars: 58, Forks: 11, Success: True
#
# Processing 171/3796: Android Billing Godot Plugin
#   Making API call for code-with-max/godot-google-play-iapp
#     API Response: 200
#     Rate limit remaining: 4852
#   Stars: 67, Forks: 6, Success: True
#
# Processing 172/3796: Android Deeplink Plugin
#   Making API call for cengiz-pz/godot-android-deeplink-plugin
#     API Response: 200
#     Rate limit remaining: 4851
#   Stars: 19, Forks: 4, Success: True
#
# Processing 173/3796: Android Haptics
#   Making API call for Mobuos/godot-android-haptics
#     API Response: 200
#     Rate limit remaining: 4850
#   Stars: 7, Forks: 0, Success: True
# Skipping 174/3796: Android IAP Demo with C# (already processed)
# Skipping 175/3796: Android In-App Purchases (IAP) Demo (already processed)
#
# Processing 176/3796: Android In-app Review Plugin
#   Making API call for cengiz-pz/godot-android-inapp-review-plugin
#     API Response: 200
#     Rate limit remaining: 4849
#   Stars: 27, Forks: 4, Success: True
#   Checkpoint saved: 140 repos processed
#
# Processing 177/3796: Android Internet Connection State Plugin
#   Making API call for MeroVinggen/Godot-AndroidInternetConnectionStatePlugin
#     API Response: 200
#     Rate limit remaining: 4848
#   Stars: 4, Forks: 2, Success: True
#
# Processing 178/3796: Android Notification Scheduler Plugin
#   Making API call for cengiz-pz/godot-android-notification-scheduler-plugin
#     API Response: 200
#     Rate limit remaining: 4847
#   Stars: 38, Forks: 8, Success: True
#
# Processing 179/3796: Android RMB Emulator
#   Making API call for MuffinInACup/ARMBE
#     API Response: 200
#     Rate limit remaining: 4846
#   Stars: 0, Forks: 0, Success: True
#
# Processing 180/3796: Android Share Plugin
#   Making API call for cengiz-pz/godot-android-share-plugin
#     API Response: 200
#     Rate limit remaining: 4845
#   Stars: 24, Forks: 5, Success: True
#
# Processing 181/3796: Android System Bar Color Changer
#   Making API call for syntaxerror247/godot-android-system-bar-color-changer
#     API Response: 200
#     Rate limit remaining: 4844
#   Stars: 26, Forks: 2, Success: True
#
# Processing 182/3796: AndroidSystemBarControl
#   Making API call for minami110/godot-signal-extensions
#     API Response: 200
#     Rate limit remaining: 4843
#   Stars: 9, Forks: 0, Success: True
#
# Processing 183/3796: Anima for Godot 4
#   Making API call for ceceppa/anima
#     API Response: 200
#     Rate limit remaining: 4842
#   Stars: 735, Forks: 24, Success: True
#
# Processing 184/3796: Animated Camera
#   Making API call for x1212/godot_animated_camera
#     API Response: 200
#     Rate limit remaining: 4841
#   Stars: 4, Forks: 1, Success: True
#
# Processing 185/3796: Animated Control Node
#   Making API call for toafloast/godot-AnimatedControl
#     API Response: 200
#     Rate limit remaining: 4840
#   Stars: 3, Forks: 0, Success: True
#
# Processing 186/3796: Animated Grid Container
#   Making API call for gmarais/AnimatedGridContainerPlugin
#     API Response: 200
#     Rate limit remaining: 4839
#   Stars: 16, Forks: 3, Success: True
#   Checkpoint saved: 150 repos processed
#
# Processing 187/3796: Animated Shape 2D
#   Making API call for Goutte/godot-addon-animated-shape-2d
#     API Response: 200
#     Rate limit remaining: 4838
#   Stars: 168, Forks: 2, Success: True
#
# Processing 188/3796: Animated Sprite to Animation Player Convertor
#   Making API call for poohcom1/godot-animated-sprite-2-player
#     API Response: 200
#     Rate limit remaining: 4837
#   Stars: 62, Forks: 5, Success: True
# Skipping 189/3796: Animated Sprite to Animation Player Convertor 4.0 (already processed)
#
# Processing 190/3796: Animated Text
#   Making API call for IndigoBeetle/godot_animated_text
#     API Response: 200
#     Rate limit remaining: 4836
#   Stars: 5, Forks: 0, Success: True
#
# Processing 191/3796: Animated Tiled Skybox
#   Making API call for pythoncoder83/animated-tiled-skybox
#     API Response: 200
#     Rate limit remaining: 4835
#   Stars: 0, Forks: 0, Success: True
#
# Processing 192/3796: AnimatedButton
#   Making API call for AdilDevStuff/AnimatedButton
#     API Response: 200
#     Rate limit remaining: 4834
#   Stars: 9, Forks: 0, Success: True
#
# Processing 193/3796: Animation Node Redirector
#   Making API call for DangerousWhenWet/animation-node-redirector
#     API Response: 200
#     Rate limit remaining: 4833
#   Stars: 2, Forks: 1, Success: True
#
# Processing 194/3796: Animation Resetter
#   Making API call for timothyqiu/godot-animation-resetter
#     API Response: 200
#     Rate limit remaining: 4832
#   Stars: 22, Forks: 3, Success: True
#
# Processing 195/3796: Animation Slider
#   Making API call for andrew-wilkes/godot-animation-slider
#     API Response: 200
#     Rate limit remaining: 4831
#   Stars: 3, Forks: 1, Success: True
# Skipping 196/3796: Animation Slider (already processed)
#
# Processing 197/3796: AnimationPlayer frames times in Milliseconds
#   Making API call for dannygaray60/animationplayer-framedata-ms-godot
#     API Response: 200
#     Rate limit remaining: 4830
#   Stars: 4, Forks: 1, Success: True
#
# Processing 198/3796: AnimationPlayer Refactor
#   Making API call for poohcom1/godot-animation-player-refactor
#     API Response: 200
#     Rate limit remaining: 4829
#   Stars: 138, Forks: 6, Success: True
#   Checkpoint saved: 160 repos processed
#
# Processing 199/3796: AnimationPlayer SpriteFrames Helper
#   Making API call for KikimoraGames/godot_animationplayer_spriteframes_helper
#     API Response: 200
#     Rate limit remaining: 4828
#   Stars: 23, Forks: 3, Success: True
#
# Processing 200/3796: Animator Import
#   Making API call for lifelike/godot-animator-import
#     API Response: 200
#     Rate limit remaining: 4827
#   Stars: 7, Forks: 0, Success: True
#
# Processing 201/3796: AnimSheet - SpriteSheet to Animation Player
#   Making API call for Lighar/AnimSheet
#     API Response: 200
#     Rate limit remaining: 4826
#   Stars: 5, Forks: 1, Success: True
#
# Processing 202/3796: Anomaly Aces Table
#   Making API call for AnomalyAces/AnomalyAcesTable
#     API Response: 200
#     Rate limit remaining: 4825
#   Stars: 8, Forks: 2, Success: True
#
# Processing 203/3796: Anti-cheating-value
#   Making API call for baiXfeng/against-cheating-value
#     API Response: 200
#     Rate limit remaining: 4824
#   Stars: 52, Forks: 4, Success: True
# Skipping 204/3796: Anti-cheating-value-plus (already processed)
#
# Processing 205/3796: Antialiased Line2D - Better antialiasing for 2D line/polygon/circle drawing
#   Making API call for godot-extended-libraries/godot-antialiased-line2d
#     API Response: 200
#     Rate limit remaining: 4823
#   Stars: 148, Forks: 8, Success: True
# Skipping 206/3796: Antialiased Line2D - Better antialiasing for 2D line/polygon/circle drawing (already processed)
#
# Processing 207/3796: Antialiased Line2D Demo
#   Making API call for godot-extended-libraries/godot-antialiased-line2d-demo
#     API Response: 200
#     Rate limit remaining: 4822
#   Stars: 5, Forks: 4, Success: True
# Skipping 208/3796: Antialiased Line2D Demo (already processed)
#
# Processing 209/3796: AnyIcon: type and class icons utility
#   Making API call for xorblo-doitus/AnyIcon
#     API Response: 200
#     Rate limit remaining: 4821
#   Stars: 2, Forks: 0, Success: True
#
# Processing 210/3796: Applinks
#   Making API call for FoolLin/Godot-Applinks-Android-Plugin
#     API Response: 200
#     Rate limit remaining: 4820
#   Stars: 4, Forks: 0, Success: True
#
# Processing 211/3796: AppLovinMAX
#   Making API call for AppLovin/AppLovin-MAX-Godot
#     API Response: 200
#     Rate limit remaining: 4819
#   Stars: 59, Forks: 8, Success: True
#   Checkpoint saved: 170 repos processed
#
# Processing 212/3796: Appwrite SDK
#   Making API call for GodotNuts/appwrite-sdk
#     API Response: 200
#     Rate limit remaining: 4818
#   Stars: 54, Forks: 6, Success: True
#
# Processing 213/3796: APRUM
#   Making API call for demurzasty/aprum
#     API Response: 200
#     Rate limit remaining: 4817
#   Stars: 6, Forks: 0, Success: True
#
# Processing 214/3796: Arabfunny Generator
#   Making API call for Pawlogates/arabfunny_controller
#     API Response: 200
#     Rate limit remaining: 4816
#   Stars: 10, Forks: 0, Success: True
#
# Processing 215/3796: Arabic Support
#   Making API call for 3akev/godot-arabic-text
#     API Response: 200
#     Rate limit remaining: 4815
#   Stars: 22, Forks: 7, Success: True
#
# Processing 216/3796: AraVox - Dialogue Writing Helper
#   Making API call for aravikusu/AraVox
#     API Response: 200
#     Rate limit remaining: 4814
#   Stars: 5, Forks: 1, Success: True
#
# Processing 217/3796: Arc2D
#   Making API call for s3rdia/Arc2D
#     API Response: 200
#     Rate limit remaining: 4813
#   Stars: 6, Forks: 0, Success: True
#
# Processing 218/3796: Archura's Credits
#   Making API call for Draconis-25/AG-Credits
#     API Response: 200
#     Rate limit remaining: 4812
#   Stars: 2, Forks: 2, Success: True
#
# Processing 219/3796: Arcweave Godot Plugin
#   Making API call for arcweave/arcweave-godot-plugin
#     API Response: 200
#     Rate limit remaining: 4811
#   Stars: 12, Forks: 1, Success: True
# Skipping 220/3796: Arcweave Godot Plugin (already processed)
#
# Processing 221/3796: AreaOfSight2D
#   Making API call for Arzzzen105/AreaOfVision2D
#     API Response: 200
#     Rate limit remaining: 4809
#   Stars: 27, Forks: 5, Success: True
#
# Processing 222/3796: ArgParse
#   Making API call for BtheDestroyer/GodotArgParse
#     API Response: 200
#     Rate limit remaining: 4807
#   Stars: 5, Forks: 0, Success: True
#   Checkpoint saved: 180 repos processed
#
# Processing 223/3796: Arky Addons
#   Making API call for ArkkyDev/arky-addons
#     API Response: 200
#     Rate limit remaining: 4806
#   Stars: 1, Forks: 0, Success: True
#
# Processing 224/3796: Arm Performance Studio Integration
#   Making API call for ARM-software/arm-performance-studio-integration-for-godot
#     API Response: 200
#     Rate limit remaining: 4805
#   Stars: 3, Forks: 1, Success: True
#
# Processing 225/3796: ArrayUtils
#   Making API call for drusin/godot-array-utils
#     API Response: 200
#     Rate limit remaining: 4804
#   Stars: 1, Forks: 1, Success: True
#
# Processing 226/3796: Arrow2D
#   Making API call for potikhanovsergey/godot-3.5-arrow2d-plugin
#     API Response: 200
#     Rate limit remaining: 4803
#   Stars: 2, Forks: 0, Success: True
#
# Processing 227/3796: Arrow3D
#   Making API call for yankscally/arrow_3d
#     API Response: 200
#     Rate limit remaining: 4802
#   Stars: 3, Forks: 1, Success: True
#
# Processing 228/3796: Artificial Worm Brain AI
#   Making API call for leparlon/WormBrain
#     API Response: 200
#     Rate limit remaining: 4801
#   Stars: 5, Forks: 0, Success: True
#
# Processing 229/3796: Aseprite Animation Importer - Godot 4
#   Making API call for AtkinTC/aseprite_importer
#     API Response: 200
#     Rate limit remaining: 4800
#   Stars: 11, Forks: 2, Success: True
#
# Processing 230/3796: Aseprite Helper
#   Making API call for antonWetzel/AsepriteHelper
#     API Response: 200
#     Rate limit remaining: 4799
#   Stars: 4, Forks: 4, Success: True
#
# Processing 231/3796: Aseprite import
#   Making API call for eska014/aseprite-import
#     API Response: 200
#     Rate limit remaining: 4797
#   Stars: 45, Forks: 7, Success: True
#
# Processing 232/3796: Aseprite Importer
#   Making API call for hectorid/aseprite_importer
#     API Response: 200
#     Rate limit remaining: 4796
#   Stars: 86, Forks: 15, Success: True
#   Checkpoint saved: 190 repos processed
#
# Processing 233/3796: Aseprite Wizard
#   Making API call for viniciusgerevini/godot-aseprite-wizard
#     API Response: 200
#     Rate limit remaining: 4795
#   Stars: 1040, Forks: 44, Success: True
# Skipping 234/3796: Aseprite Wizard (already processed)
#
# Processing 235/3796: AsepriteAnimSetter
#   Making API call for Peatral/AsepriteAnimSetter
#     API Response: 200
#     Rate limit remaining: 4794
#   Stars: 11, Forks: 0, Success: True
#
# Processing 236/3796: Asset Atlas Replacer
#   Making API call for JessicaCC-gd/asset_atlas_replacer
#     API Response: 200
#     Rate limit remaining: 4793
#   Stars: 0, Forks: 0, Success: True
#
# Processing 237/3796: Asset Dock
#   Making API call for Reetro/Asset-Dock
#     API Response: 200
#     Rate limit remaining: 4792
#   Stars: 21, Forks: 2, Success: True
#
# Processing 238/3796: Asset Drawer
#   Making API call for newjoker6/Horizontal-Filesystem-Like-Unity
#     API Response: 200
#     Rate limit remaining: 4790
#   Stars: 144, Forks: 7, Success: True
#
# Processing 239/3796: Assets Manager
#   Making API call for Mehdi-Saleh/Asset-Manager
#     API Response: 200
#     Rate limit remaining: 4789
#   Stars: 5, Forks: 0, Success: True
#
# Processing 240/3796: AssetsPathGenerator
#   Making API call for Abab-bk/AssetsPathGenerator
#     API Response: 200
#     Rate limit remaining: 4788
#   Stars: 3, Forks: 1, Success: True
#
# Processing 241/3796: Assorted Controls
#   Making API call for detomon/godot-assorted-controls
#     API Response: 200
#     Rate limit remaining: 4787
#   Stars: 9, Forks: 1, Success: True
#
# Processing 242/3796: AStar Grid Pathfinding Demo (with tutorial Video)
#   Making API call for Goldenlion5648/GodotAStarGridDemo
#     API Response: 200
#     Rate limit remaining: 4786
#   Stars: 5, Forks: 0, Success: True
#
# Processing 243/3796: Async Resource Loader (C#)
#   Making API call for ProFiLeR4100/AsyncResourceLoaderForCS
#     API Response: 200
#     Rate limit remaining: 4785
#   Stars: 11, Forks: 0, Success: True
#   Checkpoint saved: 200 repos processed
#
# Processing 244/3796: Async Socket
#   Making API call for carabalonepaulo/async_socket
#     API Response: 200
#     Rate limit remaining: 4784
#   Stars: 5, Forks: 1, Success: True
#
# Processing 245/3796: Asynchronous Scene Loader
#   Making API call for EiTaNBaRiBoA/AsyncScene
#     API Response: 200
#     Rate limit remaining: 4783
#   Stars: 24, Forks: 1, Success: True
#
# Processing 246/3796: Asynchronous Task Manager
#   Making API call for Mr-Slurpy/Multi-Task-Manager
#     API Response: 404
#     Rate limit remaining: 4782
#     Repository not found: Mr-Slurpy/Multi-Task-Manager
#   Stars: 0, Forks: 0, Success: False
#
# Processing 247/3796: Atko.GDWeaver Assets
#   Making API call for u/46150392
#     API Response: 404
#     Rate limit remaining: 4781
#     Repository not found: u/46150392
#   Stars: 0, Forks: 0, Success: False
#
# Processing 248/3796: Atlas Importer3
#   Making API call for vichui/atlas_importer3
#     API Response: 200
#     Rate limit remaining: 4780
#   Stars: 7, Forks: 2, Success: True
#
# Processing 249/3796: AtlasPlayer
#   Making API call for Nif-kun/godot-atlas-player
#     API Response: 200
#     Rate limit remaining: 4779
#   Stars: 5, Forks: 1, Success: True
#
# Processing 250/3796: Atmosphere shader
#   Making API call for Zylann/godot_atmosphere_shader
#     API Response: 200
#     Rate limit remaining: 4778
#   Stars: 121, Forks: 9, Success: True
# Skipping 251/3796: Atmosphere shader (already processed)
# Skipping 252/3796: Audio BPM Sync Demo (already processed)
# Skipping 253/3796: Audio BPM Sync Demo (already processed)
#
# Processing 254/3796: Audio Control
#   Making API call for VP-GAMES/AudioControl
#     API Response: 200
#     Rate limit remaining: 4777
#   Stars: 5, Forks: 1, Success: True
# Skipping 255/3796: Audio Device Changer Demo (already processed)
#
# Processing 256/3796: Audio Effect Inspector
#   Making API call for NoodleSushi/AudioEffectInspector_GodotAddon
#     API Response: 200
#     Rate limit remaining: 4776
#   Stars: 35, Forks: 3, Success: True
#
# Processing 257/3796: Audio Events
#   Making API call for FreekDS/GodotAudioEvents
#     API Response: 200
#     Rate limit remaining: 4775
#   Stars: 6, Forks: 1, Success: True
#   Checkpoint saved: 210 repos processed
# Skipping 258/3796: Audio Generator Demo (already processed)
#
# Processing 259/3796: Audio Haptics
#   Making API call for timoschwarzer/godot-audio-haptics
#     API Response: 200
#     Rate limit remaining: 4774
#   Stars: 8, Forks: 0, Success: True
#
# Processing 260/3796: Audio Loader
#   Making API call for MasterPolska123/Audio-Loader
#     API Response: 200
#     Rate limit remaining: 4772
#   Stars: 3, Forks: 1, Success: True
#
# Processing 261/3796: Audio Manager
#   Making API call for Saulo-de-Souza/AudioManager
#     API Response: 200
#     Rate limit remaining: 4771
#   Stars: 8, Forks: 0, Success: True
#
# Processing 262/3796: Audio Manager 3D
#   Making API call for Saulo-de-Souza/Audio-Manager-3D
#     API Response: 200
#     Rate limit remaining: 4770
#   Stars: 7, Forks: 0, Success: True
# Skipping 263/3796: Audio Microphone Record Demo (already processed)
#
# Processing 264/3796: Audio Mixer Visualizer
#   Making API call for Landeplage/Godot-Audio-Mixer-Visualizer
#     API Response: 200
#     Rate limit remaining: 4769
#   Stars: 3, Forks: 2, Success: True
#
# Processing 265/3796: Audio Node Wrangler Addon
#   Making API call for jhlothamer/audio_node_wrangler_addon
#     API Response: 200
#     Rate limit remaining: 4768
#   Stars: 2, Forks: 0, Success: True
# Skipping 266/3796: Audio Spectrum Visualizer Demo (already processed)
#
# Processing 267/3796: Audio Station
#   Making API call for boukew99/audio_station
#     API Response: 200
#     Rate limit remaining: 4767
#   Stars: 3, Forks: 1, Success: True
#
# Processing 268/3796: Audio Stream Player Clipper 2D
#   Making API call for Saulo-de-Souza/Audio-Stream-Player-Clipper-2D
#     API Response: 200
#     Rate limit remaining: 4766
#   Stars: 4, Forks: 1, Success: True
#
# Processing 269/3796: Audio Stream Player Clipper 3D
#   Making API call for Saulo-de-Souza/Audio-Stream-Player-Clipper-3D
#     API Response: 200
#     Rate limit remaining: 4765
#   Stars: 1, Forks: 2, Success: True
#
# Processing 270/3796: Audio Visualizer Plugin
#   Making API call for MahadDareshani/Audio-Visualizer-Plugin-Godot
#     API Response: 200
#     Rate limit remaining: 4764
#   Stars: 2, Forks: 1, Success: True
#   Checkpoint saved: 220 repos processed
#
# Processing 271/3796: AudioEffectGate
#   Making API call for Visssarion/audio-gate
#     API Response: 200
#     Rate limit remaining: 4763
#   Stars: 7, Forks: 1, Success: True
#
# Processing 272/3796: AudioGame RPG
#   Making API call for NarayanaWalters/PTS
#     API Response: 200
#     Rate limit remaining: 4762
#   Stars: 4, Forks: 3, Success: True
#
# Processing 273/3796: AudioLogic
#   Making API call for chafmere/AudioLogic
#     API Response: 200
#     Rate limit remaining: 4761
#   Stars: 4, Forks: 1, Success: True
#
# Processing 274/3796: AudiosPlugin : Godot iOS Audio Plugin
#   Making API call for audiosdev/AudiosPlugin-Godot-iOS-Audio-Plugin
#     API Response: 200
#     Rate limit remaining: 4760
#   Stars: 8, Forks: 1, Success: True
#
# Processing 275/3796: AudioStream Subtitle
#   Making API call for S83gamedev/AudioStream-Subtitle-Plugin
#     API Response: 200
#     Rate limit remaining: 4759
#   Stars: 4, Forks: 1, Success: True
#
# Processing 276/3796: AudioStreamPlayerArea2D
#   Making API call for Julian-Vos/godot-scripts
#     API Response: 200
#     Rate limit remaining: 4758
#   Stars: 48, Forks: 7, Success: True
# Skipping 277/3796: AudioStreamPlayerArea2D (already processed)
#
# Processing 278/3796: AudioStreamPlayerMultiple
#   Making API call for mawario103/AudioStreamPlayerMultiple
#     API Response: 200
#     Rate limit remaining: 4757
#   Stars: 0, Forks: 0, Success: True
#
# Processing 279/3796: AudioStreamPreview
#   Making API call for fbcosentino/godot-audiostreampreview
#     API Response: 200
#     Rate limit remaining: 4756
#   Stars: 12, Forks: 2, Success: True
#
# Processing 280/3796: Auto add class_name
#   Making API call for zwickarr/godot-auto-class-name
#     API Response: 200
#     Rate limit remaining: 4755
#   Stars: 4, Forks: 1, Success: True
#
# Processing 281/3796: Auto Export Version
#   Making API call for KoBeWi/Godot-Auto-Export-Version
#     API Response: 200
#     Rate limit remaining: 4754
#   Stars: 64, Forks: 4, Success: True
#   Checkpoint saved: 230 repos processed
# Skipping 282/3796: Auto Export Version (already processed)
#
# Processing 283/3796: Auto Night Mode
#   Making API call for rambda/godot_auto_night_mode
#     API Response: 200
#     Rate limit remaining: 4753
#   Stars: 8, Forks: 2, Success: True
#
# Processing 284/3796: Auto Polygon2D Triangulation
#   Making API call for dweremeichik/godot_autopoly_plugin
#     API Response: 200
#     Rate limit remaining: 4752
#   Stars: 25, Forks: 3, Success: True
#
# ...
#     Rate limit remaining: 4602
#   Stars: 15, Forks: 1, Success: True
#
# Processing 3706/3796: Stair-stepping Demo
#   Making API call for JheKWall/Godot-Stair-Step-Demo
#     API Response: 200
#     Rate limit remaining: 4600
#   Stars: 32, Forks: 2, Success: True
#
# Processing 3707/3796: Start.io Godot Android Plugin
#   Making API call for fernacas-dev/godot-startio-android-plugin
#     API Response: 200
#     Rate limit remaining: 4599
#   Stars: 4, Forks: 0, Success: True
#   Checkpoint saved: 3170 repos processed
#
# Processing 3708/3796: State Graph
#   Making API call for MrBSmith/StateGraph
#     API Response: 200
#     Rate limit remaining: 4598
#   Stars: 39, Forks: 8, Success: True
#
# Processing 3709/3796: State Machine
#   Making API call for AlecSouthward/state-machine
#     API Response: 200
#     Rate limit remaining: 4597
#   Stars: 30, Forks: 0, Success: True
#
# Processing 3710/3796: State Machine for Platformer Games
#   Making API call for CeesarLeon2002/state-machine-for-platformer-games
#     API Response: 404
#     Rate limit remaining: 4596
#     Repository not found: CeesarLeon2002/state-machine-for-platformer-games
#   Stars: 0, Forks: 0, Success: False
#
# Processing 3711/3796: Statechart Sharp: a state machine plugin
#   Making API call for laoguowangCP/godot-statechart-sharp
#     API Response: 200
#     Rate limit remaining: 4595
#   Stars: 18, Forks: 0, Success: True
#
# Processing 3712/3796: Steam Template
#   Making API call for Malcolm-Q/SteamGodotTemplate
#     API Response: 200
#     Rate limit remaining: 4594
#   Stars: 35, Forks: 3, Success: True
#
# Processing 3713/3796: Stopwatch
#   Making API call for GuaraProductions/Stopwatch
#     API Response: 200
#     Rate limit remaining: 4593
#   Stars: 7, Forks: 1, Success: True
#
# Processing 3714/3796: Storage Manager
#   Making API call for davidkbd/Godot_StorageManager
#     API Response: 200
#     Rate limit remaining: 4592
#   Stars: 4, Forks: 1, Success: True
#
# Processing 3715/3796: String utilities
#   Making API call for mxt08-real/String-utilities
#     API Response: 200
#     Rate limit remaining: 4591
#   Stars: 1, Forks: 0, Success: True
#
# Processing 3716/3796: SuperChart-draggable&zoomable
#   Making API call for DeanNevan/Godot-2D-Super-Chart
#     API Response: 200
#     Rate limit remaining: 4590
#   Stars: 5, Forks: 2, Success: True
#
# Processing 3717/3796: SuperLightning
#   Making API call for DeanNevan/Godot-2D-Super-Lightning
#     API Response: 200
#     Rate limit remaining: 4589
#   Stars: 11, Forks: 1, Success: True
#   Checkpoint saved: 3180 repos processed
#
# Processing 3718/3796: Switch Manager
#   Making API call for AlecSouthward/Switch-Manager
#     API Response: 200
#     Rate limit remaining: 4588
#   Stars: 3, Forks: 1, Success: True
#
# Processing 3719/3796: TableDB
#   Making API call for GeCreator/TableDB
#     API Response: 200
#     Rate limit remaining: 4587
#   Stars: 2, Forks: 0, Success: True
#
# Processing 3720/3796: TCG Layout (.NET only)
#   Making API call for Jaete/TCG-Hand-Layout
#     API Response: 200
#     Rate limit remaining: 4586
#   Stars: 5, Forks: 0, Success: True
#
# Processing 3721/3796: Telegram Bot API
#   Making API call for fenix-hub/godot-engine.telegram-bot
#     API Response: 200
#     Rate limit remaining: 4585
#   Stars: 9, Forks: 2, Success: True
#
# Processing 3722/3796: Template for Hole.io style games
#   Making API call for Go3DGoGodot/Hole.io-made-in-Godot
#     API Response: 200
#     Rate limit remaining: 4584
#   Stars: 6, Forks: 1, Success: True
#
# Processing 3723/3796: Template for pathfinding games
#   Making API call for xolatgames/Pathfinding
#     API Response: 200
#     Rate limit remaining: 4583
#   Stars: 5, Forks: 1, Success: True
#
# Processing 3724/3796: TemplateSaver
#   Making API call for D0RYU/TemplateSaver
#     API Response: 200
#     Rate limit remaining: 4582
#   Stars: 7, Forks: 1, Success: True
#
# Processing 3725/3796: Terrain Editor
#   Making API call for Zylann/godot_terrain_plugin
#     API Response: 200
#     Rate limit remaining: 4581
#   Stars: 128, Forks: 24, Success: True
#
# Processing 3726/3796: Texture Progress of Subunits
#   Making API call for JarLowrey/TextureProgressOfSubunits
#     API Response: 200
#     Rate limit remaining: 4580
#   Stars: 8, Forks: 1, Success: True
# Skipping 3727/3796: TextureButtonColored (already processed)
#
# Processing 3728/3796: TexturePacker Importer (SpriteSheet, AtlasTexture)
#   Making API call for CodeAndWeb/texturepacker-godot-plugin
#     API Response: 200
#     Rate limit remaining: 4579
#   Stars: 72, Forks: 19, Success: True
#   Checkpoint saved: 3190 repos processed
# Skipping 3729/3796: TexturePacker Importer (SpriteSheet, AtlasTexture, TileSet) for Godot 3 (already processed)
# Skipping 3730/3796: TexturePacker Importer (SpriteSheet, AtlasTexture, TileSet) for Godot 3.5 (already processed)
#
# Processing 3731/3796: Third Person Controller
#   Making API call for WaffleAWT/Godot-4.3-Third-Person-Controller
#     API Response: 200
#     Rate limit remaining: 4578
#   Stars: 42, Forks: 3, Success: True
#
# Processing 3732/3796: Third Person Controller
#   Making API call for Sombresonge/Third-Person-Controller
#     API Response: 200
#     Rate limit remaining: 4577
#   Stars: 7, Forks: 3, Success: True
#
# Processing 3733/3796: TileSetCutter
#   Making API call for JeromeOrtali/TileSetCutter
#     API Response: 200
#     Rate limit remaining: 4576
#   Stars: 4, Forks: 3, Success: True
#
# Processing 3734/3796: Todo Cards
#   Making API call for WhalesState/godot-todo-cards
#     API Response: 200
#     Rate limit remaining: 4575
#   Stars: 19, Forks: 2, Success: True
#
# Processing 3735/3796: TODO Manager (Godot 3.x)
#   Making API call for OrigamiDev-Pete/TODO_Manager
#     API Response: 200
#     Rate limit remaining: 4574
#   Stars: 417, Forks: 24, Success: True
# Skipping 3736/3796: TODO Manager (Godot 4) (already processed)
#
# Processing 3737/3796: Toggle Code Generation
#   Making API call for zaevi/godot-toggle-code-generation
#     API Response: 200
#     Rate limit remaining: 4573
#   Stars: 0, Forks: 0, Success: True
#
# Processing 3738/3796: Tracer
#   Making API call for wyvernbw/tracer.gd
#     API Response: 200
#     Rate limit remaining: 4572
#   Stars: 32, Forks: 1, Success: True
#
# Processing 3739/3796: Tracery
#   Making API call for Althar93/GDTracery
#     API Response: 200
#     Rate limit remaining: 4571
#   Stars: 15, Forks: 3, Success: True
#
# Processing 3740/3796: TrailMesh
#   Making API call for tcmug/godot_trailmesh
#     API Response: 200
#     Rate limit remaining: 4570
#   Stars: 45, Forks: 7, Success: True
#
# Processing 3741/3796: Transition Type Demo
#   Making API call for Ark2000/Trans-Type-Demo
#     API Response: 200
#     Rate limit remaining: 4569
#   Stars: 0, Forks: 0, Success: True
#   Checkpoint saved: 3200 repos processed
#
# Processing 3742/3796: Translation editor
#   Making API call for Zylann/godot_translation_editor
#     API Response: 200
#     Rate limit remaining: 4568
#   Stars: 44, Forks: 3, Success: True
#
# Processing 3743/3796: Typed Dictionary NET
#   Making API call for PattyHoswell/Godot-NET-Typed-Dictionary
#     API Response: 200
#     Rate limit remaining: 4567
#   Stars: 5, Forks: 0, Success: True
#
# Processing 3744/3796: UI-Expander
#   Making API call for omid3098/expander-addon
#     API Response: 200
#     Rate limit remaining: 4566
#   Stars: 2, Forks: 0, Success: True
#
# Processing 3745/3796: UniParticles3D
#   Making API call for DanielSnd/UniParticles3D
#     API Response: 200
#     Rate limit remaining: 4565
#   Stars: 25, Forks: 2, Success: True
#
# Processing 3746/3796: unirest gdscript
#   Making API call for fenix-hub/unirest-gdscript
#     API Response: 200
#     Rate limit remaining: 4564
#   Stars: 36, Forks: 1, Success: True
#
# Processing 3747/3796: Universal Save/Load System
#   Making API call for stupidratstudio/thoth
#     API Response: 200
#     Rate limit remaining: 4563
#   Stars: 22, Forks: 0, Success: True
#
# Processing 3748/3796: Useful Shader Nodes for Godot 4
#   Making API call for ReKylee/Useful-Shader-Nodes-for-Godot-4
#     API Response: 200
#     Rate limit remaining: 4562
#   Stars: 4, Forks: 1, Success: True
#
# Processing 3749/3796: Vehicle Controller 2D
#   Making API call for ivanskodje-godotengine/Vehicle-Controller-2D
#     API Response: 200
#     Rate limit remaining: 4561
#   Stars: 21, Forks: 10, Success: True
#
# Processing 3750/3796: vim-motion
#   Making API call for wovri-github/godot-vim-joshnajera
#     API Response: 200
#     Rate limit remaining: 4560
#   Stars: 16, Forks: 1, Success: True
#
# Processing 3751/3796: Visual Behavior Tree
#   Making API call for fian46/addons-btree
#     API Response: 200
#     Rate limit remaining: 4559
#   Stars: 117, Forks: 20, Success: True
#   Checkpoint saved: 3210 repos processed
# Skipping 3752/3796: Visual Script Circle Pop Demo (already processed)
# Skipping 3753/3796: Visual Script Multitouch View Demo (already processed)
#
# Processing 3754/3796: Visual Shader Derive Z Node
#   Making API call for Foyezes/Godot-Derive-Z-Node
#     API Response: 200
#     Rate limit remaining: 4558
#   Stars: 0, Forks: 0, Success: True
#
# Processing 3755/3796: Visual Shader Height Blend Node
#   Making API call for Foyezes/Godot-HeightBlend-Node
#     API Response: 200
#     Rate limit remaining: 4557
#   Stars: 1, Forks: 0, Success: True
#
# Processing 3756/3796: Visual Shader Normal Combine Node
#   Making API call for Foyezes/Godot-Normal-Combine-Node
#     API Response: 200
#     Rate limit remaining: 4556
#   Stars: 4, Forks: 2, Success: True
#
# Processing 3757/3796: Visual Shader Normal Strength Node
#   Making API call for Foyezes/Godot-Normal-Strength-Node
#     API Response: 200
#     Rate limit remaining: 4555
#   Stars: 0, Forks: 0, Success: True
#
# Processing 3758/3796: Visual Shader Parallax Mapping Node
#   Making API call for Foyezes/Godot-Parallax-Mapping-Node
#     API Response: 200
#     Rate limit remaining: 4554
#   Stars: 0, Forks: 0, Success: True
#
# Processing 3759/3796: Visual Shader Pixel Normal World Node
#   Making API call for Foyezes/Godot-Pixel-Normal-World-Node
#     API Response: 200
#     Rate limit remaining: 4553
#   Stars: 0, Forks: 0, Success: True
#
# Processing 3760/3796: Visual Shader UV Manipulation Node
#   Making API call for Foyezes/Godot-UV-Manipulation-Node
#     API Response: 200
#     Rate limit remaining: 4552
#   Stars: 1, Forks: 0, Success: True
#
# Processing 3761/3796: Visual Shader UV Nodes Pack
#   Making API call for Foyezes/Visual-Shader-UV-Nodes-Pack
#     API Response: 200
#     Rate limit remaining: 4551
#   Stars: 0, Forks: 0, Success: True
#
# Processing 3762/3796: Visual Shader Vector Transform Node
#   Making API call for Foyezes/Godot-Vector-Transform-Node
#     API Response: 200
#     Rate limit remaining: 4550
#   Stars: 5, Forks: 0, Success: True
#
# Processing 3763/3796: VOID
#   Making API call for dbiton/VOID
#     API Response: 200
#     Rate limit remaining: 4549
#   Stars: 1, Forks: 0, Success: True
#   Checkpoint saved: 3220 repos processed
#
# Processing 3764/3796: Volume Sliders (Singleton example)
#   Making API call for ManuelArtz/Volume-Sliders-Singleton-example-
#     API Response: 200
#     Rate limit remaining: 4547
#   Stars: 0, Forks: 1, Success: True
#
# Processing 3765/3796: Volumetric Fog
#   Making API call for Bauxitedev/volumetric-fog-demo
#     API Response: 200
#     Rate limit remaining: 4546
#   Stars: 50, Forks: 3, Success: True
#
# Processing 3766/3796: VoronoiShatter - Procedurally fracture 3D meshes
#   Making API call for robertvaradan/voronoishatter
#     API Response: 200
#     Rate limit remaining: 4545
#   Stars: 35, Forks: 5, Success: True
#
# Processing 3767/3796: VoxelOctree
#   Making API call for BraindeadBZH/VoxelOctreePlugin
#     API Response: 200
#     Rate limit remaining: 4544
#   Stars: 23, Forks: 3, Success: True
#
# Processing 3768/3796: Vpainter
#   Making API call for nx7r/Vpainter
#     API Response: 200
#     Rate limit remaining: 4543
#   Stars: 41, Forks: 2, Success: True
#
# Processing 3769/3796: VR Tools
#   Making API call for anunknowperson/godot-vr-tools
#     API Response: 200
#     Rate limit remaining: 4542
#   Stars: 8, Forks: 1, Success: True
#
# Processing 3770/3796: VRM Importer and MToon Shader - Humanoid 3d Avatar Model Format
#   Making API call for V-Sekai/godot-vrm
#     API Response: 200
#     Rate limit remaining: 4541
#   Stars: 352, Forks: 30, Success: True
# Skipping 3771/3796: VRM Importer for 3D Avatars and MToon Shader (already processed)
#
# Processing 3772/3796: WAD Level Loader
#   Making API call for Chaosus/GDWADLevelLoader
#     API Response: 200
#     Rate limit remaining: 4540
#   Stars: 33, Forks: 3, Success: True
#
# Processing 3773/3796: WAT - Unit Testing Framework
#   Making API call for CodeDarigan/WAT
#     API Response: 200
#     Rate limit remaining: 4538
#   Stars: 315, Forks: 18, Success: True
#
# Processing 3774/3796: WAT Unit Testing Framework
#   Making API call for AlexDarigan/WAT
#     API Response: 200
#     Rate limit remaining: 4536
#   Stars: 315, Forks: 18, Success: True
#   Checkpoint saved: 3230 repos processed
# Skipping 3775/3796: WAT Unit Testing Framework (For Godot Mono) (already processed)
#
# Processing 3776/3796: Water shader
#   Making API call for faculezcano/godot-water-shader
#     API Response: 200
#     Rate limit remaining: 4535
#   Stars: 16, Forks: 2, Success: True
# Skipping 3777/3796: WebRTC Minimal Demo (already processed)
# Skipping 3778/3796: WebRTC Signaling Demo (already processed)
# Skipping 3779/3796: WebSocket Chat Demo (already processed)
# Skipping 3780/3796: WebSocket Minimal Demo (already processed)
# Skipping 3781/3796: Websocket Multiplayer Demo (already processed)
#
# Processing 3782/3796: Weeping Angel Example
#   Making API call for bypell/weeping-angel-godot
#     API Response: 200
#     Rate limit remaining: 4534
#   Stars: 18, Forks: 4, Success: True
# Skipping 3783/3796: Window Management Demo (already processed)
#
# Processing 3784/3796: WindowsV2
#   Making API call for brb-fr/windows-v2
#     API Response: 200
#     Rate limit remaining: 4533
#   Stars: 1, Forks: 0, Success: True
#
# Processing 3785/3796: WIP 0.5 - Abstract State Machine Graphic (ASM)
#   Making API call for nonunknown/abstract-state-machine
#     API Response: 200
#     Rate limit remaining: 4531
#   Stars: 27, Forks: 3, Success: True
#
# Processing 3786/3796: World of Alpheratz (Platformer Demo)
#   Making API call for Ark2000/world_of_alpheratz
#     API Response: 200
#     Rate limit remaining: 4530
#   Stars: 97, Forks: 17, Success: True
#
# Processing 3787/3796: xBRZ Screen-Filter
#   Making API call for LanzaSchneider/godot-xBRZ
#     API Response: 200
#     Rate limit remaining: 4529
#   Stars: 12, Forks: 3, Success: True
#
# Processing 3788/3796: XMLReader
#   Making API call for ACB-prgm/XMLReader
#     API Response: 200
#     Rate limit remaining: 4528
#   Stars: 1, Forks: 0, Success: True
#
# Processing 3789/3796: Xsolla SDK
#   Making API call for godot279/XsollaSDK
#     API Response: 200
#     Rate limit remaining: 4526
#   Stars: 6, Forks: 0, Success: True
#
# Processing 3790/3796: Yamms - Yet another MultiMesh Scatter
#   Making API call for Mattiny/yamms
#     API Response: 200
#     Rate limit remaining: 4525
#   Stars: 35, Forks: 5, Success: True
#
# Processing 3791/3796: YouTube Sub Counter
#   Making API call for takelime/Godot-YouTube-API
#     API Response: 200
#     Rate limit remaining: 4523
#   Stars: 1, Forks: 0, Success: True
#   Checkpoint saved: 3240 repos processed
#
# Processing 3792/3796: YouTube's button effect
#   Making API call for SpyrexDE/YoutubeButtonEffect
#     API Response: 200
#     Rate limit remaining: 4522
#   Stars: 8, Forks: 0, Success: True
#
# Processing 3793/3796: Zalance SDK
#   Making API call for ZalanceInc/zalance-godot-sdk
#     API Response: 200
#     Rate limit remaining: 4521
#   Stars: 1, Forks: 0, Success: True
#
# Processing 3794/3796: Zone Area2D Editor
#   Making API call for xphere/godot-zone
#     API Response: 200
#     Rate limit remaining: 4520
#   Stars: 9, Forks: 1, Success: True
#
# Processing 3795/3796: Zoomy
#   Making API call for nobuyukinyuu/zoomy
#     API Response: 200
#     Rate limit remaining: 4519
#   Stars: 6, Forks: 1, Success: True
#
# Processing 3796/3796: [DEPRECATED] Blockchain SDK by Enjin [DEPRECATED]
#   Making API call for enjin/enjin-godot-sdk
#     API Response: 404
#     Rate limit remaining: 4518
#     Repository not found: enjin/enjin-godot-sdk
#   Stars: 0, Forks: 0, Success: False
#
# === SAVING 3245 REPOS WITH RAW GITHUB DATA ===
# Step 3 complete - raw data with duplicates preserved

# %% [markdown]
# ### Step 4 - Clean

# %% [markdown]
# ### Step 5 - Plot

# %%
def create_plots():
    with open('raw_github_rankings.csv', 'r', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        repos = list(reader)
    
    # Filter only successful API calls
    successful_repos = [repo for repo in repos if repo['api_success'] == 'True']
    
    stars = [int(repo['stars']) for repo in successful_repos]
    forks = [int(repo['forks']) for repo in successful_repos]
    categories = [repo['category'] for repo in successful_repos]
    titles = [repo['title'] for repo in successful_repos]
    
    last_updated = []
    for repo in successful_repos:
        try:
            if repo['last_updated']:
                date_obj = datetime.fromisoformat(repo['last_updated'].replace('Z', '+00:00'))
                last_updated.append(date_obj)
            else:
                last_updated.append(None)
        except:
            last_updated.append(None)
    
    # 1. Top repositories by stars
    plt.figure(figsize=(6, 8))
    sorted_repos = sorted(zip(titles, stars), key=lambda x: x[1], reverse=True)
    top_titles, top_stars = zip(*sorted_repos[:30])
    
    plt.barh(range(len(top_titles)), top_stars, color='#4CAF50')
    plt.yticks(range(len(top_titles)), [title[:30] + '...' if len(title) > 30 else title for title in top_titles])
    plt.xlabel('Stars (log scale)')
    plt.xscale('log')
    plt.title('Top 30 by Stars', fontsize=10, fontweight='bold')
    plt.gca().invert_yaxis()
    plt.grid(True, alpha=0.3, axis='x')
    
    for i, v in enumerate(top_stars):
        plt.text(v * 1.1, i, f'{v:,}', va='center', fontsize=8)
    
    plt.tight_layout()
    plt.savefig('top_repos_by_stars.png')
    plt.close()
        
    # 2. Category distribution
    plt.figure(figsize=(4, 4))
    category_counts = Counter(categories)
    top_categories = dict(category_counts.most_common(8))
    
    colors = plt.cm.Set3(np.linspace(0, 1, len(top_categories)))
    wedges, texts, autotexts = plt.pie(top_categories.values(), labels=top_categories.keys(), 
                                       autopct='%1.1f%%', colors=colors, startangle=90)
    plt.title('Distribution by Category', fontsize=10, fontweight='bold')
    
    for autotext in autotexts:
        autotext.set_fontsize(10)
        autotext.set_color('black')
    
    plt.tight_layout()
    plt.savefig('category_distribution.png')
    plt.close()
    
    # 3. Activity timeline (last updated dates) - 3 years, wide chart
    plt.figure(figsize=(8, 3))
    valid_dates = [date for date in last_updated if date is not None]
    if valid_dates:
        months = [date.strftime('%Y-%m') for date in valid_dates]
        month_counts = Counter(months)
        
        sorted_months = sorted(month_counts.items())
        recent_months = sorted_months[-36:]  # Last 36 months (3 years)
        
        if recent_months:
            month_labels, counts = zip(*recent_months)
            plt.bar(range(len(month_labels)), counts, color='#FF9800', alpha=0.7)
            plt.xticks(range(len(month_labels)), month_labels, rotation=45, ha='right')
            plt.ylabel('Repositories Updated')
            plt.title('Activity Timeline (Last 3 Years)', fontsize=10, fontweight='bold')
            plt.grid(True, alpha=0.3, axis='y')
    
    plt.tight_layout()
    plt.savefig('activity_timeline.png')
    plt.close()
    
    print(f"Analysis of {len(successful_repos)} repositories with GitHub data:")
    print(f"Total repositories processed: {len(repos)}")
    print(f"Successful API calls: {len(successful_repos)}")
    print(f"Failed API calls: {len(repos) - len(successful_repos)}")
    print(f"Total stars: {sum(stars):,}")
    print(f"Total forks: {sum(forks):,}")
    print(f"Average stars: {np.mean(stars):.1f}")
    print(f"Median stars: {np.median(stars):.1f}")
    
    if category_counts:
        print(f"Most popular category: {category_counts.most_common(1)[0][0]} ({category_counts.most_common(1)[0][1]} repos)")
    
    high_star_repos = [repo for repo in successful_repos if int(repo['stars']) > 100]
    print(f"Repositories with >100 stars: {len(high_star_repos)}")
    
    top_5_repos = sorted(successful_repos, key=lambda x: int(x['stars']), reverse=True)[:5]
    print("\nTop 5 repositories:")
    for i, repo in enumerate(top_5_repos, 1):
        print(f"{i}. {repo['title']} - {repo['stars']} stars ({repo['category']})")
    
    print("\nGenerated 4 plot files:")
    print("- top_repos_by_stars.png")
    print("- stars_vs_forks.png") 
    print("- category_distribution.png")
    print("- activity_timeline.png")

create_plots()
# Out:
# Analysis of 3165 repositories with GitHub data:
# Total repositories processed: 3243
# Successful API calls: 3165
# Failed API calls: 78
# Total stars: 179,132
# Total forks: 16,134
# Average stars: 56.6
# Median stars: 10.0
# Most popular category: Tools (1061 repos)
# Repositories with >100 stars: 328
#
# Top 5 repositories:
# 1. Godot Demo Projects - 6935 stars (Demos)
# 2. Material Maker - 4059 stars (3D Tools)
# 3. Terrain3D - 2990 stars (3D Tools)
# 4. Dialogue Manager - 2779 stars (Tools)
# 5. Phantom Camera - 2658 stars (Tools)
#
# Generated 4 plot files:
# - top_repos_by_stars.png
# - stars_vs_forks.png
# - category_distribution.png
# - activity_timeline.png

# %% [markdown]
# ### Step 6 - Create README.md

# %%
def generate_readme():
    # Read the data from CSV files
    with open('raw_github_rankings.csv', 'r', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        repos = list(reader)
    
    # Filter only successful API calls
    successful_repos = [repo for repo in repos if repo['api_success'] == 'True']
    
    stars = [int(repo['stars']) for repo in successful_repos]
    forks = [int(repo['forks']) for repo in successful_repos]
    categories = [repo['category'] for repo in successful_repos]
    
    # Group by category
    category_groups = {}
    for repo in successful_repos:
        category = repo['category'] if repo['category'] else 'Other'
        if category not in category_groups:
            category_groups[category] = []
        category_groups[category].append(repo)
    
    # Sort each category by stars
    for category in category_groups:
        category_groups[category].sort(key=lambda x: int(x['stars']), reverse=True)
    
    # Sort categories by their top repo's star count
    sorted_categories = sorted(category_groups.items(), 
                             key=lambda x: int(x[1][0]['stars']) if x[1] else 0, 
                             reverse=True)
    
    # Load non-GitHub assets for additional table
    non_github_assets = []
    try:
        with open('non_github_assets_final.csv', 'r', encoding='utf-8') as f:
            reader = csv.DictReader(f)
            non_github_assets = list(reader)
    except FileNotFoundError:
        pass
    
    # Start building README
    markdown = """# Godot Stars!

Here we provide a leaderboard for assets in the Godot Asset Library.

## Overview

"""
    
    # Add statistics
    category_counts = Counter(categories)
    high_star_repos = [repo for repo in successful_repos if int(repo['stars']) > 100]
    
    markdown += f"""- Total repositories analyzed: {len(repos):,}
- Successful GitHub API calls: {len(successful_repos):,}
- Total stars across all repos: {sum(stars):,}
- Total forks across all repos: {sum(forks):,}
- Average stars per repository: {np.mean(stars):.1f}
- Median stars per repository: {np.median(stars):.1f}
- Repositories with >100 stars: {len(high_star_repos)}
- Categories represented: {len(category_counts)}

"""
    
    if category_counts:
        top_category = category_counts.most_common(1)[0]
        markdown += f"Most popular category: {top_category[0]} ({top_category[1]} repositories)\n\n"
    
    # Add visualizations section
    markdown += """## Repositories by Category

Repositories with 10+ stars, ranked by GitHub stars.

"""
    
    # Add category tables
    for category, category_repos in sorted_categories:
        repos_10_plus = [repo for repo in category_repos if int(repo['stars']) >= 10]
        if not repos_10_plus:
            continue
            
        markdown += f"### {category}\n\n"
        markdown += "| Repository | Stars | Forks | Last Updated | License |\n"
        markdown += "|------------|-------|-------|--------------|----------|\n"
        
        for repo in repos_10_plus:
            name = f"[{repo['title']}]({repo['github_url']})"
            stars = f"{int(repo['stars']):,}"
            forks = f"{int(repo['forks']):,}"
            license_text = repo.get('license', 'N/A')
            
            try:
                if repo['last_updated']:
                    date_obj = datetime.fromisoformat(repo['last_updated'].replace('Z', '+00:00'))
                    last_updated = date_obj.strftime('%Y-%m-%d')
                else:
                    last_updated = 'N/A'
            except:
                last_updated = 'N/A'
            
            markdown += f"| {name} | {stars} | {forks} | {last_updated} | {license_text} |\n"
        
    markdown += "\n"
    markdown += """## Visualizations

![Top Repositories by Stars](top_repos_by_stars.png)

![Category Distribution](category_distribution.png)

![Repository Activity Timeline](activity_timeline.png)"""

    # Add non-GitHub assets table if available
    markdown += "\n"
    if non_github_assets:
        markdown += f"""## Non-GitHub Assets

{len(non_github_assets)} assets without GitHub repositories, sorted alphabetically.

| Asset | Category | License | Author |
|-------|----------|---------|---------|
"""
        
        for asset in non_github_assets:#[:20]:  # Show first 20
            name = f"[{asset['title']}]({asset['asset_url']})"
            category = asset.get('category', 'N/A')
            license_text = asset.get('license', 'N/A')
            author = asset.get('author', 'N/A')
            markdown += f"| {name} | {category} | {license_text} | {author} |\n"
        
        #if len(non_github_assets) > 20:
            #markdown += f"\n...and {len(non_github_assets) - 20} more assets\n"
        
        markdown += "\n"
    
    markdown += f"\nGenerated on {datetime.now().strftime('%Y-%m-%d')}"

    # Write README
    with open('README.md', 'w', encoding='utf-8') as f:
        f.write(markdown)
    
    print(f"Generated README.md with:")
    print(f"- {len(sorted_categories)} categories")
    print(f"- {len(successful_repos)} repositories with GitHub data")
    if non_github_assets:
        print(f"- {len(non_github_assets)} non-GitHub assets")
    print(f"- 4 embedded visualization images")
    
    print(f"\nTop categories by leading repository:")
    for category, category_repos in sorted_categories[:5]:
        if category_repos:
            top_repo = category_repos[0]
            print(f"  {category}: {top_repo['title']} ({int(top_repo['stars']):,} stars)")

generate_readme()
# Out:
# Generated README.md with:
# - 10 categories
# - 3165 repositories with GitHub data
# - 179 non-GitHub assets
# - 4 embedded visualization images
#
# Top categories by leading repository:
#   Demos: Godot Demo Projects (6,935 stars)
#   3D Tools: Material Maker (4,059 stars)
#   Tools: Dialogue Manager (2,779 stars)
#   2D Tools: RMSmartShape2D (1,503 stars)
#   Templates: COGITO : Immersive Sim Template (1,357 stars)
